# %%
# Load all 6 pretrained models

from sparseDPD import DataManager, ARVTDNN_NeuralNetwork, Volterra, PNTDNN_NeuralNetwork, PGJANET_NeuralNetwork

# Same dataset/training style as refactored_notebook.ipynb
simpleDataManager = DataManager(
    num_training_points=20000,
    num_validaiton_points=2000,
    num_test_points=2000,
    filepath='UCD_datasets/PA_IO.mat'
)

# Setup a volterra model and a volterra inverse
volterra_forward_model = Volterra(num_nl_orders=3, num_memory_levels=3, dataset=simpleDataManager.training_dataset)

print(f" Volterra NMSE: {volterra_forward_model.calculate_volterra_nmse(simpleDataManager.test_dataset)} dB")

ARVTDNN_one_layer_forward_nn = ARVTDNN_NeuralNetwork(
    num_memory_levels=15,
    forward_model=True,
    model_type = 'OneLayerNetwork',
    nn_file_path = 'pre_trained_models/arvtdnn_one_layer.pt'
)

PGJANET_forward_nn = PGJANET_NeuralNetwork(
    num_memory_levels=50,
    forward_model=True,
    nn_file_path = 'pre_trained_models/pgjanet_checkpoint.pt',
    batch_size=32,
    seq_stride=1
)

PNTDNN_one_layer_forward_nn = PNTDNN_NeuralNetwork(
    num_memory_levels=15,
    forward_model=True,
    nn_file_path = 'pre_trained_models/pntdnn_one_layer.pt'
)

PNTDNN_multi_layer_forward_nn = PNTDNN_NeuralNetwork(
    num_memory_levels=15,
    forward_model=True,
    model_type = 'MultiLayerNetwork',
    nn_file_path = 'pre_trained_models/pntdnn_multi_layer.pt'
)

PNTDNN_three_layer_forward_nn = PNTDNN_NeuralNetwork(
    num_memory_levels=15,
    forward_model=True,
    model_type = 'ThreeLayerNetwork',
    nn_file_path = 'pre_trained_models/pntdnn_three_layer.pt'
)
# Out:
#  Volterra NMSE: -36.75465903237275 dB
# Using cuda device
# Using cuda device
# Using cuda device
# Using cuda device
# Using cuda device

# %%
# Use the New Adaptive Pruning Experiment on PNTDNN one layer forward model
from sparseDPD import AdaptivePruningExperiment

adaptive_pruning_experiment = AdaptivePruningExperiment(
    nn_model=PNTDNN_one_layer_forward_nn,
    retrain_epochs= 200,
    training_dataset = simpleDataManager.training_dataset,
    valid_dataset = simpleDataManager.validation_dataset,
    test_dataset = simpleDataManager.test_dataset,
    nmse_tolerance = 1,
    initial_prune_fraction=0.5,
    min_prune_fraction=0.01,
    max_prune_fraction=0.5
)

adaptive_pruning_experiment.run()
# Out:
# Baseline NMSE          : -40.0258 dB
# Tolerance              : +1.00 dB
# NMSE must stay below   : -39.0258 dB
# Initial prune fraction : 50.0%
# Min prune fraction     : 1.0%
# Max prune fraction     : 50.0%
#
# ============================================================
# Step 1  |  fraction = 50.00%
# ============================================================
# Pruning 50.00% of remaining weights...
# Current sparsity: 50.00% of weights are zero
# Retraining for 200 epochs...
# Epoch  10/200  Loss=2.3411e-01  Valid Loss=1.7739e-02  LR=1.00e-03  NMSE=-40.3068 dB
# Epoch  20/200  Loss=2.1904e-01  Valid Loss=1.6514e-02  LR=1.00e-03  NMSE=-40.6175 dB
# Epoch  30/200  Loss=2.2258e-01  Valid Loss=1.6849e-02  LR=1.00e-03  NMSE=-40.5304 dB
# Epoch  40/200  Loss=1.9162e-01  Valid Loss=2.0225e-02  LR=5.00e-04  NMSE=-39.7372 dB
# Epoch  50/200  Loss=1.7854e-01  Valid Loss=1.5476e-02  LR=2.50e-04  NMSE=-40.8996 dB
# Epoch  60/200  Loss=1.6762e-01  Valid Loss=1.5114e-02  LR=1.25e-04  NMSE=-41.0025 dB
# Epoch  70/200  Loss=1.6829e-01  Valid Loss=1.4997e-02  LR=1.25e-04  NMSE=-41.0360 dB
# Epoch  80/200  Loss=1.6836e-01  Valid Loss=1.4866e-02  LR=1.25e-04  NMSE=-41.0741 dB
# Epoch  90/200  Loss=1.6808e-01  Valid Loss=1.4781e-02  LR=1.25e-04  NMSE=-41.0990 dB
# Epoch 100/200  Loss=1.6763e-01  Valid Loss=1.4720e-02  LR=1.25e-04  NMSE=-41.1170 dB
# Epoch 110/200  Loss=1.6718e-01  Valid Loss=1.4669e-02  LR=1.25e-04  NMSE=-41.1320 dB
# Epoch 120/200  Loss=1.6666e-01  Valid Loss=1.4621e-02  LR=1.25e-04  NMSE=-41.1464 dB
# Epoch 130/200  Loss=1.6616e-01  Valid Loss=1.4571e-02  LR=1.25e-04  NMSE=-41.1612 dB
# Epoch 140/200  Loss=1.6572e-01  Valid Loss=1.4532e-02  LR=1.25e-04  NMSE=-41.1727 dB
# Epoch 150/200  Loss=1.6531e-01  Valid Loss=1.4491e-02  LR=1.25e-04  NMSE=-41.1850 dB
# Epoch 160/200  Loss=1.6488e-01  Valid Loss=1.4454e-02  LR=1.25e-04  NMSE=-41.1964 dB
# Epoch 170/200  Loss=1.6447e-01  Valid Loss=1.4416e-02  LR=1.25e-04  NMSE=-41.2077 dB
# Epoch 180/200  Loss=1.6410e-01  Valid Loss=1.4378e-02  LR=1.25e-04  NMSE=-41.2192 dB
# Epoch 190/200  Loss=1.6370e-01  Valid Loss=1.4339e-02  LR=1.25e-04  NMSE=-41.2310 dB
# Epoch 200/200  Loss=1.6337e-01  Valid Loss=1.4307e-02  LR=1.25e-04  NMSE=-41.2406 dB
#
# Best model from epoch 200 with validation loss: 1.4307e-02
# NMSE: -40.5729 dB  (threshold: -39.0258 dB)
#   ACCEPTED  (delta: -0.5471 dB)
#   Plenty of headroom -> increasing next fraction to 50.00%
#
# ============================================================
# Step 2  |  fraction = 50.00%
# ============================================================
# Pruning 50.00% of remaining weights...
# Current sparsity: 75.00% of weights are zero
# Retraining for 200 epochs...
# Epoch  10/200  Loss=3.4788e-01  Valid Loss=3.1582e-02  LR=1.00e-03  NMSE=-37.8017 dB
# Epoch  20/200  Loss=2.4387e-01  Valid Loss=2.2784e-02  LR=1.00e-03  NMSE=-39.2199 dB
# Epoch  30/200  Loss=2.1540e-01  Valid Loss=1.7884e-02  LR=1.00e-03  NMSE=-40.2716 dB
# Epoch  40/200  Loss=2.0340e-01  Valid Loss=1.5752e-02  LR=1.00e-03  NMSE=-40.8227 dB
# Epoch  50/200  Loss=1.9815e-01  Valid Loss=1.5243e-02  LR=1.00e-03  NMSE=-40.9653 dB
# Epoch  60/200  Loss=1.9837e-01  Valid Loss=1.5144e-02  LR=1.00e-03  NMSE=-40.9937 dB
# Epoch  70/200  Loss=1.8700e-01  Valid Loss=2.0420e-02  LR=5.00e-04  NMSE=-39.6956 dB
# Epoch  80/200  Loss=1.7302e-01  Valid Loss=1.4779e-02  LR=2.50e-04  NMSE=-41.0998 dB
# Epoch  90/200  Loss=1.7430e-01  Valid Loss=1.4704e-02  LR=2.50e-04  NMSE=-41.1217 dB
# Epoch 100/200  Loss=1.6746e-01  Valid Loss=1.5027e-02  LR=1.25e-04  NMSE=-41.0273 dB
# Epoch 110/200  Loss=1.6683e-01  Valid Loss=1.5104e-02  LR=6.25e-05  NMSE=-41.0052 dB
# Epoch 120/200  Loss=1.6538e-01  Valid Loss=1.4435e-02  LR=3.13e-05  NMSE=-41.2021 dB
# Epoch 130/200  Loss=1.6463e-01  Valid Loss=1.4461e-02  LR=3.13e-05  NMSE=-41.1942 dB
# Epoch 140/200  Loss=1.6343e-01  Valid Loss=1.4417e-02  LR=1.56e-05  NMSE=-41.2074 dB
# Epoch 150/200  Loss=1.6276e-01  Valid Loss=1.4395e-02  LR=7.81e-06  NMSE=-41.2140 dB
# Epoch 160/200  Loss=1.6246e-01  Valid Loss=1.4390e-02  LR=3.91e-06  NMSE=-41.2154 dB
# Epoch 170/200  Loss=1.6232e-01  Valid Loss=1.4385e-02  LR=1.95e-06  NMSE=-41.2171 dB
# Epoch 180/200  Loss=1.6223e-01  Valid Loss=1.4387e-02  LR=9.77e-07  NMSE=-41.2166 dB
# Epoch 190/200  Loss=1.6222e-01  Valid Loss=1.4387e-02  LR=4.88e-07  NMSE=-41.2164 dB
# Epoch 200/200  Loss=1.6217e-01  Valid Loss=1.4389e-02  LR=4.88e-07  NMSE=-41.2157 dB
#
# Best model from epoch 168 with validation loss: 1.4384e-02
# NMSE: -40.5447 dB  (threshold: -39.0258 dB)
#   ACCEPTED  (delta: -0.5188 dB)
#   Plenty of headroom -> increasing next fraction to 50.00%
#
# ============================================================
# Step 3  |  fraction = 50.00%
# ============================================================
# Pruning 50.00% of remaining weights...
# Current sparsity: 87.50% of weights are zero
# Retraining for 200 epochs...
# Epoch  10/200  Loss=5.3121e-01  Valid Loss=5.5333e-02  LR=1.00e-03  NMSE=-35.3663 dB
# Epoch  20/200  Loss=4.5420e-01  Valid Loss=4.7640e-02  LR=1.00e-03  NMSE=-36.0165 dB
# Epoch  30/200  Loss=4.2777e-01  Valid Loss=4.4307e-02  LR=1.00e-03  NMSE=-36.3314 dB
# Epoch  40/200  Loss=4.1871e-01  Valid Loss=4.2933e-02  LR=1.00e-03  NMSE=-36.4682 dB
# Epoch  50/200  Loss=4.1390e-01  Valid Loss=4.1783e-02  LR=1.00e-03  NMSE=-36.5862 dB
# Epoch  60/200  Loss=4.1025e-01  Valid Loss=4.0854e-02  LR=1.00e-03  NMSE=-36.6838 dB
# Epoch  70/200  Loss=4.0748e-01  Valid Loss=4.0305e-02  LR=1.00e-03  NMSE=-36.7425 dB
# Epoch  80/200  Loss=4.0500e-01  Valid Loss=3.9857e-02  LR=1.00e-03  NMSE=-36.7911 dB
# Epoch  90/200  Loss=4.0240e-01  Valid Loss=3.9415e-02  LR=1.00e-03  NMSE=-36.8395 dB
# Epoch 100/200  Loss=3.9965e-01  Valid Loss=3.8963e-02  LR=1.00e-03  NMSE=-36.8896 dB
# Epoch 110/200  Loss=3.9679e-01  Valid Loss=3.8488e-02  LR=1.00e-03  NMSE=-36.9429 dB
# Epoch 120/200  Loss=3.9376e-01  Valid Loss=3.7998e-02  LR=1.00e-03  NMSE=-36.9986 dB
# Epoch 130/200  Loss=3.9064e-01  Valid Loss=3.7491e-02  LR=1.00e-03  NMSE=-37.0569 dB
# Epoch 140/200  Loss=3.8743e-01  Valid Loss=3.6972e-02  LR=1.00e-03  NMSE=-37.1174 dB
# Epoch 150/200  Loss=3.8417e-01  Valid Loss=3.6458e-02  LR=1.00e-03  NMSE=-37.1782 dB
# Epoch 160/200  Loss=3.8090e-01  Valid Loss=3.5950e-02  LR=1.00e-03  NMSE=-37.2392 dB
# Epoch 170/200  Loss=3.7770e-01  Valid Loss=3.5456e-02  LR=1.00e-03  NMSE=-37.2992 dB
# Epoch 180/200  Loss=3.7453e-01  Valid Loss=3.4974e-02  LR=1.00e-03  NMSE=-37.3587 dB
# Epoch 190/200  Loss=3.7146e-01  Valid Loss=3.4514e-02  LR=1.00e-03  NMSE=-37.4162 dB
# Epoch 200/200  Loss=3.6821e-01  Valid Loss=3.4086e-02  LR=1.00e-03  NMSE=-37.4703 dB
#
# Best model from epoch 200 with validation loss: 3.4086e-02
# NMSE: -37.1470 dB  (threshold: -39.0258 dB)
#   REJECTED  (delta: +2.8788 dB) — restoring model
#   Reduced fraction to 25.00%
#
# ============================================================
# Step 4  |  fraction = 25.00%
# ============================================================
# Pruning 25.00% of remaining weights...
# Current sparsity: 81.25% of weights are zero
# Retraining for 200 epochs...
# Epoch  10/200  Loss=2.0604e-01  Valid Loss=1.6264e-02  LR=1.00e-03  NMSE=-40.6838 dB
# Epoch  20/200  Loss=2.0325e-01  Valid Loss=1.5879e-02  LR=1.00e-03  NMSE=-40.7880 dB
# Epoch  30/200  Loss=2.0111e-01  Valid Loss=1.5683e-02  LR=1.00e-03  NMSE=-40.8418 dB
# Epoch  40/200  Loss=1.9979e-01  Valid Loss=1.5557e-02  LR=1.00e-03  NMSE=-40.8769 dB
# Epoch  50/200  Loss=1.9878e-01  Valid Loss=1.5479e-02  LR=1.00e-03  NMSE=-40.8988 dB
# Epoch  60/200  Loss=1.9800e-01  Valid Loss=1.5425e-02  LR=1.00e-03  NMSE=-40.9139 dB
# Epoch  70/200  Loss=1.9730e-01  Valid Loss=1.5385e-02  LR=1.00e-03  NMSE=-40.9252 dB
# Epoch  80/200  Loss=1.9672e-01  Valid Loss=1.5342e-02  LR=1.00e-03  NMSE=-40.9372 dB
# Epoch  90/200  Loss=1.9617e-01  Valid Loss=1.5310e-02  LR=1.00e-03  NMSE=-40.9464 dB
# Epoch 100/200  Loss=1.9569e-01  Valid Loss=1.5280e-02  LR=1.00e-03  NMSE=-40.9548 dB
# Epoch 110/200  Loss=1.9498e-01  Valid Loss=1.5269e-02  LR=1.00e-03  NMSE=-40.9579 dB
# Epoch 120/200  Loss=1.8891e-01  Valid Loss=1.9337e-02  LR=5.00e-04  NMSE=-39.9323 dB
# Epoch 130/200  Loss=1.7492e-01  Valid Loss=1.5069e-02  LR=2.50e-04  NMSE=-41.0152 dB
# Epoch 140/200  Loss=1.7581e-01  Valid Loss=1.4923e-02  LR=2.50e-04  NMSE=-41.0574 dB
# Epoch 150/200  Loss=1.7645e-01  Valid Loss=1.4932e-02  LR=2.50e-04  NMSE=-41.0550 dB
# Epoch 160/200  Loss=1.7023e-01  Valid Loss=1.5315e-02  LR=1.25e-04  NMSE=-40.9448 dB
# Epoch 170/200  Loss=1.6958e-01  Valid Loss=1.5259e-02  LR=6.25e-05  NMSE=-40.9609 dB
# Epoch 180/200  Loss=1.6765e-01  Valid Loss=1.4687e-02  LR=3.13e-05  NMSE=-41.1268 dB
# Epoch 190/200  Loss=1.6662e-01  Valid Loss=1.4683e-02  LR=1.56e-05  NMSE=-41.1281 dB
# Epoch 200/200  Loss=1.6605e-01  Valid Loss=1.4657e-02  LR=7.81e-06  NMSE=-41.1357 dB
#
# Best model from epoch 200 with validation loss: 1.4657e-02
# NMSE: -40.4363 dB  (threshold: -39.0258 dB)
#   ACCEPTED  (delta: -0.4105 dB)
#   Plenty of headroom -> increasing next fraction to 37.50%
#
# ============================================================
# Step 5  |  fraction = 37.50%
# ============================================================
# Pruning 37.50% of remaining weights...
# Current sparsity: 88.33% of weights are zero
# Retraining for 200 epochs...
# Epoch  10/200  Loss=8.4260e-01  Valid Loss=7.8955e-02  LR=1.00e-03  NMSE=-33.8224 dB
# Epoch  20/200  Loss=6.7001e-01  Valid Loss=6.7898e-02  LR=1.00e-03  NMSE=-34.4776 dB
# Epoch  30/200  Loss=5.8082e-01  Valid Loss=6.1848e-02  LR=1.00e-03  NMSE=-34.8829 dB
# Epoch  40/200  Loss=5.0870e-01  Valid Loss=5.5388e-02  LR=1.00e-03  NMSE=-35.3620 dB
# Epoch  50/200  Loss=4.7162e-01  Valid Loss=5.1426e-02  LR=1.00e-03  NMSE=-35.6843 dB
# Epoch  60/200  Loss=4.4798e-01  Valid Loss=4.8397e-02  LR=1.00e-03  NMSE=-35.9480 dB
# Epoch  70/200  Loss=4.3165e-01  Valid Loss=4.6169e-02  LR=1.00e-03  NMSE=-36.1526 dB
# Epoch  80/200  Loss=4.2380e-01  Valid Loss=4.4729e-02  LR=1.00e-03  NMSE=-36.2903 dB
# Epoch  90/200  Loss=4.1803e-01  Valid Loss=4.3666e-02  LR=1.00e-03  NMSE=-36.3947 dB
# Epoch 100/200  Loss=4.1064e-01  Valid Loss=4.2558e-02  LR=1.00e-03  NMSE=-36.5063 dB
# Epoch 110/200  Loss=4.0088e-01  Valid Loss=4.1227e-02  LR=1.00e-03  NMSE=-36.6443 dB
# Epoch 120/200  Loss=3.8723e-01  Valid Loss=3.9447e-02  LR=1.00e-03  NMSE=-36.8360 dB
# Epoch 130/200  Loss=3.6715e-01  Valid Loss=3.6882e-02  LR=1.00e-03  NMSE=-37.1279 dB
# Epoch 140/200  Loss=3.3049e-01  Valid Loss=3.2264e-02  LR=1.00e-03  NMSE=-37.7090 dB
# Epoch 150/200  Loss=2.8155e-01  Valid Loss=2.6044e-02  LR=1.00e-03  NMSE=-38.6390 dB
# Epoch 160/200  Loss=2.5192e-01  Valid Loss=2.2342e-02  LR=1.00e-03  NMSE=-39.3050 dB
# Epoch 170/200  Loss=2.3840e-01  Valid Loss=2.0577e-02  LR=1.00e-03  NMSE=-39.6623 dB
# Epoch 180/200  Loss=2.3133e-01  Valid Loss=1.9644e-02  LR=1.00e-03  NMSE=-39.8638 dB
# Epoch 190/200  Loss=2.2703e-01  Valid Loss=1.9108e-02  LR=1.00e-03  NMSE=-39.9840 dB
# Epoch 200/200  Loss=2.2426e-01  Valid Loss=1.8769e-02  LR=1.00e-03  NMSE=-40.0617 dB
#
# Best model from epoch 200 with validation loss: 1.8769e-02
# NMSE: -39.4694 dB  (threshold: -39.0258 dB)
#   ACCEPTED  (delta: +0.5565 dB)
#   Moderate headroom -> keeping next fraction at 37.50%
#
# ============================================================
# Step 6  |  fraction = 37.50%
# ============================================================
# Pruning 37.50% of remaining weights...
# Current sparsity: 92.78% of weights are zero
# Retraining for 200 epochs...
# Epoch  10/200  Loss=3.9683e-01  Valid Loss=3.7009e-02  LR=1.00e-03  NMSE=-37.1131 dB
# Epoch  20/200  Loss=3.7065e-01  Valid Loss=3.4265e-02  LR=1.00e-03  NMSE=-37.4476 dB
# Epoch  30/200  Loss=3.5723e-01  Valid Loss=3.2983e-02  LR=1.00e-03  NMSE=-37.6133 dB
# Epoch  40/200  Loss=3.4704e-01  Valid Loss=3.2159e-02  LR=1.00e-03  NMSE=-37.7231 dB
# Epoch  50/200  Loss=3.3848e-01  Valid Loss=3.1587e-02  LR=1.00e-03  NMSE=-37.8010 dB
# Epoch  60/200  Loss=3.3141e-01  Valid Loss=3.1090e-02  LR=1.00e-03  NMSE=-37.8700 dB
# Epoch  70/200  Loss=3.2609e-01  Valid Loss=3.0430e-02  LR=1.00e-03  NMSE=-37.9631 dB
# Epoch  80/200  Loss=3.2291e-01  Valid Loss=2.9884e-02  LR=1.00e-03  NMSE=-38.0417 dB
# Epoch  90/200  Loss=3.2085e-01  Valid Loss=2.9531e-02  LR=1.00e-03  NMSE=-38.0933 dB
# Epoch 100/200  Loss=3.1927e-01  Valid Loss=2.9319e-02  LR=1.00e-03  NMSE=-38.1247 dB
# Epoch 110/200  Loss=3.1798e-01  Valid Loss=2.9166e-02  LR=1.00e-03  NMSE=-38.1474 dB
# Epoch 120/200  Loss=3.1694e-01  Valid Loss=2.9042e-02  LR=1.00e-03  NMSE=-38.1658 dB
# Epoch 130/200  Loss=3.1604e-01  Valid Loss=2.8945e-02  LR=1.00e-03  NMSE=-38.1804 dB
# Epoch 140/200  Loss=3.1524e-01  Valid Loss=2.8860e-02  LR=1.00e-03  NMSE=-38.1932 dB
# Epoch 150/200  Loss=3.1454e-01  Valid Loss=2.8784e-02  LR=1.00e-03  NMSE=-38.2046 dB
# Epoch 160/200  Loss=3.1389e-01  Valid Loss=2.8715e-02  LR=1.00e-03  NMSE=-38.2151 dB
# Epoch 170/200  Loss=3.1332e-01  Valid Loss=2.8652e-02  LR=1.00e-03  NMSE=-38.2246 dB
# Epoch 180/200  Loss=3.1281e-01  Valid Loss=2.8597e-02  LR=1.00e-03  NMSE=-38.2329 dB
# Epoch 190/200  Loss=3.1234e-01  Valid Loss=2.8550e-02  LR=1.00e-03  NMSE=-38.2401 dB
# Epoch 200/200  Loss=3.1193e-01  Valid Loss=2.8508e-02  LR=1.00e-03  NMSE=-38.2464 dB
#
# Best model from epoch 200 with validation loss: 2.8508e-02
# NMSE: -37.8805 dB  (threshold: -39.0258 dB)
#   REJECTED  (delta: +2.1453 dB) — restoring model
#   Reduced fraction to 18.75%
#
# ============================================================
# Step 7  |  fraction = 18.75%
# ============================================================
# Pruning 18.75% of remaining weights...
# Current sparsity: 90.56% of weights are zero
# Retraining for 200 epochs...
# Epoch  10/200  Loss=2.6811e-01  Valid Loss=2.3595e-02  LR=1.00e-03  NMSE=-39.0680 dB
# Epoch  20/200  Loss=2.6765e-01  Valid Loss=2.3469e-02  LR=1.00e-03  NMSE=-39.0912 dB
# Epoch  30/200  Loss=2.6738e-01  Valid Loss=2.3398e-02  LR=1.00e-03  NMSE=-39.1043 dB
# Epoch  40/200  Loss=2.6714e-01  Valid Loss=2.3338e-02  LR=1.00e-03  NMSE=-39.1156 dB
# Epoch  50/200  Loss=2.6690e-01  Valid Loss=2.3283e-02  LR=1.00e-03  NMSE=-39.1257 dB
# Epoch  60/200  Loss=2.6667e-01  Valid Loss=2.3232e-02  LR=1.00e-03  NMSE=-39.1354 dB
# Epoch  70/200  Loss=2.6643e-01  Valid Loss=2.3179e-02  LR=1.00e-03  NMSE=-39.1451 dB
# Epoch  80/200  Loss=2.6616e-01  Valid Loss=2.3125e-02  LR=1.00e-03  NMSE=-39.1554 dB
# Epoch  90/200  Loss=2.6590e-01  Valid Loss=2.3068e-02  LR=1.00e-03  NMSE=-39.1660 dB
# Epoch 100/200  Loss=2.6560e-01  Valid Loss=2.3008e-02  LR=1.00e-03  NMSE=-39.1774 dB
# Epoch 110/200  Loss=2.6531e-01  Valid Loss=2.2948e-02  LR=1.00e-03  NMSE=-39.1886 dB
# Epoch 120/200  Loss=2.6497e-01  Valid Loss=2.2884e-02  LR=1.00e-03  NMSE=-39.2007 dB
# Epoch 130/200  Loss=2.6458e-01  Valid Loss=2.2821e-02  LR=1.00e-03  NMSE=-39.2127 dB
# Epoch 140/200  Loss=2.6415e-01  Valid Loss=2.2748e-02  LR=1.00e-03  NMSE=-39.2266 dB
# Epoch 150/200  Loss=2.6368e-01  Valid Loss=2.2670e-02  LR=1.00e-03  NMSE=-39.2416 dB
# Epoch 160/200  Loss=2.6322e-01  Valid Loss=2.2583e-02  LR=1.00e-03  NMSE=-39.2583 dB
# Epoch 170/200  Loss=2.6267e-01  Valid Loss=2.2490e-02  LR=1.00e-03  NMSE=-39.2762 dB
# Epoch 180/200  Loss=2.6204e-01  Valid Loss=2.2388e-02  LR=1.00e-03  NMSE=-39.2961 dB
# Epoch 190/200  Loss=2.6139e-01  Valid Loss=2.2276e-02  LR=1.00e-03  NMSE=-39.3178 dB
# Epoch 200/200  Loss=2.6063e-01  Valid Loss=2.2157e-02  LR=1.00e-03  NMSE=-39.3409 dB
#
# Best model from epoch 200 with validation loss: 2.2157e-02
# NMSE: -38.9054 dB  (threshold: -39.0258 dB)
#   REJECTED  (delta: +1.1204 dB) — restoring model
#   Reduced fraction to 9.38%
#
# ============================================================
# Step 8  |  fraction = 9.38%
# ============================================================
# Pruning 9.38% of remaining weights...
# Current sparsity: 89.44% of weights are zero
# Retraining for 200 epochs...
# Epoch  10/200  Loss=2.2441e-01  Valid Loss=1.8797e-02  LR=1.00e-03  NMSE=-40.0554 dB
# Epoch  20/200  Loss=2.2063e-01  Valid Loss=1.8398e-02  LR=1.00e-03  NMSE=-40.1484 dB
# Epoch  30/200  Loss=2.2009e-01  Valid Loss=1.8241e-02  LR=1.00e-03  NMSE=-40.1857 dB
# Epoch  40/200  Loss=2.1985e-01  Valid Loss=1.8150e-02  LR=1.00e-03  NMSE=-40.2073 dB
# Epoch  50/200  Loss=2.1942e-01  Valid Loss=1.8075e-02  LR=1.00e-03  NMSE=-40.2253 dB
# Epoch  60/200  Loss=2.1908e-01  Valid Loss=1.8022e-02  LR=1.00e-03  NMSE=-40.2382 dB
# Epoch  70/200  Loss=2.1879e-01  Valid Loss=1.7976e-02  LR=1.00e-03  NMSE=-40.2491 dB
# Epoch  80/200  Loss=2.1858e-01  Valid Loss=1.7936e-02  LR=1.00e-03  NMSE=-40.2589 dB
# Epoch  90/200  Loss=2.1840e-01  Valid Loss=1.7900e-02  LR=1.00e-03  NMSE=-40.2675 dB
# Epoch 100/200  Loss=2.1823e-01  Valid Loss=1.7870e-02  LR=1.00e-03  NMSE=-40.2748 dB
# Epoch 110/200  Loss=2.1809e-01  Valid Loss=1.7849e-02  LR=1.00e-03  NMSE=-40.2799 dB
# Epoch 120/200  Loss=2.1800e-01  Valid Loss=1.7828e-02  LR=1.00e-03  NMSE=-40.2852 dB
# Epoch 130/200  Loss=2.1791e-01  Valid Loss=1.7811e-02  LR=1.00e-03  NMSE=-40.2893 dB
# Epoch 140/200  Loss=2.1783e-01  Valid Loss=1.7801e-02  LR=1.00e-03  NMSE=-40.2918 dB
# Epoch 150/200  Loss=2.1777e-01  Valid Loss=1.7788e-02  LR=1.00e-03  NMSE=-40.2949 dB
# Epoch 160/200  Loss=2.1771e-01  Valid Loss=1.7776e-02  LR=1.00e-03  NMSE=-40.2979 dB
# Epoch 170/200  Loss=2.1765e-01  Valid Loss=1.7764e-02  LR=1.00e-03  NMSE=-40.3006 dB
# Epoch 180/200  Loss=2.1762e-01  Valid Loss=1.7758e-02  LR=1.00e-03  NMSE=-40.3021 dB
# Epoch 190/200  Loss=2.1760e-01  Valid Loss=1.7753e-02  LR=1.00e-03  NMSE=-40.3033 dB
# Epoch 200/200  Loss=2.1756e-01  Valid Loss=1.7748e-02  LR=1.00e-03  NMSE=-40.3046 dB
#
# Best model from epoch 200 with validation loss: 1.7748e-02
# NMSE: -39.7017 dB  (threshold: -39.0258 dB)
#   ACCEPTED  (delta: +0.3242 dB)
#   Plenty of headroom -> increasing next fraction to 14.06%
#
# ============================================================
# Step 9  |  fraction = 14.06%
# ============================================================
# Pruning 14.06% of remaining weights...
# Current sparsity: 90.97% of weights are zero
# Retraining for 200 epochs...
# Epoch  10/200  Loss=2.2529e-01  Valid Loss=1.7889e-02  LR=1.00e-03  NMSE=-40.2703 dB
# Epoch  20/200  Loss=2.2543e-01  Valid Loss=1.7818e-02  LR=1.00e-03  NMSE=-40.2875 dB
# Epoch  30/200  Loss=2.2530e-01  Valid Loss=1.7782e-02  LR=1.00e-03  NMSE=-40.2962 dB
# Epoch  40/200  Loss=2.2515e-01  Valid Loss=1.7756e-02  LR=1.00e-03  NMSE=-40.3026 dB
# Epoch  50/200  Loss=2.2501e-01  Valid Loss=1.7736e-02  LR=1.00e-03  NMSE=-40.3076 dB
# Epoch  60/200  Loss=2.2489e-01  Valid Loss=1.7719e-02  LR=1.00e-03  NMSE=-40.3118 dB
# Epoch  70/200  Loss=2.2478e-01  Valid Loss=1.7705e-02  LR=1.00e-03  NMSE=-40.3152 dB
# Epoch  80/200  Loss=2.2469e-01  Valid Loss=1.7693e-02  LR=1.00e-03  NMSE=-40.3182 dB
# Epoch  90/200  Loss=2.2461e-01  Valid Loss=1.7683e-02  LR=1.00e-03  NMSE=-40.3207 dB
# Epoch 100/200  Loss=2.2455e-01  Valid Loss=1.7673e-02  LR=1.00e-03  NMSE=-40.3230 dB
# Epoch 110/200  Loss=2.2448e-01  Valid Loss=1.7665e-02  LR=1.00e-03  NMSE=-40.3250 dB
# Epoch 120/200  Loss=2.2445e-01  Valid Loss=1.7658e-02  LR=1.00e-03  NMSE=-40.3268 dB
# Epoch 130/200  Loss=2.2436e-01  Valid Loss=1.7650e-02  LR=1.00e-03  NMSE=-40.3286 dB
# Epoch 140/200  Loss=2.2431e-01  Valid Loss=1.7644e-02  LR=1.00e-03  NMSE=-40.3302 dB
# Epoch 150/200  Loss=2.2430e-01  Valid Loss=1.7638e-02  LR=1.00e-03  NMSE=-40.3315 dB
# Epoch 160/200  Loss=2.2425e-01  Valid Loss=1.7633e-02  LR=1.00e-03  NMSE=-40.3328 dB
# Epoch 170/200  Loss=2.2420e-01  Valid Loss=1.7630e-02  LR=1.00e-03  NMSE=-40.3337 dB
# Epoch 180/200  Loss=2.2416e-01  Valid Loss=1.7626e-02  LR=1.00e-03  NMSE=-40.3345 dB
# Epoch 190/200  Loss=2.2413e-01  Valid Loss=1.7621e-02  LR=1.00e-03  NMSE=-40.3357 dB
# Epoch 200/200  Loss=2.2408e-01  Valid Loss=1.7617e-02  LR=1.00e-03  NMSE=-40.3369 dB
#
# Best model from epoch 200 with validation loss: 1.7617e-02
# NMSE: -39.6877 dB  (threshold: -39.0258 dB)
#   ACCEPTED  (delta: +0.3381 dB)
#   Moderate headroom -> keeping next fraction at 14.06%
#
# ============================================================
# Step 10  |  fraction = 14.06%
# ============================================================
# Pruning 14.06% of remaining weights...
# Current sparsity: 92.22% of weights are zero
# Retraining for 200 epochs...
# Epoch  10/200  Loss=3.8476e-01  Valid Loss=3.5785e-02  LR=1.00e-03  NMSE=-37.2592 dB
# Epoch  20/200  Loss=3.6605e-01  Valid Loss=3.3775e-02  LR=1.00e-03  NMSE=-37.5102 dB
# Epoch  30/200  Loss=3.5197e-01  Valid Loss=3.2446e-02  LR=1.00e-03  NMSE=-37.6845 dB
# Epoch  40/200  Loss=3.4001e-01  Valid Loss=3.1449e-02  LR=1.00e-03  NMSE=-37.8200 dB
# Epoch  50/200  Loss=3.3031e-01  Valid Loss=3.0752e-02  LR=1.00e-03  NMSE=-37.9174 dB
# Epoch  60/200  Loss=3.2286e-01  Valid Loss=3.0057e-02  LR=1.00e-03  NMSE=-38.0166 dB
# Epoch  70/200  Loss=3.1869e-01  Valid Loss=2.9277e-02  LR=1.00e-03  NMSE=-38.1309 dB
# Epoch  80/200  Loss=3.1700e-01  Valid Loss=2.8862e-02  LR=1.00e-03  NMSE=-38.1929 dB
# Epoch  90/200  Loss=3.1579e-01  Valid Loss=2.8696e-02  LR=1.00e-03  NMSE=-38.2179 dB
# Epoch 100/200  Loss=3.1474e-01  Valid Loss=2.8594e-02  LR=1.00e-03  NMSE=-38.2334 dB
# Epoch 110/200  Loss=3.1381e-01  Valid Loss=2.8515e-02  LR=1.00e-03  NMSE=-38.2454 dB
# Epoch 120/200  Loss=3.1299e-01  Valid Loss=2.8443e-02  LR=1.00e-03  NMSE=-38.2564 dB
# Epoch 130/200  Loss=3.1227e-01  Valid Loss=2.8372e-02  LR=1.00e-03  NMSE=-38.2673 dB
# Epoch 140/200  Loss=3.1163e-01  Valid Loss=2.8320e-02  LR=1.00e-03  NMSE=-38.2752 dB
# Epoch 150/200  Loss=3.1101e-01  Valid Loss=2.8272e-02  LR=1.00e-03  NMSE=-38.2825 dB
# Epoch 160/200  Loss=3.1046e-01  Valid Loss=2.8227e-02  LR=1.00e-03  NMSE=-38.2895 dB
# Epoch 170/200  Loss=3.0996e-01  Valid Loss=2.8188e-02  LR=1.00e-03  NMSE=-38.2955 dB
# Epoch 180/200  Loss=3.0950e-01  Valid Loss=2.8151e-02  LR=1.00e-03  NMSE=-38.3011 dB
# Epoch 190/200  Loss=3.0908e-01  Valid Loss=2.8119e-02  LR=1.00e-03  NMSE=-38.3062 dB
# Epoch 200/200  Loss=3.0870e-01  Valid Loss=2.8093e-02  LR=1.00e-03  NMSE=-38.3102 dB
#
# Best model from epoch 200 with validation loss: 2.8093e-02
# NMSE: -37.9439 dB  (threshold: -39.0258 dB)
#   REJECTED  (delta: +2.0819 dB) — restoring model
#   Reduced fraction to 7.03%
#
# ============================================================
# Step 11  |  fraction = 7.03%
# ============================================================
# Pruning 7.03% of remaining weights...
# Current sparsity: 91.67% of weights are zero
# Retraining for 200 epochs...
# Epoch  10/200  Loss=2.7190e-01  Valid Loss=2.3582e-02  LR=1.00e-03  NMSE=-39.0703 dB
# Epoch  20/200  Loss=2.7083e-01  Valid Loss=2.3450e-02  LR=1.00e-03  NMSE=-39.0948 dB
# Epoch  30/200  Loss=2.7034e-01  Valid Loss=2.3357e-02  LR=1.00e-03  NMSE=-39.1119 dB
# Epoch  40/200  Loss=2.6986e-01  Valid Loss=2.3285e-02  LR=1.00e-03  NMSE=-39.1254 dB
# Epoch  50/200  Loss=2.6944e-01  Valid Loss=2.3222e-02  LR=1.00e-03  NMSE=-39.1371 dB
# Epoch  60/200  Loss=2.6904e-01  Valid Loss=2.3162e-02  LR=1.00e-03  NMSE=-39.1483 dB
# Epoch  70/200  Loss=2.6874e-01  Valid Loss=2.3105e-02  LR=1.00e-03  NMSE=-39.1590 dB
# Epoch  80/200  Loss=2.6837e-01  Valid Loss=2.3056e-02  LR=1.00e-03  NMSE=-39.1682 dB
# Epoch  90/200  Loss=2.6798e-01  Valid Loss=2.3011e-02  LR=1.00e-03  NMSE=-39.1769 dB
# Epoch 100/200  Loss=2.6765e-01  Valid Loss=2.2964e-02  LR=1.00e-03  NMSE=-39.1857 dB
# Epoch 110/200  Loss=2.6729e-01  Valid Loss=2.2920e-02  LR=1.00e-03  NMSE=-39.1941 dB
# Epoch 120/200  Loss=2.6698e-01  Valid Loss=2.2879e-02  LR=1.00e-03  NMSE=-39.2018 dB
# Epoch 130/200  Loss=2.6668e-01  Valid Loss=2.2840e-02  LR=1.00e-03  NMSE=-39.2092 dB
# Epoch 140/200  Loss=2.6642e-01  Valid Loss=2.2804e-02  LR=1.00e-03  NMSE=-39.2160 dB
# Epoch 150/200  Loss=2.6617e-01  Valid Loss=2.2773e-02  LR=1.00e-03  NMSE=-39.2220 dB
# Epoch 160/200  Loss=2.6593e-01  Valid Loss=2.2743e-02  LR=1.00e-03  NMSE=-39.2277 dB
# Epoch 170/200  Loss=2.6572e-01  Valid Loss=2.2716e-02  LR=1.00e-03  NMSE=-39.2327 dB
# Epoch 180/200  Loss=2.6552e-01  Valid Loss=2.2694e-02  LR=1.00e-03  NMSE=-39.2369 dB
# Epoch 190/200  Loss=2.6536e-01  Valid Loss=2.2676e-02  LR=1.00e-03  NMSE=-39.2404 dB
# Epoch 200/200  Loss=2.6521e-01  Valid Loss=2.2661e-02  LR=1.00e-03  NMSE=-39.2433 dB
#
# Best model from epoch 200 with validation loss: 2.2661e-02
# NMSE: -38.8657 dB  (threshold: -39.0258 dB)
#   REJECTED  (delta: +1.1601 dB) — restoring model
#   Reduced fraction to 3.52%
#
# ============================================================
# Step 12  |  fraction = 3.52%
# ============================================================
# Pruning 3.52% of remaining weights...
# Current sparsity: 91.25% of weights are zero
# Retraining for 200 epochs...
# Epoch  10/200  Loss=2.2303e-01  Valid Loss=1.7592e-02  LR=1.00e-03  NMSE=-40.3429 dB
# Epoch  20/200  Loss=2.2167e-01  Valid Loss=2.1512e-02  LR=5.00e-04  NMSE=-39.4692 dB
# Epoch  30/200  Loss=2.2149e-01  Valid Loss=2.1185e-02  LR=2.50e-04  NMSE=-39.5358 dB
# Epoch  40/200  Loss=2.0675e-01  Valid Loss=1.7777e-02  LR=2.50e-04  NMSE=-40.2975 dB
# Epoch  50/200  Loss=2.0274e-01  Valid Loss=1.8634e-02  LR=1.25e-04  NMSE=-40.0930 dB
# Epoch  60/200  Loss=2.0056e-01  Valid Loss=1.7777e-02  LR=6.25e-05  NMSE=-40.2975 dB
# Epoch  70/200  Loss=1.9861e-01  Valid Loss=1.7441e-02  LR=3.13e-05  NMSE=-40.3804 dB
# Epoch  80/200  Loss=1.9777e-01  Valid Loss=1.7399e-02  LR=1.56e-05  NMSE=-40.3909 dB
# Epoch  90/200  Loss=1.9725e-01  Valid Loss=1.7409e-02  LR=7.81e-06  NMSE=-40.3883 dB
# Epoch 100/200  Loss=1.9702e-01  Valid Loss=1.7411e-02  LR=3.91e-06  NMSE=-40.3879 dB
# Epoch 110/200  Loss=1.9686e-01  Valid Loss=1.7414e-02  LR=1.95e-06  NMSE=-40.3870 dB
# Epoch 120/200  Loss=1.9685e-01  Valid Loss=1.7417e-02  LR=9.77e-07  NMSE=-40.3865 dB
# Epoch 130/200  Loss=1.9675e-01  Valid Loss=1.7419e-02  LR=9.77e-07  NMSE=-40.3859 dB
# Epoch 140/200  Loss=1.9670e-01  Valid Loss=1.7421e-02  LR=4.88e-07  NMSE=-40.3855 dB
# Epoch 150/200  Loss=1.9668e-01  Valid Loss=1.7421e-02  LR=2.44e-07  NMSE=-40.3853 dB
# Epoch 160/200  Loss=1.9666e-01  Valid Loss=1.7422e-02  LR=1.22e-07  NMSE=-40.3851 dB
# Epoch 170/200  Loss=1.9666e-01  Valid Loss=1.7423e-02  LR=6.10e-08  NMSE=-40.3850 dB
# Epoch 180/200  Loss=1.9665e-01  Valid Loss=1.7423e-02  LR=3.05e-08  NMSE=-40.3849 dB
# Epoch 190/200  Loss=1.9665e-01  Valid Loss=1.7423e-02  LR=1.53e-08  NMSE=-40.3849 dB
# Epoch 200/200  Loss=1.9665e-01  Valid Loss=1.7423e-02  LR=1.53e-08  NMSE=-40.3849 dB
#
# Best model from epoch 76 with validation loss: 1.7395e-02
# NMSE: -39.7231 dB  (threshold: -39.0258 dB)
#   ACCEPTED  (delta: +0.3027 dB)
#   Plenty of headroom -> increasing next fraction to 5.27%
#
# ============================================================
# Step 13  |  fraction = 5.27%
# ============================================================
# Pruning 5.27% of remaining weights...
# Current sparsity: 91.67% of weights are zero
# Retraining for 200 epochs...
# Epoch  10/200  Loss=2.7134e-01  Valid Loss=2.3557e-02  LR=1.00e-03  NMSE=-39.0749 dB
# Epoch  20/200  Loss=2.7052e-01  Valid Loss=2.3404e-02  LR=1.00e-03  NMSE=-39.1032 dB
# Epoch  30/200  Loss=2.7007e-01  Valid Loss=2.3317e-02  LR=1.00e-03  NMSE=-39.1194 dB
# Epoch  40/200  Loss=2.6963e-01  Valid Loss=2.3251e-02  LR=1.00e-03  NMSE=-39.1316 dB
# Epoch  50/200  Loss=2.6922e-01  Valid Loss=2.3189e-02  LR=1.00e-03  NMSE=-39.1434 dB
# Epoch  60/200  Loss=2.6895e-01  Valid Loss=2.3133e-02  LR=1.00e-03  NMSE=-39.1538 dB
# Epoch  70/200  Loss=2.6858e-01  Valid Loss=2.3084e-02  LR=1.00e-03  NMSE=-39.1630 dB
# Epoch  80/200  Loss=2.6825e-01  Valid Loss=2.3039e-02  LR=1.00e-03  NMSE=-39.1715 dB
# Epoch  90/200  Loss=2.6788e-01  Valid Loss=2.2992e-02  LR=1.00e-03  NMSE=-39.1803 dB
# Epoch 100/200  Loss=2.6754e-01  Valid Loss=2.2948e-02  LR=1.00e-03  NMSE=-39.1887 dB
# Epoch 110/200  Loss=2.6722e-01  Valid Loss=2.2907e-02  LR=1.00e-03  NMSE=-39.1965 dB
# Epoch 120/200  Loss=2.6693e-01  Valid Loss=2.2868e-02  LR=1.00e-03  NMSE=-39.2039 dB
# Epoch 130/200  Loss=2.6665e-01  Valid Loss=2.2831e-02  LR=1.00e-03  NMSE=-39.2110 dB
# Epoch 140/200  Loss=2.6640e-01  Valid Loss=2.2797e-02  LR=1.00e-03  NMSE=-39.2174 dB
# Epoch 150/200  Loss=2.6616e-01  Valid Loss=2.2766e-02  LR=1.00e-03  NMSE=-39.2233 dB
# Epoch 160/200  Loss=2.6593e-01  Valid Loss=2.2737e-02  LR=1.00e-03  NMSE=-39.2288 dB
# Epoch 170/200  Loss=2.6573e-01  Valid Loss=2.2712e-02  LR=1.00e-03  NMSE=-39.2335 dB
# Epoch 180/200  Loss=2.6556e-01  Valid Loss=2.2691e-02  LR=1.00e-03  NMSE=-39.2375 dB
# Epoch 190/200  Loss=2.6539e-01  Valid Loss=2.2673e-02  LR=1.00e-03  NMSE=-39.2410 dB
# Epoch 200/200  Loss=2.6524e-01  Valid Loss=2.2658e-02  LR=1.00e-03  NMSE=-39.2438 dB
#
# Best model from epoch 200 with validation loss: 2.2658e-02
# NMSE: -38.8653 dB  (threshold: -39.0258 dB)
#   REJECTED  (delta: +1.1606 dB) — restoring model
#   Reduced fraction to 2.64%
#
# ============================================================
# Step 14  |  fraction = 2.64%
# ============================================================
# Pruning 2.64% of remaining weights...
# Current sparsity: 91.53% of weights are zero
# Retraining for 200 epochs...
# Epoch  10/200  Loss=2.2347e-01  Valid Loss=1.7692e-02  LR=1.00e-03  NMSE=-40.3184 dB
# Epoch  20/200  Loss=2.2329e-01  Valid Loss=1.7616e-02  LR=1.00e-03  NMSE=-40.3371 dB
# Epoch  30/200  Loss=2.2316e-01  Valid Loss=1.7591e-02  LR=1.00e-03  NMSE=-40.3432 dB
# Epoch  40/200  Loss=2.2310e-01  Valid Loss=1.7578e-02  LR=1.00e-03  NMSE=-40.3465 dB
# Epoch  50/200  Loss=2.2307e-01  Valid Loss=1.7572e-02  LR=1.00e-03  NMSE=-40.3479 dB
# Epoch  60/200  Loss=2.2304e-01  Valid Loss=1.7570e-02  LR=1.00e-03  NMSE=-40.3484 dB
# Epoch  70/200  Loss=2.2303e-01  Valid Loss=1.7562e-02  LR=1.00e-03  NMSE=-40.3503 dB
# Epoch  80/200  Loss=2.2301e-01  Valid Loss=1.7563e-02  LR=1.00e-03  NMSE=-40.3501 dB
# Epoch  90/200  Loss=2.2060e-01  Valid Loss=2.1386e-02  LR=5.00e-04  NMSE=-39.4948 dB
# Epoch 100/200  Loss=2.0587e-01  Valid Loss=1.7748e-02  LR=2.50e-04  NMSE=-40.3046 dB
# Epoch 110/200  Loss=2.0219e-01  Valid Loss=1.8593e-02  LR=1.25e-04  NMSE=-40.1026 dB
# Epoch 120/200  Loss=2.0012e-01  Valid Loss=1.7721e-02  LR=6.25e-05  NMSE=-40.3112 dB
# Epoch 130/200  Loss=1.9824e-01  Valid Loss=1.7398e-02  LR=3.13e-05  NMSE=-40.3911 dB
# Epoch 140/200  Loss=1.9742e-01  Valid Loss=1.7355e-02  LR=1.56e-05  NMSE=-40.4019 dB
# Epoch 150/200  Loss=1.9694e-01  Valid Loss=1.7360e-02  LR=7.81e-06  NMSE=-40.4006 dB
# Epoch 160/200  Loss=1.9691e-01  Valid Loss=1.7360e-02  LR=3.91e-06  NMSE=-40.4005 dB
# Epoch 170/200  Loss=1.9668e-01  Valid Loss=1.7363e-02  LR=3.91e-06  NMSE=-40.3999 dB
# Epoch 180/200  Loss=1.9651e-01  Valid Loss=1.7366e-02  LR=1.95e-06  NMSE=-40.3992 dB
# Epoch 190/200  Loss=1.9641e-01  Valid Loss=1.7368e-02  LR=9.77e-07  NMSE=-40.3986 dB
# Epoch 200/200  Loss=1.9636e-01  Valid Loss=1.7370e-02  LR=4.88e-07  NMSE=-40.3982 dB
#
# Best model from epoch 149 with validation loss: 1.7352e-02
# NMSE: -39.7314 dB  (threshold: -39.0258 dB)
#   ACCEPTED  (delta: +0.2945 dB)
#   Plenty of headroom -> increasing next fraction to 3.96%
#
# ============================================================
# Step 15  |  fraction = 3.96%
# ============================================================
# Pruning 3.96% of remaining weights...
# Current sparsity: 91.81% of weights are zero
# Retraining for 200 epochs...
# Epoch  10/200  Loss=2.7060e-01  Valid Loss=2.3537e-02  LR=1.00e-03  NMSE=-39.0786 dB
# Epoch  20/200  Loss=2.7034e-01  Valid Loss=2.3456e-02  LR=1.00e-03  NMSE=-39.0936 dB
# Epoch  30/200  Loss=2.6998e-01  Valid Loss=2.3392e-02  LR=1.00e-03  NMSE=-39.1055 dB
# Epoch  40/200  Loss=2.6958e-01  Valid Loss=2.3334e-02  LR=1.00e-03  NMSE=-39.1162 dB
# Epoch  50/200  Loss=2.6919e-01  Valid Loss=2.3280e-02  LR=1.00e-03  NMSE=-39.1263 dB
# Epoch  60/200  Loss=2.6881e-01  Valid Loss=2.3228e-02  LR=1.00e-03  NMSE=-39.1360 dB
# Epoch  70/200  Loss=2.6843e-01  Valid Loss=2.3178e-02  LR=1.00e-03  NMSE=-39.1454 dB
# Epoch  80/200  Loss=2.6806e-01  Valid Loss=2.3129e-02  LR=1.00e-03  NMSE=-39.1545 dB
# Epoch  90/200  Loss=2.6771e-01  Valid Loss=2.3082e-02  LR=1.00e-03  NMSE=-39.1633 dB
# Epoch 100/200  Loss=2.6737e-01  Valid Loss=2.3036e-02  LR=1.00e-03  NMSE=-39.1720 dB
# Epoch 110/200  Loss=2.6707e-01  Valid Loss=2.2993e-02  LR=1.00e-03  NMSE=-39.1802 dB
# Epoch 120/200  Loss=2.6677e-01  Valid Loss=2.2953e-02  LR=1.00e-03  NMSE=-39.1878 dB
# Epoch 130/200  Loss=2.6648e-01  Valid Loss=2.2913e-02  LR=1.00e-03  NMSE=-39.1952 dB
# Epoch 140/200  Loss=2.6621e-01  Valid Loss=2.2877e-02  LR=1.00e-03  NMSE=-39.2021 dB
# Epoch 150/200  Loss=2.6597e-01  Valid Loss=2.2846e-02  LR=1.00e-03  NMSE=-39.2079 dB
# Epoch 160/200  Loss=2.6574e-01  Valid Loss=2.2818e-02  LR=1.00e-03  NMSE=-39.2134 dB
# Epoch 170/200  Loss=2.6554e-01  Valid Loss=2.2793e-02  LR=1.00e-03  NMSE=-39.2181 dB
# Epoch 180/200  Loss=2.6535e-01  Valid Loss=2.2771e-02  LR=1.00e-03  NMSE=-39.2224 dB
# Epoch 190/200  Loss=2.6517e-01  Valid Loss=2.2751e-02  LR=1.00e-03  NMSE=-39.2261 dB
# Epoch 200/200  Loss=2.6500e-01  Valid Loss=2.2735e-02  LR=1.00e-03  NMSE=-39.2292 dB
#
# Best model from epoch 200 with validation loss: 2.2735e-02
# NMSE: -38.8597 dB  (threshold: -39.0258 dB)
#   REJECTED  (delta: +1.1661 dB) — restoring model
#   Reduced fraction to 1.98%
#
# ============================================================
# Step 16  |  fraction = 1.98%
# ============================================================
# Pruning 1.98% of remaining weights...
# Current sparsity: 91.67% of weights are zero
# Retraining for 200 epochs...
# Epoch  10/200  Loss=2.7090e-01  Valid Loss=2.3467e-02  LR=1.00e-03  NMSE=-39.0916 dB
# Epoch  20/200  Loss=2.7044e-01  Valid Loss=2.3389e-02  LR=1.00e-03  NMSE=-39.1060 dB
# Epoch  30/200  Loss=2.7006e-01  Valid Loss=2.3325e-02  LR=1.00e-03  NMSE=-39.1180 dB
# Epoch  40/200  Loss=2.6969e-01  Valid Loss=2.3268e-02  LR=1.00e-03  NMSE=-39.1285 dB
# Epoch  50/200  Loss=2.6933e-01  Valid Loss=2.3216e-02  LR=1.00e-03  NMSE=-39.1383 dB
# Epoch  60/200  Loss=2.6897e-01  Valid Loss=2.3165e-02  LR=1.00e-03  NMSE=-39.1478 dB
# Epoch  70/200  Loss=2.6862e-01  Valid Loss=2.3116e-02  LR=1.00e-03  NMSE=-39.1570 dB
# Epoch  80/200  Loss=2.6827e-01  Valid Loss=2.3068e-02  LR=1.00e-03  NMSE=-39.1660 dB
# Epoch  90/200  Loss=2.6794e-01  Valid Loss=2.3023e-02  LR=1.00e-03  NMSE=-39.1746 dB
# Epoch 100/200  Loss=2.6762e-01  Valid Loss=2.2979e-02  LR=1.00e-03  NMSE=-39.1828 dB
# Epoch 110/200  Loss=2.6734e-01  Valid Loss=2.2936e-02  LR=1.00e-03  NMSE=-39.1909 dB
# Epoch 120/200  Loss=2.6705e-01  Valid Loss=2.2897e-02  LR=1.00e-03  NMSE=-39.1983 dB
# Epoch 130/200  Loss=2.6678e-01  Valid Loss=2.2860e-02  LR=1.00e-03  NMSE=-39.2054 dB
# Epoch 140/200  Loss=2.6652e-01  Valid Loss=2.2824e-02  LR=1.00e-03  NMSE=-39.2123 dB
# Epoch 150/200  Loss=2.6628e-01  Valid Loss=2.2791e-02  LR=1.00e-03  NMSE=-39.2185 dB
# Epoch 160/200  Loss=2.6606e-01  Valid Loss=2.2762e-02  LR=1.00e-03  NMSE=-39.2241 dB
# Epoch 170/200  Loss=2.6587e-01  Valid Loss=2.2736e-02  LR=1.00e-03  NMSE=-39.2289 dB
# Epoch 180/200  Loss=2.6567e-01  Valid Loss=2.2714e-02  LR=1.00e-03  NMSE=-39.2333 dB
# Epoch 190/200  Loss=2.6550e-01  Valid Loss=2.2693e-02  LR=1.00e-03  NMSE=-39.2372 dB
# Epoch 200/200  Loss=2.6533e-01  Valid Loss=2.2676e-02  LR=1.00e-03  NMSE=-39.2405 dB
#
# Best model from epoch 200 with validation loss: 2.2676e-02
# NMSE: -38.8605 dB  (threshold: -39.0258 dB)
#   REJECTED  (delta: +1.1653 dB) — restoring model
#   Cannot reduce fraction below minimum (1.00%) — stopping
#
# ============================================================
# Adaptive pruning finished  (8 accepted step(s))
# Final NMSE     : -39.7314 dB  (baseline: -40.0258 dB, delta: +0.2945 dB)
# Final sparsity : 91.53% of weights zeroed
# ============================================================

# %%
# CHeck how many parameters were in the original model

print(f"Original PNTDNN one layer forward model parameters: {PNTDNN_one_layer_forward_nn.get_num_params()*(1-0.8972)}")
# Out:
# Original PNTDNN one layer forward model parameters: 74.016

# %%
from sparseDPD import AdaptivePruningExperiment

adaptive_pruning_experiment_PJGANET = AdaptivePruningExperiment(
    nn_model=PGJANET_forward_nn,
    retrain_epochs= 35,
    training_dataset = simpleDataManager.training_dataset,
    valid_dataset = simpleDataManager.validation_dataset,
    test_dataset = simpleDataManager.test_dataset,
    nmse_tolerance = 1,
    initial_prune_fraction=0.5,
    min_prune_fraction=0.01,
    max_prune_fraction=0.5
)

adaptive_pruning_experiment_PJGANET.run()
# Out:
# Baseline NMSE          : -40.9721 dB
# Tolerance              : +1.00 dB
# NMSE must stay below   : -39.9721 dB
# Initial prune fraction : 50.0%
# Min prune fraction     : 1.0%
# Max prune fraction     : 50.0%
#
# ============================================================
# Step 1  |  fraction = 50.00%
# ============================================================
# Pruning 50.00% of remaining weights...
# Current sparsity: 50.00% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.5731e-01  Valid Loss=1.5849e-02  LR=1.00e-03  NMSE=-40.7231 dB
# Epoch  20/35  Loss=1.4227e-01  Valid Loss=1.5727e-02  LR=1.00e-03  NMSE=-40.7565 dB
# Epoch  30/35  Loss=1.4105e-01  Valid Loss=1.1500e-02  LR=1.00e-03  NMSE=-42.1162 dB
#
# Best model from epoch 35 with validation loss: 1.1415e-02
# NMSE: -41.1582 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: -0.1860 dB)
#   Plenty of headroom -> increasing next fraction to 50.00%
#
# ============================================================
# Step 2  |  fraction = 50.00%
# ============================================================
# Pruning 50.00% of remaining weights...
# Current sparsity: 75.00% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=3.3666e-01  Valid Loss=3.7208e-02  LR=1.00e-03  NMSE=-37.0166 dB
# Epoch  20/35  Loss=2.2217e-01  Valid Loss=2.2935e-02  LR=1.00e-03  NMSE=-39.1180 dB
# Epoch  30/35  Loss=1.8549e-01  Valid Loss=1.5523e-02  LR=1.00e-03  NMSE=-40.8132 dB
#
# Best model from epoch 30 with validation loss: 1.5523e-02
# NMSE: -39.9180 dB  (threshold: -39.9721 dB)
#   REJECTED  (delta: +1.0541 dB) — restoring model
#   Reduced fraction to 25.00%
#
# ============================================================
# Step 3  |  fraction = 25.00%
# ============================================================
# Pruning 25.00% of remaining weights...
# Current sparsity: 62.50% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.3812e-01  Valid Loss=1.3092e-02  LR=1.00e-03  NMSE=-41.5530 dB
# Epoch  20/35  Loss=1.3628e-01  Valid Loss=1.1567e-02  LR=1.00e-03  NMSE=-42.0909 dB
# Epoch  30/35  Loss=1.3573e-01  Valid Loss=1.2492e-02  LR=1.00e-03  NMSE=-41.7566 dB
#
# Best model from epoch 25 with validation loss: 1.1396e-02
# NMSE: -41.2124 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: -0.2403 dB)
#   Plenty of headroom -> increasing next fraction to 37.50%
#
# ============================================================
# Step 4  |  fraction = 37.50%
# ============================================================
# Pruning 37.50% of remaining weights...
# Current sparsity: 76.56% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=4.2535e-01  Valid Loss=3.4475e-02  LR=1.00e-03  NMSE=-37.3480 dB
# Epoch  20/35  Loss=2.4576e-01  Valid Loss=2.7240e-02  LR=1.00e-03  NMSE=-38.3710 dB
# Epoch  30/35  Loss=2.0046e-01  Valid Loss=1.5385e-02  LR=1.00e-03  NMSE=-40.8521 dB
#
# Best model from epoch 30 with validation loss: 1.5385e-02
# NMSE: -39.8337 dB  (threshold: -39.9721 dB)
#   REJECTED  (delta: +1.1384 dB) — restoring model
#   Reduced fraction to 18.75%
#
# ============================================================
# Step 5  |  fraction = 18.75%
# ============================================================
# Pruning 18.75% of remaining weights...
# Current sparsity: 69.53% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.6435e-01  Valid Loss=1.5311e-02  LR=1.00e-03  NMSE=-40.8729 dB
# Epoch  20/35  Loss=1.4334e-01  Valid Loss=1.6055e-02  LR=1.00e-03  NMSE=-40.6671 dB
# Epoch  30/35  Loss=1.4283e-01  Valid Loss=1.3730e-02  LR=5.00e-04  NMSE=-41.3464 dB
#
# Best model from epoch 34 with validation loss: 1.0876e-02
# NMSE: -41.4284 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: -0.4563 dB)
#   Plenty of headroom -> increasing next fraction to 28.12%
#
# ============================================================
# Step 6  |  fraction = 28.12%
# ============================================================
# Pruning 28.12% of remaining weights...
# Current sparsity: 78.10% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=4.2167e-01  Valid Loss=3.5142e-02  LR=1.00e-03  NMSE=-37.2648 dB
# Epoch  20/35  Loss=2.6671e-01  Valid Loss=2.3287e-02  LR=1.00e-03  NMSE=-39.0518 dB
# Epoch  30/35  Loss=2.3293e-01  Valid Loss=2.0969e-02  LR=1.00e-03  NMSE=-39.5072 dB
#
# Best model from epoch 35 with validation loss: 1.6202e-02
# NMSE: -39.4923 dB  (threshold: -39.9721 dB)
#   REJECTED  (delta: +1.4799 dB) — restoring model
#   Reduced fraction to 14.06%
#
# ============================================================
# Step 7  |  fraction = 14.06%
# ============================================================
# Pruning 14.06% of remaining weights...
# Current sparsity: 73.81% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.3759e-01  Valid Loss=1.5779e-02  LR=1.00e-03  NMSE=-40.7423 dB
# Epoch  20/35  Loss=1.3428e-01  Valid Loss=1.2066e-02  LR=1.00e-03  NMSE=-41.9074 dB
# Epoch  30/35  Loss=1.3385e-01  Valid Loss=1.1435e-02  LR=1.00e-03  NMSE=-42.1408 dB
#
# Best model from epoch 22 with validation loss: 1.0864e-02
# NMSE: -41.4063 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: -0.4342 dB)
#   Plenty of headroom -> increasing next fraction to 21.09%
#
# ============================================================
# Step 8  |  fraction = 21.09%
# ============================================================
# Pruning 21.09% of remaining weights...
# Current sparsity: 79.34% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=4.7940e-01  Valid Loss=4.2337e-02  LR=1.00e-03  NMSE=-36.4558 dB
# Epoch  20/35  Loss=2.7957e-01  Valid Loss=2.4380e-02  LR=1.00e-03  NMSE=-38.8526 dB
# Epoch  30/35  Loss=2.3106e-01  Valid Loss=2.1307e-02  LR=1.00e-03  NMSE=-39.4379 dB
#
# Best model from epoch 33 with validation loss: 1.7385e-02
# NMSE: -39.4714 dB  (threshold: -39.9721 dB)
#   REJECTED  (delta: +1.5008 dB) — restoring model
#   Reduced fraction to 10.55%
#
# ============================================================
# Step 9  |  fraction = 10.55%
# ============================================================
# Pruning 10.55% of remaining weights...
# Current sparsity: 76.57% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.5179e-01  Valid Loss=1.8482e-02  LR=1.00e-03  NMSE=-40.0556 dB
# Epoch  20/35  Loss=1.4281e-01  Valid Loss=1.4339e-02  LR=1.00e-03  NMSE=-41.1579 dB
# Epoch  30/35  Loss=1.3956e-01  Valid Loss=1.2612e-02  LR=1.00e-03  NMSE=-41.7151 dB
#
# Best model from epoch 34 with validation loss: 1.1245e-02
# NMSE: -41.1836 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: -0.2114 dB)
#   Plenty of headroom -> increasing next fraction to 15.82%
#
# ============================================================
# Step 10  |  fraction = 15.82%
# ============================================================
# Pruning 15.82% of remaining weights...
# Current sparsity: 80.28% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.8897e-01  Valid Loss=1.6129e-02  LR=1.00e-03  NMSE=-40.6471 dB
# Epoch  20/35  Loss=1.6121e-01  Valid Loss=1.7977e-02  LR=1.00e-03  NMSE=-40.1760 dB
# Epoch  30/35  Loss=1.4870e-01  Valid Loss=1.6926e-02  LR=1.00e-03  NMSE=-40.4374 dB
#
# Best model from epoch 33 with validation loss: 1.2113e-02
# NMSE: -41.1797 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: -0.2076 dB)
#   Plenty of headroom -> increasing next fraction to 23.73%
#
# ============================================================
# Step 11  |  fraction = 23.73%
# ============================================================
# Pruning 23.73% of remaining weights...
# Current sparsity: 84.96% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=2.2231e+00  Valid Loss=1.9346e-01  LR=1.00e-03  NMSE=-29.8572 dB
# Epoch  20/35  Loss=8.7720e-01  Valid Loss=8.7260e-02  LR=1.00e-03  NMSE=-33.3149 dB
# Epoch  30/35  Loss=5.5904e-01  Valid Loss=5.2859e-02  LR=1.00e-03  NMSE=-35.4919 dB
#
# Best model from epoch 34 with validation loss: 4.0252e-02
# NMSE: -36.0593 dB  (threshold: -39.9721 dB)
#   REJECTED  (delta: +4.9128 dB) — restoring model
#   Reduced fraction to 11.87%
#
# ============================================================
# Step 12  |  fraction = 11.87%
# ============================================================
# Pruning 11.87% of remaining weights...
# Current sparsity: 82.61% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.5767e-01  Valid Loss=1.2935e-02  LR=1.00e-03  NMSE=-41.6055 dB
# Epoch  20/35  Loss=1.5005e-01  Valid Loss=1.2020e-02  LR=1.00e-03  NMSE=-41.9239 dB
# Epoch  30/35  Loss=1.4515e-01  Valid Loss=1.2263e-02  LR=1.00e-03  NMSE=-41.8371 dB
#
# Best model from epoch 20 with validation loss: 1.2020e-02
# NMSE: -41.1763 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: -0.2042 dB)
#   Plenty of headroom -> increasing next fraction to 17.80%
#
# ============================================================
# Step 13  |  fraction = 17.80%
# ============================================================
# Pruning 17.80% of remaining weights...
# Current sparsity: 85.71% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=2.4528e+00  Valid Loss=2.1925e-01  LR=1.00e-03  NMSE=-29.3136 dB
# Epoch  20/35  Loss=9.6612e-01  Valid Loss=9.9178e-02  LR=1.00e-03  NMSE=-32.7589 dB
# Epoch  30/35  Loss=6.2970e-01  Valid Loss=7.2015e-02  LR=1.00e-03  NMSE=-34.1488 dB
#
# Best model from epoch 33 with validation loss: 4.7820e-02
# NMSE: -35.3849 dB  (threshold: -39.9721 dB)
#   REJECTED  (delta: +5.5873 dB) — restoring model
#   Reduced fraction to 8.90%
#
# ============================================================
# Step 14  |  fraction = 8.90%
# ============================================================
# Pruning 8.90% of remaining weights...
# Current sparsity: 84.16% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=3.1770e-01  Valid Loss=2.4428e-02  LR=1.00e-03  NMSE=-38.8442 dB
# Epoch  20/35  Loss=2.1222e-01  Valid Loss=3.0191e-02  LR=1.00e-03  NMSE=-37.9243 dB
# Epoch  30/35  Loss=1.9236e-01  Valid Loss=1.9915e-02  LR=1.00e-03  NMSE=-39.7312 dB
#
# Best model from epoch 32 with validation loss: 1.4646e-02
# NMSE: -40.1970 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: +0.7751 dB)
#   Close to NMSE limit -> reducing next fraction to 6.67%
#
# ============================================================
# Step 15  |  fraction = 6.67%
# ============================================================
# Pruning 6.67% of remaining weights...
# Current sparsity: 85.21% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.7589e-01  Valid Loss=1.5286e-02  LR=1.00e-03  NMSE=-40.8802 dB
# Epoch  20/35  Loss=1.6579e-01  Valid Loss=1.7159e-02  LR=1.00e-03  NMSE=-40.3782 dB
# Epoch  30/35  Loss=1.5064e-01  Valid Loss=1.1988e-02  LR=5.00e-04  NMSE=-41.9355 dB
#
# Best model from epoch 30 with validation loss: 1.1988e-02
# NMSE: -40.8859 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: +0.0863 dB)
#   Plenty of headroom -> increasing next fraction to 10.01%
#
# ============================================================
# Step 16  |  fraction = 10.01%
# ============================================================
# Pruning 10.01% of remaining weights...
# Current sparsity: 86.69% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.6987e-01  Valid Loss=1.7016e-02  LR=1.00e-03  NMSE=-40.4144 dB
# Epoch  20/35  Loss=1.6081e-01  Valid Loss=1.2296e-02  LR=1.00e-03  NMSE=-41.8256 dB
# Epoch  30/35  Loss=1.5796e-01  Valid Loss=1.2691e-02  LR=1.00e-03  NMSE=-41.6880 dB
#
# Best model from epoch 34 with validation loss: 1.1813e-02
# NMSE: -40.8857 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: +0.0864 dB)
#   Plenty of headroom -> increasing next fraction to 15.02%
#
# ============================================================
# Step 17  |  fraction = 15.02%
# ============================================================
# Pruning 15.02% of remaining weights...
# Current sparsity: 88.69% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=3.8238e-01  Valid Loss=4.4346e-02  LR=1.00e-03  NMSE=-36.2545 dB
# Epoch  20/35  Loss=2.4395e-01  Valid Loss=2.0599e-02  LR=1.00e-03  NMSE=-39.5847 dB
# Epoch  30/35  Loss=2.0875e-01  Valid Loss=1.8077e-02  LR=1.00e-03  NMSE=-40.1518 dB
#
# Best model from epoch 33 with validation loss: 1.5279e-02
# NMSE: -40.0609 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: +0.9112 dB)
#   Close to NMSE limit -> reducing next fraction to 11.26%
#
# ============================================================
# Step 18  |  fraction = 11.26%
# ============================================================
# Pruning 11.26% of remaining weights...
# Current sparsity: 89.96% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=2.0955e-01  Valid Loss=1.5728e-02  LR=1.00e-03  NMSE=-40.7563 dB
# Epoch  20/35  Loss=1.9371e-01  Valid Loss=2.1369e-02  LR=1.00e-03  NMSE=-39.4252 dB
# Epoch  30/35  Loss=1.7041e-01  Valid Loss=1.5328e-02  LR=5.00e-04  NMSE=-40.8681 dB
#
# Best model from epoch 31 with validation loss: 1.4105e-02
# NMSE: -40.2598 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: +0.7124 dB)
#   Close to NMSE limit -> reducing next fraction to 8.45%
#
# ============================================================
# Step 19  |  fraction = 8.45%
# ============================================================
# Pruning 8.45% of remaining weights...
# Current sparsity: 90.80% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=2.4469e+00  Valid Loss=1.9237e-01  LR=1.00e-03  NMSE=-29.8816 dB
# Epoch  20/35  Loss=1.1329e+00  Valid Loss=1.0053e-01  LR=1.00e-03  NMSE=-32.7002 dB
# Epoch  30/35  Loss=7.9099e-01  Valid Loss=6.7160e-02  LR=1.00e-03  NMSE=-34.4520 dB
#
# Best model from epoch 34 with validation loss: 5.3552e-02
# NMSE: -34.5984 dB  (threshold: -39.9721 dB)
#   REJECTED  (delta: +6.3738 dB) — restoring model
#   Reduced fraction to 4.22%
#
# ============================================================
# Step 20  |  fraction = 4.22%
# ============================================================
# Pruning 4.22% of remaining weights...
# Current sparsity: 90.38% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.8711e-01  Valid Loss=1.5817e-02  LR=1.00e-03  NMSE=-40.7318 dB
# Epoch  20/35  Loss=1.5772e-01  Valid Loss=1.4036e-02  LR=5.00e-04  NMSE=-41.2505 dB
# Epoch  30/35  Loss=1.4880e-01  Valid Loss=1.4142e-02  LR=2.50e-04  NMSE=-41.2178 dB
#
# Best model from epoch 34 with validation loss: 1.2812e-02
# NMSE: -40.6694 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: +0.3027 dB)
#   Plenty of headroom -> increasing next fraction to 6.34%
#
# ============================================================
# Step 21  |  fraction = 6.34%
# ============================================================
# Pruning 6.34% of remaining weights...
# Current sparsity: 90.99% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=2.5178e+00  Valid Loss=1.9456e-01  LR=1.00e-03  NMSE=-29.8325 dB
# Epoch  20/35  Loss=1.1094e+00  Valid Loss=1.0108e-01  LR=1.00e-03  NMSE=-32.6766 dB
# Epoch  30/35  Loss=8.2285e-01  Valid Loss=5.4245e-02  LR=1.00e-03  NMSE=-35.3795 dB
#
# Best model from epoch 32 with validation loss: 5.2720e-02
# NMSE: -34.6436 dB  (threshold: -39.9721 dB)
#   REJECTED  (delta: +6.3285 dB) — restoring model
#   Reduced fraction to 3.17%
#
# ============================================================
# Step 22  |  fraction = 3.17%
# ============================================================
# Pruning 3.17% of remaining weights...
# Current sparsity: 90.68% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.8725e-01  Valid Loss=1.7959e-02  LR=1.00e-03  NMSE=-40.1803 dB
# Epoch  20/35  Loss=1.8407e-01  Valid Loss=1.8700e-02  LR=1.00e-03  NMSE=-40.0046 dB
# Epoch  30/35  Loss=1.7341e-01  Valid Loss=1.5346e-02  LR=1.00e-03  NMSE=-40.8631 dB
#
# Best model from epoch 29 with validation loss: 1.4250e-02
# NMSE: -40.5628 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: +0.4094 dB)
#   Moderate headroom -> keeping next fraction at 3.17%
#
# ============================================================
# Step 23  |  fraction = 3.17%
# ============================================================
# Pruning 3.17% of remaining weights...
# Current sparsity: 90.98% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.7984e-01  Valid Loss=1.8729e-02  LR=1.00e-03  NMSE=-39.9978 dB
# Epoch  20/35  Loss=1.7048e-01  Valid Loss=1.7315e-02  LR=5.00e-04  NMSE=-40.3388 dB
# Epoch  30/35  Loss=1.5160e-01  Valid Loss=1.7639e-02  LR=5.00e-04  NMSE=-40.2582 dB
#
# Best model from epoch 33 with validation loss: 1.2310e-02
# NMSE: -40.9230 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: +0.0492 dB)
#   Plenty of headroom -> increasing next fraction to 4.75%
#
# ============================================================
# Step 24  |  fraction = 4.75%
# ============================================================
# Pruning 4.75% of remaining weights...
# Current sparsity: 91.40% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=2.4895e+00  Valid Loss=1.9117e-01  LR=1.00e-03  NMSE=-29.9089 dB
# Epoch  20/35  Loss=1.0246e+00  Valid Loss=9.4596e-02  LR=1.00e-03  NMSE=-32.9643 dB
# Epoch  30/35  Loss=7.1049e-01  Valid Loss=6.7904e-02  LR=1.00e-03  NMSE=-34.4041 dB
#
# Best model from epoch 32 with validation loss: 5.0570e-02
# NMSE: -34.9206 dB  (threshold: -39.9721 dB)
#   REJECTED  (delta: +6.0516 dB) — restoring model
#   Reduced fraction to 2.38%
#
# ============================================================
# Step 25  |  fraction = 2.38%
# ============================================================
# Pruning 2.38% of remaining weights...
# Current sparsity: 91.20% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.7975e-01  Valid Loss=1.5902e-02  LR=1.00e-03  NMSE=-40.7084 dB
# Epoch  20/35  Loss=1.7341e-01  Valid Loss=1.3906e-02  LR=1.00e-03  NMSE=-41.2910 dB
# Epoch  30/35  Loss=1.6842e-01  Valid Loss=1.4521e-02  LR=1.00e-03  NMSE=-41.1032 dB
#
# Best model from epoch 24 with validation loss: 1.3294e-02
# NMSE: -40.6883 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: +0.2838 dB)
#   Plenty of headroom -> increasing next fraction to 3.56%
#
# ============================================================
# Step 26  |  fraction = 3.56%
# ============================================================
# Pruning 3.56% of remaining weights...
# Current sparsity: 91.51% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.1515e+00  Valid Loss=1.1240e-01  LR=1.00e-03  NMSE=-32.2153 dB
# Epoch  20/35  Loss=5.8840e-01  Valid Loss=4.6763e-02  LR=1.00e-03  NMSE=-36.0240 dB
# Epoch  30/35  Loss=4.5111e-01  Valid Loss=3.9504e-02  LR=1.00e-03  NMSE=-36.7566 dB
#
# Best model from epoch 35 with validation loss: 3.0625e-02
# NMSE: -36.9117 dB  (threshold: -39.9721 dB)
#   REJECTED  (delta: +4.0604 dB) — restoring model
#   Reduced fraction to 1.78%
#
# ============================================================
# Step 27  |  fraction = 1.78%
# ============================================================
# Pruning 1.78% of remaining weights...
# Current sparsity: 91.35% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.6817e-01  Valid Loss=1.4218e-02  LR=1.00e-03  NMSE=-41.1947 dB
# Epoch  20/35  Loss=1.5028e-01  Valid Loss=1.3968e-02  LR=5.00e-04  NMSE=-41.2716 dB
# Epoch  30/35  Loss=1.4576e-01  Valid Loss=1.3031e-02  LR=5.00e-04  NMSE=-41.5733 dB
#
# Best model from epoch 35 with validation loss: 1.1869e-02
# NMSE: -41.0150 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: -0.0429 dB)
#   Plenty of headroom -> increasing next fraction to 2.67%
#
# ============================================================
# Step 28  |  fraction = 2.67%
# ============================================================
# Pruning 2.67% of remaining weights...
# Current sparsity: 91.58% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.6497e-01  Valid Loss=1.4882e-02  LR=1.00e-03  NMSE=-40.9964 dB
# Epoch  20/35  Loss=1.4939e-01  Valid Loss=1.2157e-02  LR=5.00e-04  NMSE=-41.8750 dB
# Epoch  30/35  Loss=1.4693e-01  Valid Loss=1.3310e-02  LR=5.00e-04  NMSE=-41.4812 dB
#
# Best model from epoch 26 with validation loss: 1.1979e-02
# NMSE: -40.8787 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: +0.0934 dB)
#   Plenty of headroom -> increasing next fraction to 4.01%
#
# ============================================================
# Step 29  |  fraction = 4.01%
# ============================================================
# Pruning 4.01% of remaining weights...
# Current sparsity: 91.92% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=7.3934e+00  Valid Loss=6.1837e-01  LR=1.00e-03  NMSE=-24.8105 dB
# Epoch  20/35  Loss=3.7495e+00  Valid Loss=3.2569e-01  LR=1.00e-03  NMSE=-27.5949 dB
# Epoch  30/35  Loss=2.7509e+00  Valid Loss=3.0324e-01  LR=1.00e-03  NMSE=-27.9051 dB
#
# Best model from epoch 33 with validation loss: 2.2606e-01
# NMSE: -28.7800 dB  (threshold: -39.9721 dB)
#   REJECTED  (delta: +12.1921 dB) — restoring model
#   Reduced fraction to 2.00%
#
# ============================================================
# Step 30  |  fraction = 2.00%
# ============================================================
# Pruning 2.00% of remaining weights...
# Current sparsity: 91.74% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.1369e+00  Valid Loss=9.6563e-02  LR=1.00e-03  NMSE=-32.8750 dB
# Epoch  20/35  Loss=5.9234e-01  Valid Loss=5.2084e-02  LR=1.00e-03  NMSE=-35.5560 dB
# Epoch  30/35  Loss=4.4586e-01  Valid Loss=6.3799e-02  LR=1.00e-03  NMSE=-34.6749 dB
#
# Best model from epoch 34 with validation loss: 3.0354e-02
# NMSE: -36.7051 dB  (threshold: -39.9721 dB)
#   REJECTED  (delta: +4.2670 dB) — restoring model
#   Reduced fraction to 1.00%
#
# ============================================================
# Step 31  |  fraction = 1.00%
# ============================================================
# Pruning 1.00% of remaining weights...
# Current sparsity: 91.66% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.6145e-01  Valid Loss=1.1817e-02  LR=1.00e-03  NMSE=-41.9980 dB
# Epoch  20/35  Loss=1.6610e-01  Valid Loss=1.5623e-02  LR=1.00e-03  NMSE=-40.7855 dB
# Epoch  30/35  Loss=1.4383e-01  Valid Loss=1.1700e-02  LR=5.00e-04  NMSE=-42.0412 dB
#
# Best model from epoch 30 with validation loss: 1.1700e-02
# NMSE: -41.1059 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: -0.1337 dB)
#   Plenty of headroom -> increasing next fraction to 1.50%
#
# ============================================================
# Step 32  |  fraction = 1.50%
# ============================================================
# Pruning 1.50% of remaining weights...
# Current sparsity: 91.78% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.6687e-01  Valid Loss=1.5272e-02  LR=1.00e-03  NMSE=-40.8842 dB
# Epoch  20/35  Loss=1.6760e-01  Valid Loss=1.3623e-02  LR=1.00e-03  NMSE=-41.3803 dB
# Epoch  30/35  Loss=1.4213e-01  Valid Loss=1.3755e-02  LR=5.00e-04  NMSE=-41.3384 dB
#
# Best model from epoch 31 with validation loss: 1.1718e-02
# NMSE: -40.9646 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: +0.0075 dB)
#   Plenty of headroom -> increasing next fraction to 2.26%
#
# ============================================================
# Step 33  |  fraction = 2.26%
# ============================================================
# Pruning 2.26% of remaining weights...
# Current sparsity: 91.98% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.1193e+00  Valid Loss=9.9208e-02  LR=1.00e-03  NMSE=-32.7576 dB
# Epoch  20/35  Loss=5.0555e-01  Valid Loss=4.0071e-02  LR=1.00e-03  NMSE=-36.6948 dB
# Epoch  30/35  Loss=3.8213e-01  Valid Loss=3.0250e-02  LR=1.00e-03  NMSE=-37.9158 dB
#
# Best model from epoch 35 with validation loss: 2.6733e-02
# NMSE: -37.5789 dB  (threshold: -39.9721 dB)
#   REJECTED  (delta: +3.3932 dB) — restoring model
#   Reduced fraction to 1.13%
#
# ============================================================
# Step 34  |  fraction = 1.13%
# ============================================================
# Pruning 1.13% of remaining weights...
# Current sparsity: 91.88% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=1.5927e-01  Valid Loss=1.2936e-02  LR=1.00e-03  NMSE=-41.6051 dB
# Epoch  20/35  Loss=1.6098e-01  Valid Loss=1.3655e-02  LR=1.00e-03  NMSE=-41.3702 dB
# Epoch  30/35  Loss=1.4177e-01  Valid Loss=1.2626e-02  LR=5.00e-04  NMSE=-41.7105 dB
#
# Best model from epoch 28 with validation loss: 1.1321e-02
# NMSE: -41.2730 dB  (threshold: -39.9721 dB)
#   ACCEPTED  (delta: -0.3008 dB)
#   Plenty of headroom -> increasing next fraction to 1.69%
#
# ============================================================
# Step 35  |  fraction = 1.69%
# ============================================================
# Pruning 1.69% of remaining weights...
# Current sparsity: 92.02% of weights are zero
# Retraining for 35 epochs...
# Epoch  10/35  Loss=9.6618e-01  Valid Loss=7.9236e-02  LR=1.00e-03  NMSE=-33.7338 dB
# Epoch  20/35  Loss=4.2847e-01  Valid Loss=3.8470e-02  LR=1.00e-03  NMSE=-36.8718 dB
# Epoch  30/35  Loss=3.2167e-01  Valid Loss=3.2389e-02  LR=1.00e-03  NMSE=-37.6190 dB
#
# Best model from epoch 35 with validation loss: 2.1170e-02
# NMSE: -38.4516 dB  (threshold: -39.9721 dB)
#   REJECTED  (delta: +2.5205 dB) — restoring model
#   Cannot reduce fraction below minimum (1.00%) — stopping
#
# ============================================================
# Adaptive pruning finished  (21 accepted step(s))
# Final NMSE     : -41.2730 dB  (baseline: -40.9721 dB, delta: -0.3008 dB)
# Final sparsity : 91.88% of weights zeroed
# ============================================================
