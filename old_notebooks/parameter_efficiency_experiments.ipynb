# %% [markdown]
# # Neural Network Parameter Efficiency for Digital Pre-Distortion
#
# This notebook compares different network architectures and pruning methods to find the optimal balance between model performance and parameter efficiency.
#
# **Key Focus**: Absolute parameter count (not relative pruning percentages)
#
# ## Experimental Setup
#
# ### Network Architectures:
# - **OneLayerNetwork**: 12 hidden units (~900 parameters)
# - **ThreeLayerNetwork**: 30→15 hidden units (~2,700 parameters)
# - **MultiLayerNetwork**: 64→32→32→32→32→16→8 (~7,000+ parameters)
#
# ### Pruning Methods:
# - **Linear/Magnitude Pruning**: Removes individual weights based on L1 magnitude
# - **Node Pruning**: Removes entire neurons based on their importance
#
# ### Dataset:
# - PA_IO.mat (UCD dataset)
# - Training: 19,000 points
# - Validation: 1,000 points
# - Test: 2,000 points

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from collections import defaultdict

from sparseDPD import Volterra
from sparseDPD import Dataset
from sparseDPD import Datapath
from sparseDPD import DataManager
from sparseDPD import LinearExperiment
from sparseDPD import PNTDNN_NeuralNetwork
from sparseDPD import PGJANET_NeuralNetwork
from sparseDPD import NodePruningExperiment

# Set plotting style
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['figure.dpi'] = 100
plt.rcParams['font.size'] = 10

print("✓ Libraries imported successfully")
# Out:
# ✓ Libraries imported successfully

# %% [markdown]
# ## 1. Load Dataset and Train Baseline Volterra Model

# %%
# Load the PA_IO dataset
dataManager = DataManager(
    filepath='UCD_datasets/PA_IO.mat',
    num_training_points=19000,
    num_validaiton_points=1000,
    num_test_points=2000
)

# Train Volterra baseline
volterra_model = Volterra(
    num_nl_orders=3,
    num_memory_levels=3,
    dataset=dataManager.training_dataset
)

volterra_nmse = volterra_model.calculate_volterra_nmse(dataManager.test_dataset)
print(f"Volterra Baseline NMSE: {volterra_nmse:.2f} dB")
# Out:
# Volterra Baseline NMSE: -36.79 dB

# %% [markdown]
# ## 2. Train Baseline Neural Network Models
#
# Training four different network architectures to establish performance baselines.

# %%
# Dictionary to store all models and results
models = {}
baseline_results = {}

num_epochs = 300  # Number of epochs for training baseline models

print("="*70)
print("TRAINING BASELINE MODELS")
print("="*70)
# Out:
# ======================================================================
# TRAINING BASELINE MODELS
# ======================================================================

# %%
# 2.1 Train OneLayerNetwork
print("\n" + "="*70)
print("Training PNTDNN - OneLayerNetwork")
print("="*70)

model_one = PNTDNN_NeuralNetwork(
    num_memory_levels=20,
    model_type='OneLayerNetwork',
    forward_model=True
)

train_losses, valid_losses, best_epoch = model_one.get_best_model(
    num_epochs=num_epochs,
    training_dataset=dataManager.training_dataset,
    validation_dataset=dataManager.validation_dataset,
    learning_rate=1e-3
)

nmse_one = model_one.calculate_forward_nmse(dataManager.test_dataset)
params_one = model_one.get_num_params()

models['OneLayer'] = model_one
baseline_results['OneLayer'] = {
    'nmse': nmse_one,
    'params': params_one,
    'valid_losses': valid_losses,
    'best_epoch': best_epoch
}

print(f"\n✓ OneLayerNetwork - NMSE: {nmse_one:.2f} dB, Parameters: {params_one:,}")
# Out:
# ======================================================================
# Training PNTDNN - OneLayerNetwork
# ======================================================================
# Using cuda device
# Epoch  10/300  Loss=2.9768e+01  Valid Loss=1.4354e+00  LR=1.00e-03
# Epoch  20/300  Loss=7.6157e+00  Valid Loss=3.7617e-01  LR=1.00e-03
# Epoch  30/300  Loss=3.2058e+00  Valid Loss=1.5037e-01  LR=1.00e-03
# Epoch  40/300  Loss=1.5567e+00  Valid Loss=7.0457e-02  LR=1.00e-03
# Epoch  50/300  Loss=8.4258e-01  Valid Loss=4.0052e-02  LR=1.00e-03
# Epoch  60/300  Loss=5.6086e-01  Valid Loss=2.8827e-02  LR=1.00e-03
# Epoch  70/300  Loss=4.4746e-01  Valid Loss=2.2785e-02  LR=1.00e-03
# Epoch  80/300  Loss=3.9454e-01  Valid Loss=2.0356e-02  LR=1.00e-03
# Epoch  90/300  Loss=3.6449e-01  Valid Loss=1.8985e-02  LR=1.00e-03
# Epoch 100/300  Loss=3.3390e-01  Valid Loss=1.7421e-02  LR=1.00e-03
# Epoch 110/300  Loss=3.1723e-01  Valid Loss=1.5917e-02  LR=1.00e-03
# Epoch 120/300  Loss=3.0091e-01  Valid Loss=1.4858e-02  LR=1.00e-03
# Epoch 130/300  Loss=2.8894e-01  Valid Loss=1.4199e-02  LR=1.00e-03
# Epoch 140/300  Loss=2.7692e-01  Valid Loss=1.3871e-02  LR=1.00e-03
# Epoch 150/300  Loss=2.6848e-01  Valid Loss=1.3484e-02  LR=1.00e-03
# Epoch 160/300  Loss=2.5527e-01  Valid Loss=1.3160e-02  LR=1.00e-03
# Epoch 170/300  Loss=2.4993e-01  Valid Loss=1.3111e-02  LR=1.00e-03
# Epoch 180/300  Loss=1.8552e-01  Valid Loss=9.1402e-03  LR=5.00e-04
# Epoch 190/300  Loss=1.9875e-01  Valid Loss=8.8468e-03  LR=5.00e-04
# Epoch 200/300  Loss=1.9793e-01  Valid Loss=8.6522e-03  LR=5.00e-04
# Epoch 210/300  Loss=1.9397e-01  Valid Loss=8.3914e-03  LR=5.00e-04
# Epoch 220/300  Loss=1.8609e-01  Valid Loss=8.1844e-03  LR=5.00e-04
# Epoch 230/300  Loss=1.8834e-01  Valid Loss=8.2822e-03  LR=2.50e-04
# Epoch 240/300  Loss=1.6247e-01  Valid Loss=8.2875e-03  LR=2.50e-04
# Epoch 250/300  Loss=1.5482e-01  Valid Loss=8.0266e-03  LR=1.25e-04
# Epoch 260/300  Loss=1.5130e-01  Valid Loss=7.7980e-03  LR=6.25e-05
# Epoch 270/300  Loss=1.5129e-01  Valid Loss=7.7870e-03  LR=6.25e-05
# Epoch 280/300  Loss=1.4772e-01  Valid Loss=7.8072e-03  LR=3.13e-05
# Epoch 290/300  Loss=1.4617e-01  Valid Loss=7.8152e-03  LR=1.56e-05
# Epoch 300/300  Loss=1.4539e-01  Valid Loss=7.7769e-03  LR=7.81e-06
#
# Best model from epoch 299 with validation loss: 7.7760e-03
#
# ✓ OneLayerNetwork - NMSE: -40.64 dB, Parameters: 960

# %%
# 2.2 Train ThreeLayerNetwork
print("\n" + "="*70)
print("Training PNTDNN - ThreeLayerNetwork")
print("="*70)

model_three = PNTDNN_NeuralNetwork(
    num_memory_levels=20,
    model_type='ThreeLayerNetwork',
    forward_model=True
)

train_losses, valid_losses, best_epoch = model_three.get_best_model(
    num_epochs=num_epochs,
    training_dataset=dataManager.training_dataset,
    validation_dataset=dataManager.validation_dataset,
    learning_rate=1e-3
)

nmse_three = model_three.calculate_forward_nmse(dataManager.test_dataset)
params_three = model_three.get_num_params()

models['ThreeLayer'] = model_three
baseline_results['ThreeLayer'] = {
    'nmse': nmse_three,
    'params': params_three,
    'valid_losses': valid_losses,
    'best_epoch': best_epoch
}

print(f"\n✓ ThreeLayerNetwork - NMSE: {nmse_three:.2f} dB, Parameters: {params_three:,}")
# Out:
# ======================================================================
# Training PNTDNN - ThreeLayerNetwork
# ======================================================================
# Using cuda device
# Epoch  10/300  Loss=4.8582e+00  Valid Loss=1.9650e-01  LR=1.00e-03
# Epoch  20/300  Loss=1.1103e+00  Valid Loss=5.3057e-02  LR=1.00e-03
# Epoch  30/300  Loss=6.0507e-01  Valid Loss=2.6779e-02  LR=1.00e-03
# Epoch  40/300  Loss=5.9234e-01  Valid Loss=2.3016e-02  LR=1.00e-03
# Epoch  50/300  Loss=4.9452e-01  Valid Loss=2.2915e-02  LR=1.00e-03
# Epoch  60/300  Loss=3.3647e-01  Valid Loss=1.4642e-02  LR=5.00e-04
# Epoch  70/300  Loss=2.7772e-01  Valid Loss=1.4215e-02  LR=5.00e-04
# Epoch  80/300  Loss=3.0971e-01  Valid Loss=1.3470e-02  LR=5.00e-04
# Epoch  90/300  Loss=3.1398e-01  Valid Loss=1.3272e-02  LR=5.00e-04
# Epoch 100/300  Loss=3.0704e-01  Valid Loss=1.2959e-02  LR=5.00e-04
# Epoch 110/300  Loss=2.7775e-01  Valid Loss=1.3237e-02  LR=5.00e-04
# Epoch 120/300  Loss=2.0555e-01  Valid Loss=9.6049e-03  LR=2.50e-04
# Epoch 130/300  Loss=2.0047e-01  Valid Loss=8.9911e-03  LR=1.25e-04
# Epoch 140/300  Loss=1.8786e-01  Valid Loss=9.0992e-03  LR=1.25e-04
# Epoch 150/300  Loss=1.7532e-01  Valid Loss=8.4363e-03  LR=6.25e-05
# Epoch 160/300  Loss=1.7489e-01  Valid Loss=8.4458e-03  LR=6.25e-05
# Epoch 170/300  Loss=1.7029e-01  Valid Loss=8.2939e-03  LR=3.13e-05
# Epoch 180/300  Loss=1.6986e-01  Valid Loss=8.2665e-03  LR=3.13e-05
# Epoch 190/300  Loss=1.6929e-01  Valid Loss=8.2381e-03  LR=3.13e-05
# Epoch 200/300  Loss=1.6862e-01  Valid Loss=8.2078e-03  LR=3.13e-05
# Epoch 210/300  Loss=1.6796e-01  Valid Loss=8.1728e-03  LR=3.13e-05
# Epoch 220/300  Loss=1.6731e-01  Valid Loss=8.1479e-03  LR=3.13e-05
# Epoch 230/300  Loss=1.6666e-01  Valid Loss=8.1292e-03  LR=3.13e-05
# Epoch 240/300  Loss=1.6605e-01  Valid Loss=8.1024e-03  LR=3.13e-05
# Epoch 250/300  Loss=1.6545e-01  Valid Loss=8.0814e-03  LR=3.13e-05
# Epoch 260/300  Loss=1.6486e-01  Valid Loss=8.0545e-03  LR=3.13e-05
# Epoch 270/300  Loss=1.6429e-01  Valid Loss=8.0349e-03  LR=3.13e-05
# Epoch 280/300  Loss=1.6374e-01  Valid Loss=8.0188e-03  LR=3.13e-05
# Epoch 290/300  Loss=1.6318e-01  Valid Loss=8.0086e-03  LR=3.13e-05
# Epoch 300/300  Loss=1.6264e-01  Valid Loss=7.9890e-03  LR=3.13e-05
#
# Best model from epoch 299 with validation loss: 7.9890e-03
#
# ✓ ThreeLayerNetwork - NMSE: -40.06 dB, Parameters: 2,820

# %%
# 2.3 Train MultiLayerNetwork
print("\n" + "="*70)
print("Training PNTDNN - MultiLayerNetwork")
print("="*70)

model_multi = PNTDNN_NeuralNetwork(
    num_memory_levels=20,
    model_type='MultiLayerNetwork',
    forward_model=True
)

train_losses, valid_losses, best_epoch = model_multi.get_best_model(
    num_epochs=num_epochs,
    training_dataset=dataManager.training_dataset,
    validation_dataset=dataManager.validation_dataset,
    learning_rate=1e-3
)

nmse_multi = model_multi.calculate_forward_nmse(dataManager.test_dataset)
params_multi = model_multi.get_num_params()

models['MultiLayer'] = model_multi
baseline_results['MultiLayer'] = {
    'nmse': nmse_multi,
    'params': params_multi,
    'valid_losses': valid_losses,
    'best_epoch': best_epoch
}

print(f"\n✓ MultiLayerNetwork - NMSE: {nmse_multi:.2f} dB, Parameters: {params_multi:,}")
# Out:
# ======================================================================
# Training PNTDNN - MultiLayerNetwork
# ======================================================================
# Using cuda device
# Epoch  10/300  Loss=4.0029e+00  Valid Loss=1.6887e-01  LR=1.00e-03
# Epoch  20/300  Loss=1.2387e+00  Valid Loss=6.3764e-02  LR=1.00e-03
# Epoch  30/300  Loss=7.7110e-01  Valid Loss=4.1208e-02  LR=1.00e-03
# Epoch  40/300  Loss=8.6552e-01  Valid Loss=2.8536e-02  LR=1.00e-03
# Epoch  50/300  Loss=7.4914e-01  Valid Loss=2.8832e-02  LR=1.00e-03
# Epoch  60/300  Loss=7.3771e-01  Valid Loss=2.7064e-02  LR=1.00e-03
# Epoch  70/300  Loss=7.7500e-01  Valid Loss=3.0729e-02  LR=1.00e-03
# Epoch  80/300  Loss=6.6716e-01  Valid Loss=2.8402e-02  LR=1.00e-03
# Epoch  90/300  Loss=4.8638e-01  Valid Loss=2.1648e-02  LR=1.00e-03
# Epoch 100/300  Loss=3.3481e-01  Valid Loss=1.1959e-02  LR=1.00e-03
# Epoch 110/300  Loss=2.3568e-01  Valid Loss=1.5072e-02  LR=5.00e-04
# Epoch 120/300  Loss=2.1275e-01  Valid Loss=1.1848e-02  LR=2.50e-04
# Epoch 130/300  Loss=1.8656e-01  Valid Loss=9.4194e-03  LR=1.25e-04
# Epoch 140/300  Loss=1.8984e-01  Valid Loss=9.1525e-03  LR=1.25e-04
# Epoch 150/300  Loss=1.9218e-01  Valid Loss=9.4877e-03  LR=6.25e-05
# Epoch 160/300  Loss=1.7332e-01  Valid Loss=9.0491e-03  LR=6.25e-05
# Epoch 170/300  Loss=1.6676e-01  Valid Loss=8.9120e-03  LR=3.13e-05
# Epoch 180/300  Loss=1.6654e-01  Valid Loss=8.8096e-03  LR=3.13e-05
# Epoch 190/300  Loss=1.6607e-01  Valid Loss=8.7451e-03  LR=3.13e-05
# Epoch 200/300  Loss=1.6531e-01  Valid Loss=8.6976e-03  LR=3.13e-05
# Epoch 210/300  Loss=1.6449e-01  Valid Loss=8.6583e-03  LR=3.13e-05
# Epoch 220/300  Loss=1.6365e-01  Valid Loss=8.6197e-03  LR=3.13e-05
# Epoch 230/300  Loss=1.6283e-01  Valid Loss=8.5813e-03  LR=3.13e-05
# Epoch 240/300  Loss=1.6201e-01  Valid Loss=8.5450e-03  LR=3.13e-05
# Epoch 250/300  Loss=1.6118e-01  Valid Loss=8.5084e-03  LR=3.13e-05
# Epoch 260/300  Loss=1.6044e-01  Valid Loss=8.4707e-03  LR=3.13e-05
# Epoch 270/300  Loss=1.5971e-01  Valid Loss=8.4329e-03  LR=3.13e-05
# Epoch 280/300  Loss=1.5895e-01  Valid Loss=8.3977e-03  LR=3.13e-05
# Epoch 290/300  Loss=1.5823e-01  Valid Loss=8.3649e-03  LR=3.13e-05
# Epoch 300/300  Loss=1.5759e-01  Valid Loss=8.3322e-03  LR=3.13e-05
#
# Best model from epoch 300 with validation loss: 8.3322e-03
#
# ✓ MultiLayerNetwork - NMSE: -40.42 dB, Parameters: 10,768

# %%
# 2.4 Train PGJANET
print("\n" + "="*70)
print("Training PGJANET - PGJANETNetwork")
print("="*70)

model_pgjanet = PGJANET_NeuralNetwork(
    num_memory_levels=50,
    model_type='PGJANETNetwork',
    forward_model=True
)

train_losses, valid_losses, best_epoch = model_pgjanet.get_best_model(
    num_epochs=num_epochs,
    training_dataset=dataManager.training_dataset,
    validation_dataset=dataManager.validation_dataset,
    learning_rate=1e-3
)

nmse_pgjanet = model_pgjanet.calculate_forward_nmse(dataManager.test_dataset)
params_pgjanet = model_pgjanet.get_num_params()

models['PGJANET'] = model_pgjanet
baseline_results['PGJANET'] = {
    'nmse': nmse_pgjanet,
    'params': params_pgjanet,
    'valid_losses': valid_losses,
    'best_epoch': best_epoch
}

print(f"\n✓ PGJANETNetwork - NMSE: {nmse_pgjanet:.2f} dB, Parameters: {params_pgjanet:,}")
# Out:
# ======================================================================
# Training PGJANET - PGJANETNetwork
# ======================================================================
# Using cuda device
# Epoch  10/300  Loss=3.3996e+00  Valid Loss=1.3944e-01  LR=1.00e-03
# Epoch  20/300  Loss=1.8053e+00  Valid Loss=6.3013e-02  LR=1.00e-03
# Epoch  30/300  Loss=1.0174e+00  Valid Loss=6.8157e-02  LR=1.00e-03
# Epoch  40/300  Loss=8.0975e-01  Valid Loss=3.3519e-02  LR=1.00e-03
# Epoch  50/300  Loss=6.6479e-01  Valid Loss=7.7439e-02  LR=1.00e-03
# Epoch  60/300  Loss=6.1058e-01  Valid Loss=4.9802e-02  LR=1.00e-03
# Epoch  70/300  Loss=6.5350e-01  Valid Loss=7.4893e-02  LR=1.00e-03
# Epoch  80/300  Loss=4.8996e-01  Valid Loss=2.5559e-02  LR=5.00e-04
# Epoch  90/300  Loss=4.7682e-01  Valid Loss=2.9962e-02  LR=5.00e-04
# Epoch 100/300  Loss=4.3837e-01  Valid Loss=2.3114e-02  LR=2.50e-04
# Epoch 110/300  Loss=4.3289e-01  Valid Loss=2.1189e-02  LR=1.25e-04
# Epoch 120/300  Loss=4.2859e-01  Valid Loss=2.2831e-02  LR=1.25e-04
# Epoch 130/300  Loss=4.1146e-01  Valid Loss=2.0469e-02  LR=6.25e-05
# Epoch 140/300  Loss=4.1297e-01  Valid Loss=2.0575e-02  LR=6.25e-05
# Epoch 150/300  Loss=4.0723e-01  Valid Loss=1.9746e-02  LR=3.13e-05
# Epoch 160/300  Loss=4.0615e-01  Valid Loss=2.0908e-02  LR=3.13e-05
# Epoch 170/300  Loss=4.0236e-01  Valid Loss=1.9986e-02  LR=1.56e-05
# Epoch 180/300  Loss=4.0035e-01  Valid Loss=1.9601e-02  LR=1.56e-05
# Epoch 190/300  Loss=4.0049e-01  Valid Loss=1.9799e-02  LR=1.56e-05
# Epoch 200/300  Loss=3.9804e-01  Valid Loss=1.9671e-02  LR=7.81e-06
# Epoch 210/300  Loss=3.9819e-01  Valid Loss=1.9665e-02  LR=3.91e-06
# Epoch 220/300  Loss=3.9624e-01  Valid Loss=1.9634e-02  LR=1.95e-06
# Epoch 230/300  Loss=3.9622e-01  Valid Loss=1.9635e-02  LR=9.77e-07
# Epoch 240/300  Loss=3.9591e-01  Valid Loss=1.9621e-02  LR=4.88e-07
# Epoch 250/300  Loss=3.9584e-01  Valid Loss=1.9630e-02  LR=2.44e-07
# Epoch 260/300  Loss=3.9580e-01  Valid Loss=1.9604e-02  LR=1.22e-07
# Epoch 270/300  Loss=3.9576e-01  Valid Loss=1.9621e-02  LR=1.22e-07
# Epoch 280/300  Loss=3.9574e-01  Valid Loss=1.9621e-02  LR=6.10e-08
# Epoch 290/300  Loss=3.9573e-01  Valid Loss=1.9622e-02  LR=3.05e-08
# Epoch 300/300  Loss=3.9572e-01  Valid Loss=1.9623e-02  LR=1.53e-08
#
# Best model from epoch 205 with validation loss: 1.9508e-02
#
# ✓ PGJANETNetwork - NMSE: -36.27 dB, Parameters: 1,872

# %% [markdown]
# ### Baseline Model Comparison

# %%
# Display baseline results
print("\n" + "="*70)
print("BASELINE MODEL COMPARISON")
print("="*70)
print(f"{'Model':<20} {'Parameters':>12} {'NMSE (dB)':>12}")
print("-"*70)
for name, results in baseline_results.items():
    print(f"{name:<20} {results['params']:>12,} {results['nmse']:>12.2f}")
print("="*70)

# Plot baseline training curves
fig, axes = plt.subplots(1, 4, figsize=(20, 4))
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

for idx, (name, results) in enumerate(baseline_results.items()):
    ax = axes[idx]
    valid_losses = results['valid_losses']
    best_epoch = results['best_epoch']
    epochs = np.arange(1, len(valid_losses) + 1)
    
    ax.plot(epochs, valid_losses, linewidth=2, color=colors[idx], label='Validation Loss')
    ax.axvline(x=best_epoch, linestyle='--', linewidth=1.5, color='red', alpha=0.8, label=f'Best Epoch: {best_epoch}')
    ax.plot(best_epoch, valid_losses[best_epoch-1], marker='*', markersize=12, color='red', markeredgecolor='black')
    
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Validation Loss')
    ax.set_title(f'{name}\n{results["params"]:,} params, NMSE: {results["nmse"]:.2f} dB', fontweight='bold')
    ax.legend()
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ======================================================================
# BASELINE MODEL COMPARISON
# ======================================================================
# Model                  Parameters    NMSE (dB)
# ----------------------------------------------------------------------
# OneLayer                      960       -40.64
# ThreeLayer                  2,820       -40.06
# MultiLayer                 10,768       -40.42
# PGJANET                     1,872       -36.27
# ======================================================================

# %% [markdown]
# ## 3. Linear/Magnitude Pruning Experiments
#
# Running magnitude-based pruning on all four network architectures.

# %%
# Store pruning experiment results
linear_pruning_results = {}

retrain_epochs = 100

print("\n" + "="*70)
print("LINEAR/MAGNITUDE PRUNING EXPERIMENTS")
print("="*70)
# Out:
# ======================================================================
# LINEAR/MAGNITUDE PRUNING EXPERIMENTS
# ======================================================================

# %%
# Helper function to calculate effective parameters
def calc_effective_params(base_params, prune_pct):
    """Calculate number of non-zero parameters"""
    return int(base_params * (1 - prune_pct / 100))

# %%
# 3.1 Linear Pruning - OneLayerNetwork
print("\n" + "="*70)
print("Linear Pruning - OneLayerNetwork")
print("="*70)

exp_linear_one = LinearExperiment(
    nn_model=models['OneLayer'],
    num_prune_iterations=12,
    prune_amount=0.2,
    retrain_epochs=retrain_epochs,
    training_dataset=dataManager.get_training_data(),
    valid_dataset=dataManager.get_validation_data(),
    test_dataset=dataManager.get_test_data()
)

# Run experiment and store results
initial_nmse = exp_linear_one.original_nn_model.calculate_forward_nmse(exp_linear_one.test_dataset)
prune_pcts, nmse_results, valid_losses, best_epochs, all_valid_losses = exp_linear_one.prune()

# Calculate parameter counts
base_params = baseline_results['OneLayer']['params']
param_counts = [base_params] + [calc_effective_params(base_params, pct) for pct in prune_pcts]

linear_pruning_results['OneLayer'] = {
    'params': param_counts,
    'nmse': [initial_nmse] + nmse_results,
    'valid_losses': all_valid_losses,
    'best_epochs': best_epochs
}

print(f"\nParameter range: {min(param_counts):,} - {max(param_counts):,}")
print(f"NMSE range: {min([initial_nmse] + nmse_results):.2f} - {max([initial_nmse] + nmse_results):.2f} dB")
# Out:
# ======================================================================
# Linear Pruning - OneLayerNetwork
# ======================================================================
#
# ============================================================
# Pruning Iteration 1/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 20.00% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.1306e-01  Valid Loss=1.2141e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.1285e-01  Valid Loss=1.1876e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.1313e-01  Valid Loss=1.1601e-02  LR=1.00e-03
# Epoch  40/100  Loss=2.1089e-01  Valid Loss=1.1393e-02  LR=1.00e-03
# Epoch  50/100  Loss=2.0938e-01  Valid Loss=1.1206e-02  LR=1.00e-03
# Epoch  60/100  Loss=2.0886e-01  Valid Loss=1.1044e-02  LR=1.00e-03
# Epoch  70/100  Loss=2.0844e-01  Valid Loss=1.0910e-02  LR=1.00e-03
# Epoch  80/100  Loss=2.0712e-01  Valid Loss=1.0816e-02  LR=1.00e-03
# Epoch  90/100  Loss=2.0584e-01  Valid Loss=1.0681e-02  LR=1.00e-03
# Epoch 100/100  Loss=2.0486e-01  Valid Loss=1.0613e-02  LR=1.00e-03
#
# Best model from epoch 99 with validation loss: 1.0583e-02
# NMSE: -38.8875 dB
#
# ============================================================
# Pruning Iteration 2/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 36.04% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.9405e-01  Valid Loss=1.0113e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.6676e-01  Valid Loss=7.9844e-03  LR=5.00e-04
# Epoch  30/100  Loss=1.5103e-01  Valid Loss=7.8197e-03  LR=2.50e-04
# Epoch  40/100  Loss=1.5130e-01  Valid Loss=7.7766e-03  LR=2.50e-04
# Epoch  50/100  Loss=1.5224e-01  Valid Loss=7.7202e-03  LR=2.50e-04
# Epoch  60/100  Loss=1.5249e-01  Valid Loss=7.7048e-03  LR=2.50e-04
# Epoch  70/100  Loss=1.5233e-01  Valid Loss=7.6700e-03  LR=2.50e-04
# Epoch  80/100  Loss=1.5212e-01  Valid Loss=7.6375e-03  LR=2.50e-04
# Epoch  90/100  Loss=1.5191e-01  Valid Loss=7.6222e-03  LR=2.50e-04
# Epoch 100/100  Loss=1.5153e-01  Valid Loss=7.6259e-03  LR=2.50e-04
#
# Best model from epoch 99 with validation loss: 7.6098e-03
# NMSE: -40.6984 dB
#
# ============================================================
# Pruning Iteration 3/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 48.85% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.9470e-01  Valid Loss=1.0534e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.8975e-01  Valid Loss=9.9638e-03  LR=1.00e-03
# Epoch  30/100  Loss=1.8962e-01  Valid Loss=9.8665e-03  LR=1.00e-03
# Epoch  40/100  Loss=1.8873e-01  Valid Loss=9.8148e-03  LR=1.00e-03
# Epoch  50/100  Loss=1.8888e-01  Valid Loss=9.7518e-03  LR=1.00e-03
# Epoch  60/100  Loss=1.8775e-01  Valid Loss=9.6295e-03  LR=1.00e-03
# Epoch  70/100  Loss=1.8695e-01  Valid Loss=9.5607e-03  LR=1.00e-03
# Epoch  80/100  Loss=1.8724e-01  Valid Loss=9.4972e-03  LR=1.00e-03
# Epoch  90/100  Loss=1.8497e-01  Valid Loss=9.4822e-03  LR=1.00e-03
# Epoch 100/100  Loss=1.8569e-01  Valid Loss=9.4040e-03  LR=1.00e-03
#
# Best model from epoch 98 with validation loss: 9.3942e-03
# NMSE: -39.3678 dB
#
# ============================================================
# Pruning Iteration 4/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 59.06% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.9585e-01  Valid Loss=8.9022e-03  LR=1.00e-03
# Epoch  20/100  Loss=1.8684e-01  Valid Loss=8.2661e-03  LR=1.00e-03
# Epoch  30/100  Loss=1.8415e-01  Valid Loss=7.7664e-03  LR=1.00e-03
# Epoch  40/100  Loss=1.8011e-01  Valid Loss=7.9614e-03  LR=1.00e-03
# Epoch  50/100  Loss=1.5843e-01  Valid Loss=7.7716e-03  LR=5.00e-04
# Epoch  60/100  Loss=1.5146e-01  Valid Loss=7.5640e-03  LR=2.50e-04
# Epoch  70/100  Loss=1.5121e-01  Valid Loss=7.5481e-03  LR=2.50e-04
# Epoch  80/100  Loss=1.5033e-01  Valid Loss=7.5295e-03  LR=2.50e-04
# Epoch  90/100  Loss=1.4964e-01  Valid Loss=7.4980e-03  LR=2.50e-04
# Epoch 100/100  Loss=1.4908e-01  Valid Loss=7.4667e-03  LR=2.50e-04
#
# Best model from epoch 100 with validation loss: 7.4667e-03
# NMSE: -40.6611 dB
#
# ============================================================
# Pruning Iteration 5/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 67.29% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.7798e-01  Valid Loss=7.8926e-03  LR=1.00e-03
# Epoch  20/100  Loss=1.7541e-01  Valid Loss=7.5782e-03  LR=1.00e-03
# Epoch  30/100  Loss=1.7350e-01  Valid Loss=7.5286e-03  LR=1.00e-03
# Epoch  40/100  Loss=1.7222e-01  Valid Loss=7.4716e-03  LR=1.00e-03
# Epoch  50/100  Loss=1.7113e-01  Valid Loss=7.4509e-03  LR=1.00e-03
# Epoch  60/100  Loss=1.7035e-01  Valid Loss=7.4406e-03  LR=1.00e-03
# Epoch  70/100  Loss=1.6965e-01  Valid Loss=7.4433e-03  LR=1.00e-03
# Epoch  80/100  Loss=1.5091e-01  Valid Loss=7.3049e-03  LR=5.00e-04
# Epoch  90/100  Loss=1.5204e-01  Valid Loss=7.3153e-03  LR=5.00e-04
# Epoch 100/100  Loss=1.4522e-01  Valid Loss=7.1684e-03  LR=2.50e-04
#
# Best model from epoch 100 with validation loss: 7.1684e-03
# NMSE: -40.8251 dB
#
# ============================================================
# Pruning Iteration 6/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 73.85% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.7080e-01  Valid Loss=7.4659e-03  LR=1.00e-03
# Epoch  20/100  Loss=1.6980e-01  Valid Loss=7.4408e-03  LR=1.00e-03
# Epoch  30/100  Loss=1.6942e-01  Valid Loss=7.4091e-03  LR=1.00e-03
# Epoch  40/100  Loss=1.6916e-01  Valid Loss=7.3751e-03  LR=1.00e-03
# Epoch  50/100  Loss=1.6883e-01  Valid Loss=7.3694e-03  LR=1.00e-03
# Epoch  60/100  Loss=1.6853e-01  Valid Loss=7.3556e-03  LR=1.00e-03
# Epoch  70/100  Loss=1.6827e-01  Valid Loss=7.3532e-03  LR=1.00e-03
# Epoch  80/100  Loss=1.5010e-01  Valid Loss=7.1751e-03  LR=5.00e-04
# Epoch  90/100  Loss=1.4310e-01  Valid Loss=7.0355e-03  LR=2.50e-04
# Epoch 100/100  Loss=1.4462e-01  Valid Loss=7.0811e-03  LR=2.50e-04
#
# Best model from epoch 90 with validation loss: 7.0355e-03
# NMSE: -40.8961 dB
#
# ============================================================
# Pruning Iteration 7/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 79.06% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.7568e-01  Valid Loss=7.7177e-03  LR=1.00e-03
# Epoch  20/100  Loss=1.7770e-01  Valid Loss=7.7142e-03  LR=1.00e-03
# Epoch  30/100  Loss=1.7792e-01  Valid Loss=7.7402e-03  LR=5.00e-04
# Epoch  40/100  Loss=1.5723e-01  Valid Loss=7.4254e-03  LR=5.00e-04
# Epoch  50/100  Loss=1.5197e-01  Valid Loss=7.3370e-03  LR=2.50e-04
# Epoch  60/100  Loss=1.4811e-01  Valid Loss=7.1699e-03  LR=1.25e-04
# Epoch  70/100  Loss=1.4854e-01  Valid Loss=7.1663e-03  LR=1.25e-04
# Epoch  80/100  Loss=1.4869e-01  Valid Loss=7.1643e-03  LR=1.25e-04
# Epoch  90/100  Loss=1.4871e-01  Valid Loss=7.1614e-03  LR=1.25e-04
# Epoch 100/100  Loss=1.4868e-01  Valid Loss=7.1585e-03  LR=1.25e-04
#
# Best model from epoch 100 with validation loss: 7.1585e-03
# NMSE: -40.8479 dB
#
# ============================================================
# Pruning Iteration 8/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 83.23% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.5021e-01  Valid Loss=1.7465e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.4857e-01  Valid Loss=1.1904e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.3395e-01  Valid Loss=1.0892e-02  LR=1.00e-03
# Epoch  40/100  Loss=2.3260e-01  Valid Loss=1.0801e-02  LR=1.00e-03
# Epoch  50/100  Loss=2.3219e-01  Valid Loss=1.0747e-02  LR=1.00e-03
# Epoch  60/100  Loss=2.3171e-01  Valid Loss=1.0723e-02  LR=1.00e-03
# Epoch  70/100  Loss=2.3114e-01  Valid Loss=1.0696e-02  LR=1.00e-03
# Epoch  80/100  Loss=2.3077e-01  Valid Loss=1.0682e-02  LR=1.00e-03
# Epoch  90/100  Loss=2.3047e-01  Valid Loss=1.0674e-02  LR=1.00e-03
# Epoch 100/100  Loss=2.3018e-01  Valid Loss=1.0654e-02  LR=1.00e-03
#
# Best model from epoch 100 with validation loss: 1.0654e-02
# NMSE: -39.1280 dB
#
# ============================================================
# Pruning Iteration 9/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 86.56% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.6119e-01  Valid Loss=1.1859e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.5343e-01  Valid Loss=1.1501e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.5021e-01  Valid Loss=1.1374e-02  LR=1.00e-03
# Epoch  40/100  Loss=2.4877e-01  Valid Loss=1.1293e-02  LR=1.00e-03
# Epoch  50/100  Loss=2.4810e-01  Valid Loss=1.1223e-02  LR=1.00e-03
# Epoch  60/100  Loss=2.4769e-01  Valid Loss=1.1179e-02  LR=1.00e-03
# Epoch  70/100  Loss=2.4737e-01  Valid Loss=1.1151e-02  LR=1.00e-03
# Epoch  80/100  Loss=2.4720e-01  Valid Loss=1.1128e-02  LR=1.00e-03
# Epoch  90/100  Loss=2.4708e-01  Valid Loss=1.1103e-02  LR=1.00e-03
# Epoch 100/100  Loss=2.4694e-01  Valid Loss=1.1083e-02  LR=1.00e-03
#
# Best model from epoch 100 with validation loss: 1.1083e-02
# NMSE: -38.9436 dB
#
# ============================================================
# Pruning Iteration 10/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 89.27% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.7207e-01  Valid Loss=1.2881e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.6499e-01  Valid Loss=1.2267e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.6176e-01  Valid Loss=1.1866e-02  LR=1.00e-03
# Epoch  40/100  Loss=2.6069e-01  Valid Loss=1.1706e-02  LR=1.00e-03
# Epoch  50/100  Loss=2.6042e-01  Valid Loss=1.1669e-02  LR=1.00e-03
# Epoch  60/100  Loss=2.6019e-01  Valid Loss=1.1657e-02  LR=1.00e-03
# Epoch  70/100  Loss=2.6002e-01  Valid Loss=1.1652e-02  LR=1.00e-03
# Epoch  80/100  Loss=2.5985e-01  Valid Loss=1.1643e-02  LR=1.00e-03
# Epoch  90/100  Loss=2.5968e-01  Valid Loss=1.1635e-02  LR=1.00e-03
# Epoch 100/100  Loss=2.5954e-01  Valid Loss=1.1624e-02  LR=1.00e-03
#
# Best model from epoch 100 with validation loss: 1.1624e-02
# NMSE: -38.6927 dB
#
# ============================================================
# Pruning Iteration 11/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 91.46% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.7920e-01  Valid Loss=1.3734e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.5711e-01  Valid Loss=1.2672e-02  LR=5.00e-04
# Epoch  30/100  Loss=2.5772e-01  Valid Loss=1.2523e-02  LR=5.00e-04
# Epoch  40/100  Loss=2.5796e-01  Valid Loss=1.2461e-02  LR=5.00e-04
# Epoch  50/100  Loss=2.5793e-01  Valid Loss=1.2440e-02  LR=5.00e-04
# Epoch  60/100  Loss=2.5764e-01  Valid Loss=1.2412e-02  LR=5.00e-04
# Epoch  70/100  Loss=2.5730e-01  Valid Loss=1.2386e-02  LR=5.00e-04
# Epoch  80/100  Loss=2.5695e-01  Valid Loss=1.2361e-02  LR=5.00e-04
# Epoch  90/100  Loss=2.5663e-01  Valid Loss=1.2336e-02  LR=5.00e-04
# Epoch 100/100  Loss=2.5633e-01  Valid Loss=1.2314e-02  LR=5.00e-04
#
# Best model from epoch 100 with validation loss: 1.2314e-02
# NMSE: -38.4700 dB
#
# ============================================================
# Pruning Iteration 12/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 93.12% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=5.7796e-01  Valid Loss=2.6864e-02  LR=1.00e-03
# Epoch  20/100  Loss=5.6264e-01  Valid Loss=2.5868e-02  LR=1.00e-03
# Epoch  30/100  Loss=5.6006e-01  Valid Loss=2.5637e-02  LR=1.00e-03
# Epoch  40/100  Loss=5.5974e-01  Valid Loss=2.5589e-02  LR=1.00e-03
# Epoch  50/100  Loss=5.5978e-01  Valid Loss=2.5580e-02  LR=1.00e-03
# Epoch  60/100  Loss=5.5987e-01  Valid Loss=2.5574e-02  LR=1.00e-03
# Epoch  70/100  Loss=5.5136e-01  Valid Loss=2.5455e-02  LR=5.00e-04
# Epoch  80/100  Loss=5.5172e-01  Valid Loss=2.5393e-02  LR=5.00e-04
# Epoch  90/100  Loss=5.5178e-01  Valid Loss=2.5384e-02  LR=5.00e-04
# Epoch 100/100  Loss=5.4502e-01  Valid Loss=2.5301e-02  LR=2.50e-04
#
# Best model from epoch 100 with validation loss: 2.5301e-02
# NMSE: -35.2213 dB
#
# Parameter range: 65 - 960
# NMSE range: -40.90 - -35.22 dB

# %%
# 3.2 Linear Pruning - ThreeLayerNetwork
print("\n" + "="*70)
print("Linear Pruning - ThreeLayerNetwork")
print("="*70)

exp_linear_three = LinearExperiment(
    nn_model=models['ThreeLayer'],
    num_prune_iterations=12,
    prune_amount=0.2,
    retrain_epochs=retrain_epochs,
    training_dataset=dataManager.get_training_data(),
    valid_dataset=dataManager.get_validation_data(),
    test_dataset=dataManager.get_test_data()
)

# Run experiment and store results
initial_nmse = exp_linear_three.original_nn_model.calculate_forward_nmse(exp_linear_three.test_dataset)
prune_pcts, nmse_results, valid_losses, best_epochs, all_valid_losses = exp_linear_three.prune()

# Calculate parameter counts
base_params = baseline_results['ThreeLayer']['params']
param_counts = [base_params] + [calc_effective_params(base_params, pct) for pct in prune_pcts]

linear_pruning_results['ThreeLayer'] = {
    'params': param_counts,
    'nmse': [initial_nmse] + nmse_results,
    'valid_losses': all_valid_losses,
    'best_epochs': best_epochs
}

print(f"\nParameter range: {min(param_counts):,} - {max(param_counts):,}")
print(f"NMSE range: {min([initial_nmse] + nmse_results):.2f} - {max([initial_nmse] + nmse_results):.2f} dB")
# Out:
# ======================================================================
# Linear Pruning - ThreeLayerNetwork
# ======================================================================
#
# ============================================================
# Pruning Iteration 1/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 20.00% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.6433e-01  Valid Loss=1.8005e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.0184e-01  Valid Loss=1.1810e-02  LR=5.00e-04
# Epoch  30/100  Loss=1.8182e-01  Valid Loss=8.1869e-03  LR=2.50e-04
# Epoch  40/100  Loss=1.8167e-01  Valid Loss=8.7199e-03  LR=2.50e-04
# Epoch  50/100  Loss=1.6484e-01  Valid Loss=8.3031e-03  LR=1.25e-04
# Epoch  60/100  Loss=1.5705e-01  Valid Loss=7.8476e-03  LR=6.25e-05
# Epoch  70/100  Loss=1.5383e-01  Valid Loss=7.6496e-03  LR=3.13e-05
# Epoch  80/100  Loss=1.5374e-01  Valid Loss=7.6463e-03  LR=3.13e-05
# Epoch  90/100  Loss=1.5047e-01  Valid Loss=7.5647e-03  LR=1.56e-05
# Epoch 100/100  Loss=1.5059e-01  Valid Loss=7.5546e-03  LR=1.56e-05
#
# Best model from epoch 100 with validation loss: 7.5546e-03
# NMSE: -40.4605 dB
#
# ============================================================
# Pruning Iteration 2/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 35.99% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.7310e-01  Valid Loss=1.8148e-02  LR=1.00e-03
# Epoch  20/100  Loss=3.7528e-01  Valid Loss=1.5953e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.3848e-01  Valid Loss=1.6670e-02  LR=1.00e-03
# Epoch  40/100  Loss=1.8941e-01  Valid Loss=1.0168e-02  LR=5.00e-04
# Epoch  50/100  Loss=1.6796e-01  Valid Loss=8.4177e-03  LR=2.50e-04
# Epoch  60/100  Loss=1.7074e-01  Valid Loss=7.5360e-03  LR=2.50e-04
# Epoch  70/100  Loss=1.7217e-01  Valid Loss=7.4274e-03  LR=2.50e-04
# Epoch  80/100  Loss=1.6976e-01  Valid Loss=7.4032e-03  LR=2.50e-04
# Epoch  90/100  Loss=1.4991e-01  Valid Loss=7.5021e-03  LR=1.25e-04
# Epoch 100/100  Loss=1.4364e-01  Valid Loss=7.3589e-03  LR=6.25e-05
#
# Best model from epoch 100 with validation loss: 7.3589e-03
# NMSE: -40.5976 dB
#
# ============================================================
# Pruning Iteration 3/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 48.79% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.1320e-01  Valid Loss=1.4683e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.8574e-01  Valid Loss=9.8343e-03  LR=5.00e-04
# Epoch  30/100  Loss=1.6241e-01  Valid Loss=7.7547e-03  LR=2.50e-04
# Epoch  40/100  Loss=1.6685e-01  Valid Loss=7.5637e-03  LR=2.50e-04
# Epoch  50/100  Loss=1.6708e-01  Valid Loss=7.4378e-03  LR=2.50e-04
# Epoch  60/100  Loss=1.6682e-01  Valid Loss=7.3714e-03  LR=2.50e-04
# Epoch  70/100  Loss=1.6642e-01  Valid Loss=7.3322e-03  LR=2.50e-04
# Epoch  80/100  Loss=1.6676e-01  Valid Loss=7.3257e-03  LR=2.50e-04
# Epoch  90/100  Loss=1.6533e-01  Valid Loss=7.3081e-03  LR=2.50e-04
# Epoch 100/100  Loss=1.6519e-01  Valid Loss=7.3025e-03  LR=2.50e-04
#
# Best model from epoch 99 with validation loss: 7.2944e-03
# NMSE: -40.7927 dB
#
# ============================================================
# Pruning Iteration 4/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 59.04% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.9693e-01  Valid Loss=1.1621e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.1097e-01  Valid Loss=1.2999e-02  LR=1.00e-03
# Epoch  30/100  Loss=1.7981e-01  Valid Loss=7.8056e-03  LR=5.00e-04
# Epoch  40/100  Loss=1.5660e-01  Valid Loss=7.4931e-03  LR=2.50e-04
# Epoch  50/100  Loss=1.4711e-01  Valid Loss=7.2544e-03  LR=1.25e-04
# Epoch  60/100  Loss=1.4747e-01  Valid Loss=7.2003e-03  LR=1.25e-04
# Epoch  70/100  Loss=1.4811e-01  Valid Loss=7.1765e-03  LR=1.25e-04
# Epoch  80/100  Loss=1.4795e-01  Valid Loss=7.1487e-03  LR=1.25e-04
# Epoch  90/100  Loss=1.4750e-01  Valid Loss=7.1271e-03  LR=1.25e-04
# Epoch 100/100  Loss=1.4692e-01  Valid Loss=7.1099e-03  LR=1.25e-04
#
# Best model from epoch 100 with validation loss: 7.1099e-03
# NMSE: -40.8995 dB
#
# ============================================================
# Pruning Iteration 5/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 67.23% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.0479e-01  Valid Loss=1.2109e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.0720e-01  Valid Loss=1.1148e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.0365e-01  Valid Loss=1.0691e-02  LR=1.00e-03
# Epoch  40/100  Loss=1.9950e-01  Valid Loss=1.0546e-02  LR=1.00e-03
# Epoch  50/100  Loss=1.9846e-01  Valid Loss=1.0505e-02  LR=1.00e-03
# Epoch  60/100  Loss=1.9742e-01  Valid Loss=1.0469e-02  LR=1.00e-03
# Epoch  70/100  Loss=1.9537e-01  Valid Loss=1.0448e-02  LR=1.00e-03
# Epoch  80/100  Loss=1.9479e-01  Valid Loss=1.0473e-02  LR=1.00e-03
# Epoch  90/100  Loss=1.6755e-01  Valid Loss=7.2700e-03  LR=5.00e-04
# Epoch 100/100  Loss=1.4435e-01  Valid Loss=7.1494e-03  LR=2.50e-04
#
# Best model from epoch 97 with validation loss: 7.1164e-03
# NMSE: -41.0044 dB
#
# ============================================================
# Pruning Iteration 6/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 73.79% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.9242e-01  Valid Loss=1.1818e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.7837e-01  Valid Loss=1.1149e-02  LR=1.00e-03
# Epoch  30/100  Loss=1.8719e-01  Valid Loss=1.0702e-02  LR=1.00e-03
# Epoch  40/100  Loss=1.8718e-01  Valid Loss=1.0557e-02  LR=1.00e-03
# Epoch  50/100  Loss=1.8728e-01  Valid Loss=1.0545e-02  LR=1.00e-03
# Epoch  60/100  Loss=1.5846e-01  Valid Loss=7.2858e-03  LR=5.00e-04
# Epoch  70/100  Loss=1.5798e-01  Valid Loss=7.2281e-03  LR=5.00e-04
# Epoch  80/100  Loss=1.5956e-01  Valid Loss=7.3157e-03  LR=2.50e-04
# Epoch  90/100  Loss=1.4334e-01  Valid Loss=7.0971e-03  LR=2.50e-04
# Epoch 100/100  Loss=1.3751e-01  Valid Loss=6.9758e-03  LR=1.25e-04
#
# Best model from epoch 100 with validation loss: 6.9758e-03
# NMSE: -41.0096 dB
#
# ============================================================
# Pruning Iteration 7/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 79.04% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.9099e-01  Valid Loss=1.0533e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.6165e-01  Valid Loss=7.5634e-03  LR=5.00e-04
# Epoch  30/100  Loss=1.6468e-01  Valid Loss=7.4047e-03  LR=5.00e-04
# Epoch  40/100  Loss=1.6206e-01  Valid Loss=7.2352e-03  LR=5.00e-04
# Epoch  50/100  Loss=1.6146e-01  Valid Loss=7.1733e-03  LR=5.00e-04
# Epoch  60/100  Loss=1.6189e-01  Valid Loss=7.1584e-03  LR=5.00e-04
# Epoch  70/100  Loss=1.6138e-01  Valid Loss=7.1333e-03  LR=5.00e-04
# Epoch  80/100  Loss=1.6115e-01  Valid Loss=7.1094e-03  LR=5.00e-04
# Epoch  90/100  Loss=1.6079e-01  Valid Loss=7.0822e-03  LR=5.00e-04
# Epoch 100/100  Loss=1.6028e-01  Valid Loss=7.0665e-03  LR=5.00e-04
#
# Best model from epoch 100 with validation loss: 7.0665e-03
# NMSE: -40.9270 dB
#
# ============================================================
# Pruning Iteration 8/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 83.23% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.8427e-01  Valid Loss=1.0713e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.8787e-01  Valid Loss=1.0104e-02  LR=1.00e-03
# Epoch  30/100  Loss=1.8535e-01  Valid Loss=9.5516e-03  LR=1.00e-03
# Epoch  40/100  Loss=1.8348e-01  Valid Loss=9.2672e-03  LR=1.00e-03
# Epoch  50/100  Loss=1.8237e-01  Valid Loss=9.1073e-03  LR=1.00e-03
# Epoch  60/100  Loss=1.8138e-01  Valid Loss=9.0020e-03  LR=1.00e-03
# Epoch  70/100  Loss=1.8051e-01  Valid Loss=8.9088e-03  LR=1.00e-03
# Epoch  80/100  Loss=1.7980e-01  Valid Loss=8.8335e-03  LR=1.00e-03
# Epoch  90/100  Loss=1.7902e-01  Valid Loss=8.7505e-03  LR=1.00e-03
# Epoch 100/100  Loss=1.7849e-01  Valid Loss=8.6829e-03  LR=1.00e-03
#
# Best model from epoch 100 with validation loss: 8.6829e-03
# NMSE: -39.8559 dB
#
# ============================================================
# Pruning Iteration 9/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 86.60% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.0371e-01  Valid Loss=1.3701e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.8590e-01  Valid Loss=8.3445e-03  LR=1.00e-03
# Epoch  30/100  Loss=1.7845e-01  Valid Loss=8.0105e-03  LR=1.00e-03
# Epoch  40/100  Loss=1.7793e-01  Valid Loss=7.7401e-03  LR=1.00e-03
# Epoch  50/100  Loss=1.7732e-01  Valid Loss=7.5382e-03  LR=1.00e-03
# Epoch  60/100  Loss=1.7687e-01  Valid Loss=7.4053e-03  LR=1.00e-03
# Epoch  70/100  Loss=1.7575e-01  Valid Loss=7.3358e-03  LR=1.00e-03
# Epoch  80/100  Loss=1.7473e-01  Valid Loss=7.2855e-03  LR=1.00e-03
# Epoch  90/100  Loss=1.7389e-01  Valid Loss=7.2451e-03  LR=1.00e-03
# Epoch 100/100  Loss=1.7295e-01  Valid Loss=7.2110e-03  LR=1.00e-03
#
# Best model from epoch 100 with validation loss: 7.2110e-03
# NMSE: -40.8431 dB
#
# ============================================================
# Pruning Iteration 10/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 89.29% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.6077e-01  Valid Loss=1.1737e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.3487e-01  Valid Loss=1.0872e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.2570e-01  Valid Loss=1.0221e-02  LR=1.00e-03
# Epoch  40/100  Loss=2.2397e-01  Valid Loss=9.8743e-03  LR=1.00e-03
# Epoch  50/100  Loss=2.0958e-01  Valid Loss=9.4437e-03  LR=1.00e-03
# Epoch  60/100  Loss=2.0352e-01  Valid Loss=8.9866e-03  LR=1.00e-03
# Epoch  70/100  Loss=1.9555e-01  Valid Loss=8.6195e-03  LR=1.00e-03
# Epoch  80/100  Loss=1.8958e-01  Valid Loss=8.3168e-03  LR=1.00e-03
# Epoch  90/100  Loss=1.8495e-01  Valid Loss=8.0949e-03  LR=1.00e-03
# Epoch 100/100  Loss=1.8158e-01  Valid Loss=7.9457e-03  LR=1.00e-03
#
# Best model from epoch 100 with validation loss: 7.9457e-03
# NMSE: -40.5273 dB
#
# ============================================================
# Pruning Iteration 11/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 91.42% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.8016e-01  Valid Loss=1.3206e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.5083e-01  Valid Loss=1.1868e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.4553e-01  Valid Loss=1.1559e-02  LR=1.00e-03
# Epoch  40/100  Loss=2.4533e-01  Valid Loss=1.1399e-02  LR=1.00e-03
# Epoch  50/100  Loss=2.4235e-01  Valid Loss=1.1295e-02  LR=1.00e-03
# Epoch  60/100  Loss=2.4016e-01  Valid Loss=1.1210e-02  LR=1.00e-03
# Epoch  70/100  Loss=2.3863e-01  Valid Loss=1.1125e-02  LR=1.00e-03
# Epoch  80/100  Loss=2.3722e-01  Valid Loss=1.1064e-02  LR=1.00e-03
# Epoch  90/100  Loss=2.3620e-01  Valid Loss=1.1018e-02  LR=1.00e-03
# Epoch 100/100  Loss=2.3528e-01  Valid Loss=1.0982e-02  LR=1.00e-03
#
# Best model from epoch 100 with validation loss: 1.0982e-02
# NMSE: -39.1265 dB
#
# ============================================================
# Pruning Iteration 12/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 93.12% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.1266e-01  Valid Loss=1.4869e-02  LR=1.00e-03
# Epoch  20/100  Loss=3.0854e-01  Valid Loss=1.4148e-02  LR=1.00e-03
# Epoch  30/100  Loss=3.0287e-01  Valid Loss=1.3785e-02  LR=1.00e-03
# Epoch  40/100  Loss=2.9513e-01  Valid Loss=1.3729e-02  LR=1.00e-03
# Epoch  50/100  Loss=2.3008e-01  Valid Loss=1.0708e-02  LR=1.00e-03
# Epoch  60/100  Loss=2.2924e-01  Valid Loss=1.0775e-02  LR=1.00e-03
# Epoch  70/100  Loss=2.2700e-01  Valid Loss=1.0554e-02  LR=1.00e-03
# Epoch  80/100  Loss=2.1314e-01  Valid Loss=1.0472e-02  LR=5.00e-04
# Epoch  90/100  Loss=2.1502e-01  Valid Loss=1.0400e-02  LR=5.00e-04
# Epoch 100/100  Loss=2.1534e-01  Valid Loss=1.0375e-02  LR=5.00e-04
#
# Best model from epoch 100 with validation loss: 1.0375e-02
# NMSE: -39.3479 dB
#
# Parameter range: 194 - 2,820
# NMSE range: -41.01 - -39.13 dB

# %%
# 3.3 Linear Pruning - MultiLayerNetwork
print("\n" + "="*70)
print("Linear Pruning - MultiLayerNetwork")
print("="*70)

exp_linear_multi = LinearExperiment(
    nn_model=models['MultiLayer'],
    num_prune_iterations=12,
    prune_amount=0.2,
    retrain_epochs=retrain_epochs,
    training_dataset=dataManager.get_training_data(),
    valid_dataset=dataManager.get_validation_data(),
    test_dataset=dataManager.get_test_data()
)

# Run experiment and store results
initial_nmse = exp_linear_multi.original_nn_model.calculate_forward_nmse(exp_linear_multi.test_dataset)
prune_pcts, nmse_results, valid_losses, best_epochs, all_valid_losses = exp_linear_multi.prune()

# Calculate parameter counts
base_params = baseline_results['MultiLayer']['params']
param_counts = [base_params] + [calc_effective_params(base_params, pct) for pct in prune_pcts]

linear_pruning_results['MultiLayer'] = {
    'params': param_counts,
    'nmse': [initial_nmse] + nmse_results,
    'valid_losses': all_valid_losses,
    'best_epochs': best_epochs
}

print(f"\nParameter range: {min(param_counts):,} - {max(param_counts):,}")
print(f"NMSE range: {min([initial_nmse] + nmse_results):.2f} - {max([initial_nmse] + nmse_results):.2f} dB")
# Out:
# ======================================================================
# Linear Pruning - MultiLayerNetwork
# ======================================================================
#
# ============================================================
# Pruning Iteration 1/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 20.00% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.1112e-01  Valid Loss=1.2524e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.9110e-01  Valid Loss=1.1939e-02  LR=5.00e-04
# Epoch  30/100  Loss=1.9204e-01  Valid Loss=9.7383e-03  LR=2.50e-04
# Epoch  40/100  Loss=1.8492e-01  Valid Loss=1.1568e-02  LR=1.25e-04
# Epoch  50/100  Loss=1.6414e-01  Valid Loss=7.9646e-03  LR=1.25e-04
# Epoch  60/100  Loss=1.6758e-01  Valid Loss=8.0043e-03  LR=1.25e-04
# Epoch  70/100  Loss=1.5087e-01  Valid Loss=7.8054e-03  LR=6.25e-05
# Epoch  80/100  Loss=1.4651e-01  Valid Loss=7.8853e-03  LR=3.13e-05
# Epoch  90/100  Loss=1.4516e-01  Valid Loss=7.7317e-03  LR=1.56e-05
# Epoch 100/100  Loss=1.4273e-01  Valid Loss=7.6850e-03  LR=7.81e-06
#
# Best model from epoch 100 with validation loss: 7.6850e-03
# NMSE: -40.7358 dB
#
# ============================================================
# Pruning Iteration 2/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 36.00% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.4041e-01  Valid Loss=2.2339e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.8292e-01  Valid Loss=1.1430e-02  LR=5.00e-04
# Epoch  30/100  Loss=1.7115e-01  Valid Loss=8.2931e-03  LR=2.50e-04
# Epoch  40/100  Loss=1.7613e-01  Valid Loss=9.6978e-03  LR=1.25e-04
# Epoch  50/100  Loss=1.5473e-01  Valid Loss=7.7503e-03  LR=1.25e-04
# Epoch  60/100  Loss=1.4501e-01  Valid Loss=7.4409e-03  LR=6.25e-05
# Epoch  70/100  Loss=1.4566e-01  Valid Loss=7.4223e-03  LR=6.25e-05
# Epoch  80/100  Loss=1.4107e-01  Valid Loss=7.4816e-03  LR=3.13e-05
# Epoch  90/100  Loss=1.4180e-01  Valid Loss=7.5075e-03  LR=1.56e-05
# Epoch 100/100  Loss=1.4017e-01  Valid Loss=7.4280e-03  LR=1.56e-05
#
# Best model from epoch 68 with validation loss: 7.4207e-03
# NMSE: -40.8396 dB
#
# ============================================================
# Pruning Iteration 3/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 48.80% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.0214e-01  Valid Loss=2.2483e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.8510e-01  Valid Loss=1.1648e-02  LR=5.00e-04
# Epoch  30/100  Loss=1.8663e-01  Valid Loss=1.2068e-02  LR=5.00e-04
# Epoch  40/100  Loss=1.6996e-01  Valid Loss=7.7030e-03  LR=2.50e-04
# Epoch  50/100  Loss=1.7069e-01  Valid Loss=8.5418e-03  LR=1.25e-04
# Epoch  60/100  Loss=1.5175e-01  Valid Loss=7.6406e-03  LR=1.25e-04
# Epoch  70/100  Loss=1.4461e-01  Valid Loss=7.4678e-03  LR=6.25e-05
# Epoch  80/100  Loss=1.4465e-01  Valid Loss=7.4150e-03  LR=6.25e-05
# Epoch  90/100  Loss=1.4470e-01  Valid Loss=7.3918e-03  LR=6.25e-05
# Epoch 100/100  Loss=1.4451e-01  Valid Loss=7.3858e-03  LR=6.25e-05
#
# Best model from epoch 100 with validation loss: 7.3858e-03
# NMSE: -40.8557 dB
#
# ============================================================
# Pruning Iteration 4/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 59.05% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.3199e-01  Valid Loss=1.9335e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.8133e-01  Valid Loss=1.1312e-02  LR=5.00e-04
# Epoch  30/100  Loss=1.8221e-01  Valid Loss=1.0703e-02  LR=5.00e-04
# Epoch  40/100  Loss=1.9144e-01  Valid Loss=1.0905e-02  LR=2.50e-04
# Epoch  50/100  Loss=1.5927e-01  Valid Loss=7.5395e-03  LR=2.50e-04
# Epoch  60/100  Loss=1.4513e-01  Valid Loss=7.3644e-03  LR=1.25e-04
# Epoch  70/100  Loss=1.3869e-01  Valid Loss=7.3389e-03  LR=6.25e-05
# Epoch  80/100  Loss=1.3730e-01  Valid Loss=7.1977e-03  LR=3.13e-05
# Epoch  90/100  Loss=1.3741e-01  Valid Loss=7.2058e-03  LR=3.13e-05
# Epoch 100/100  Loss=1.3484e-01  Valid Loss=7.2010e-03  LR=1.56e-05
#
# Best model from epoch 84 with validation loss: 7.1900e-03
# NMSE: -41.0173 dB
#
# ============================================================
# Pruning Iteration 5/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 67.24% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.2641e-01  Valid Loss=1.3878e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.6963e-01  Valid Loss=1.5509e-02  LR=5.00e-04
# Epoch  30/100  Loss=1.8645e-01  Valid Loss=1.0876e-02  LR=5.00e-04
# Epoch  40/100  Loss=1.6068e-01  Valid Loss=7.6298e-03  LR=2.50e-04
# Epoch  50/100  Loss=1.6215e-01  Valid Loss=7.3608e-03  LR=2.50e-04
# Epoch  60/100  Loss=1.6245e-01  Valid Loss=7.2891e-03  LR=2.50e-04
# Epoch  70/100  Loss=1.6270e-01  Valid Loss=7.3877e-03  LR=1.25e-04
# Epoch  80/100  Loss=1.4574e-01  Valid Loss=7.2521e-03  LR=1.25e-04
# Epoch  90/100  Loss=1.4666e-01  Valid Loss=7.2557e-03  LR=1.25e-04
# Epoch 100/100  Loss=1.3974e-01  Valid Loss=7.2342e-03  LR=6.25e-05
#
# Best model from epoch 100 with validation loss: 7.2342e-03
# NMSE: -40.9251 dB
#
# ============================================================
# Pruning Iteration 6/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 73.79% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.6679e-01  Valid Loss=1.5904e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.4823e-01  Valid Loss=1.4942e-02  LR=1.00e-03
# Epoch  30/100  Loss=1.8489e-01  Valid Loss=8.9934e-03  LR=5.00e-04
# Epoch  40/100  Loss=1.8409e-01  Valid Loss=1.0484e-02  LR=2.50e-04
# Epoch  50/100  Loss=1.5900e-01  Valid Loss=7.5280e-03  LR=2.50e-04
# Epoch  60/100  Loss=1.5987e-01  Valid Loss=7.4032e-03  LR=2.50e-04
# Epoch  70/100  Loss=1.6073e-01  Valid Loss=7.2124e-03  LR=2.50e-04
# Epoch  80/100  Loss=1.5989e-01  Valid Loss=7.2242e-03  LR=2.50e-04
# Epoch  90/100  Loss=1.4380e-01  Valid Loss=7.2719e-03  LR=1.25e-04
# Epoch 100/100  Loss=1.3983e-01  Valid Loss=7.2250e-03  LR=6.25e-05
#
# Best model from epoch 73 with validation loss: 7.2100e-03
# NMSE: -40.8755 dB
#
# ============================================================
# Pruning Iteration 7/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 79.03% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.3022e-01  Valid Loss=1.1692e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.9385e-01  Valid Loss=1.1478e-02  LR=1.00e-03
# Epoch  30/100  Loss=1.9211e-01  Valid Loss=1.2186e-02  LR=1.00e-03
# Epoch  40/100  Loss=1.7157e-01  Valid Loss=8.3082e-03  LR=5.00e-04
# Epoch  50/100  Loss=1.5314e-01  Valid Loss=7.4455e-03  LR=2.50e-04
# Epoch  60/100  Loss=1.4497e-01  Valid Loss=7.2046e-03  LR=1.25e-04
# Epoch  70/100  Loss=1.4599e-01  Valid Loss=7.0848e-03  LR=1.25e-04
# Epoch  80/100  Loss=1.4609e-01  Valid Loss=7.0874e-03  LR=1.25e-04
# Epoch  90/100  Loss=1.4199e-01  Valid Loss=7.2244e-03  LR=6.25e-05
# Epoch 100/100  Loss=1.3963e-01  Valid Loss=7.0578e-03  LR=3.13e-05
#
# Best model from epoch 100 with validation loss: 7.0578e-03
# NMSE: -40.9255 dB
#
# ============================================================
# Pruning Iteration 8/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 83.23% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.1779e-01  Valid Loss=1.4322e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.3310e-01  Valid Loss=1.4183e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.1416e-01  Valid Loss=1.3700e-02  LR=1.00e-03
# Epoch  40/100  Loss=1.9449e-01  Valid Loss=1.3194e-02  LR=1.00e-03
# Epoch  50/100  Loss=1.9173e-01  Valid Loss=1.1877e-02  LR=1.00e-03
# Epoch  60/100  Loss=1.8679e-01  Valid Loss=1.2248e-02  LR=1.00e-03
# Epoch  70/100  Loss=1.6498e-01  Valid Loss=7.6891e-03  LR=5.00e-04
# Epoch  80/100  Loss=1.4865e-01  Valid Loss=7.1917e-03  LR=2.50e-04
# Epoch  90/100  Loss=1.4117e-01  Valid Loss=7.0916e-03  LR=1.25e-04
# Epoch 100/100  Loss=1.4267e-01  Valid Loss=6.9897e-03  LR=1.25e-04
#
# Best model from epoch 100 with validation loss: 6.9897e-03
# NMSE: -41.0211 dB
#
# ============================================================
# Pruning Iteration 9/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 86.58% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.9586e-01  Valid Loss=9.3047e-03  LR=1.00e-03
# Epoch  20/100  Loss=1.8174e-01  Valid Loss=9.6683e-03  LR=1.00e-03
# Epoch  30/100  Loss=1.6279e-01  Valid Loss=7.9802e-03  LR=5.00e-04
# Epoch  40/100  Loss=1.6403e-01  Valid Loss=7.5849e-03  LR=5.00e-04
# Epoch  50/100  Loss=1.6480e-01  Valid Loss=7.7373e-03  LR=5.00e-04
# Epoch  60/100  Loss=1.4884e-01  Valid Loss=7.3838e-03  LR=2.50e-04
# Epoch  70/100  Loss=1.5117e-01  Valid Loss=7.4483e-03  LR=1.25e-04
# Epoch  80/100  Loss=1.4194e-01  Valid Loss=7.3098e-03  LR=1.25e-04
# Epoch  90/100  Loss=1.4212e-01  Valid Loss=7.2220e-03  LR=1.25e-04
# Epoch 100/100  Loss=1.4193e-01  Valid Loss=7.1809e-03  LR=1.25e-04
#
# Best model from epoch 100 with validation loss: 7.1809e-03
# NMSE: -41.0453 dB
#
# ============================================================
# Pruning Iteration 10/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 89.26% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.2299e-01  Valid Loss=1.3396e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.8171e-01  Valid Loss=1.0834e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.0960e-01  Valid Loss=1.1122e-02  LR=1.00e-03
# Epoch  40/100  Loss=1.6275e-01  Valid Loss=7.2351e-03  LR=5.00e-04
# Epoch  50/100  Loss=1.4594e-01  Valid Loss=7.0699e-03  LR=2.50e-04
# Epoch  60/100  Loss=1.4936e-01  Valid Loss=6.9996e-03  LR=2.50e-04
# Epoch  70/100  Loss=1.4081e-01  Valid Loss=7.0543e-03  LR=1.25e-04
# Epoch  80/100  Loss=1.3881e-01  Valid Loss=6.9326e-03  LR=6.25e-05
# Epoch  90/100  Loss=1.3893e-01  Valid Loss=6.9539e-03  LR=3.13e-05
# Epoch 100/100  Loss=1.3663e-01  Valid Loss=6.9530e-03  LR=3.13e-05
#
# Best model from epoch 79 with validation loss: 6.9261e-03
# NMSE: -41.0995 dB
#
# ============================================================
# Pruning Iteration 11/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 91.41% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.1350e-01  Valid Loss=1.4321e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.1968e-01  Valid Loss=1.1085e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.0323e-01  Valid Loss=1.1453e-02  LR=1.00e-03
# Epoch  40/100  Loss=1.7879e-01  Valid Loss=8.1866e-03  LR=5.00e-04
# Epoch  50/100  Loss=1.8146e-01  Valid Loss=7.8298e-03  LR=5.00e-04
# Epoch  60/100  Loss=1.7956e-01  Valid Loss=7.6619e-03  LR=5.00e-04
# Epoch  70/100  Loss=1.7659e-01  Valid Loss=7.5514e-03  LR=5.00e-04
# Epoch  80/100  Loss=1.7804e-01  Valid Loss=7.6251e-03  LR=5.00e-04
# Epoch  90/100  Loss=1.5846e-01  Valid Loss=7.2689e-03  LR=2.50e-04
# Epoch 100/100  Loss=1.5961e-01  Valid Loss=7.2543e-03  LR=2.50e-04
#
# Best model from epoch 100 with validation loss: 7.2543e-03
# NMSE: -40.8547 dB
#
# ============================================================
# Pruning Iteration 12/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 93.13% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.4816e-01  Valid Loss=1.1896e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.9652e-01  Valid Loss=1.1110e-02  LR=1.00e-03
# Epoch  30/100  Loss=1.7530e-01  Valid Loss=8.0833e-03  LR=5.00e-04
# Epoch  40/100  Loss=1.7434e-01  Valid Loss=7.8453e-03  LR=5.00e-04
# Epoch  50/100  Loss=1.7853e-01  Valid Loss=7.6827e-03  LR=5.00e-04
# Epoch  60/100  Loss=1.7973e-01  Valid Loss=7.6738e-03  LR=5.00e-04
# Epoch  70/100  Loss=1.5640e-01  Valid Loss=7.5114e-03  LR=2.50e-04
# Epoch  80/100  Loss=1.5953e-01  Valid Loss=7.4721e-03  LR=2.50e-04
# Epoch  90/100  Loss=1.5110e-01  Valid Loss=7.6761e-03  LR=1.25e-04
# Epoch 100/100  Loss=1.4907e-01  Valid Loss=7.4019e-03  LR=6.25e-05
#
# Best model from epoch 100 with validation loss: 7.4019e-03
# NMSE: -40.8413 dB
#
# Parameter range: 739 - 10,768
# NMSE range: -41.10 - -40.42 dB

# %%
# 3.4 Linear Pruning - PGJANET
print("\n" + "="*70)
print("Linear Pruning - PGJANET")
print("="*70)

exp_linear_pgjanet = LinearExperiment(
    nn_model=models['PGJANET'],
    num_prune_iterations=12,
    prune_amount=0.2,
    retrain_epochs=retrain_epochs,
    training_dataset=dataManager.get_training_data(),
    valid_dataset=dataManager.get_validation_data(),
    test_dataset=dataManager.get_test_data()
)

# Run experiment and store results
initial_nmse = exp_linear_pgjanet.original_nn_model.calculate_forward_nmse(exp_linear_pgjanet.test_dataset)
prune_pcts, nmse_results, valid_losses, best_epochs, all_valid_losses = exp_linear_pgjanet.prune()

# Calculate parameter counts
base_params = baseline_results['PGJANET']['params']
param_counts = [base_params] + [calc_effective_params(base_params, pct) for pct in prune_pcts]

linear_pruning_results['PGJANET'] = {
    'params': param_counts,
    'nmse': [initial_nmse] + nmse_results,
    'valid_losses': all_valid_losses,
    'best_epochs': best_epochs
}

print(f"\nParameter range: {min(param_counts):,} - {max(param_counts):,}")
print(f"NMSE range: {min([initial_nmse] + nmse_results):.2f} - {max([initial_nmse] + nmse_results):.2f} dB")
# Out:
# ======================================================================
# Linear Pruning - PGJANET
# ======================================================================
#
# ============================================================
# Pruning Iteration 1/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 19.98% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=4.7545e-01  Valid Loss=3.1450e-02  LR=1.00e-03
# Epoch  20/100  Loss=4.1568e-01  Valid Loss=2.2446e-02  LR=5.00e-04
# Epoch  30/100  Loss=4.3126e-01  Valid Loss=3.2260e-02  LR=5.00e-04
# Epoch  40/100  Loss=3.9947e-01  Valid Loss=2.0331e-02  LR=2.50e-04
# Epoch  50/100  Loss=3.9036e-01  Valid Loss=2.9647e-02  LR=2.50e-04
# Epoch  60/100  Loss=3.8511e-01  Valid Loss=2.7021e-02  LR=1.25e-04
# Epoch  70/100  Loss=3.7500e-01  Valid Loss=2.2579e-02  LR=1.25e-04
# Epoch  80/100  Loss=3.7545e-01  Valid Loss=1.9385e-02  LR=1.25e-04
# Epoch  90/100  Loss=3.6520e-01  Valid Loss=2.0537e-02  LR=6.25e-05
# Epoch 100/100  Loss=3.6311e-01  Valid Loss=1.8256e-02  LR=3.13e-05
#
# Best model from epoch 97 with validation loss: 1.8037e-02
# NMSE: -36.6513 dB
#
# ============================================================
# Pruning Iteration 2/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 36.00% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=5.8737e-01  Valid Loss=4.0679e-02  LR=1.00e-03
# Epoch  20/100  Loss=4.9515e-01  Valid Loss=2.8161e-02  LR=1.00e-03
# Epoch  30/100  Loss=4.6996e-01  Valid Loss=2.2414e-02  LR=1.00e-03
# Epoch  40/100  Loss=4.2542e-01  Valid Loss=5.6876e-02  LR=1.00e-03
# Epoch  50/100  Loss=4.1422e-01  Valid Loss=1.9189e-02  LR=1.00e-03
# Epoch  60/100  Loss=4.0736e-01  Valid Loss=2.3903e-02  LR=1.00e-03
# Epoch  70/100  Loss=3.7250e-01  Valid Loss=1.9004e-02  LR=5.00e-04
# Epoch  80/100  Loss=3.7059e-01  Valid Loss=2.1344e-02  LR=5.00e-04
# Epoch  90/100  Loss=3.6621e-01  Valid Loss=2.0578e-02  LR=5.00e-04
# Epoch 100/100  Loss=3.4702e-01  Valid Loss=1.8613e-02  LR=2.50e-04
#
# Best model from epoch 85 with validation loss: 1.7928e-02
# NMSE: -36.7163 dB
#
# ============================================================
# Pruning Iteration 3/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 48.82% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.1317e+00  Valid Loss=5.1066e-02  LR=1.00e-03
# Epoch  20/100  Loss=6.8603e-01  Valid Loss=3.0057e-02  LR=1.00e-03
# Epoch  30/100  Loss=5.3335e-01  Valid Loss=2.7503e-02  LR=1.00e-03
# Epoch  40/100  Loss=4.7776e-01  Valid Loss=2.5798e-02  LR=1.00e-03
# Epoch  50/100  Loss=4.3911e-01  Valid Loss=2.2549e-02  LR=1.00e-03
# Epoch  60/100  Loss=3.9709e-01  Valid Loss=2.0881e-02  LR=5.00e-04
# Epoch  70/100  Loss=3.8615e-01  Valid Loss=2.1761e-02  LR=5.00e-04
# Epoch  80/100  Loss=3.8052e-01  Valid Loss=2.0214e-02  LR=5.00e-04
# Epoch  90/100  Loss=3.6458e-01  Valid Loss=1.7877e-02  LR=2.50e-04
# Epoch 100/100  Loss=3.6015e-01  Valid Loss=1.7133e-02  LR=1.25e-04
#
# Best model from epoch 88 with validation loss: 1.7089e-02
# NMSE: -36.5560 dB
#
# ============================================================
# Pruning Iteration 4/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 59.08% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.0697e+00  Valid Loss=4.8714e-02  LR=1.00e-03
# Epoch  20/100  Loss=7.0125e-01  Valid Loss=3.7133e-02  LR=1.00e-03
# Epoch  30/100  Loss=5.9555e-01  Valid Loss=2.8662e-02  LR=1.00e-03
# Epoch  40/100  Loss=5.3690e-01  Valid Loss=3.6741e-02  LR=1.00e-03
# Epoch  50/100  Loss=4.7520e-01  Valid Loss=2.8244e-02  LR=1.00e-03
# Epoch  60/100  Loss=4.4440e-01  Valid Loss=3.1492e-02  LR=5.00e-04
# Epoch  70/100  Loss=4.2825e-01  Valid Loss=2.0199e-02  LR=5.00e-04
# Epoch  80/100  Loss=4.0824e-01  Valid Loss=2.1465e-02  LR=2.50e-04
# Epoch  90/100  Loss=4.0104e-01  Valid Loss=1.9429e-02  LR=2.50e-04
# Epoch 100/100  Loss=3.9493e-01  Valid Loss=1.9489e-02  LR=2.50e-04
#
# Best model from epoch 95 with validation loss: 1.7516e-02
# NMSE: -36.3392 dB
#
# ============================================================
# Pruning Iteration 5/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 67.25% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.1597e+00  Valid Loss=5.4881e-02  LR=1.00e-03
# Epoch  20/100  Loss=7.6965e-01  Valid Loss=4.3783e-02  LR=1.00e-03
# Epoch  30/100  Loss=6.4942e-01  Valid Loss=4.7627e-02  LR=1.00e-03
# Epoch  40/100  Loss=5.8113e-01  Valid Loss=3.4036e-02  LR=1.00e-03
# Epoch  50/100  Loss=5.3301e-01  Valid Loss=3.0636e-02  LR=1.00e-03
# Epoch  60/100  Loss=4.8929e-01  Valid Loss=3.0402e-02  LR=1.00e-03
# Epoch  70/100  Loss=4.7061e-01  Valid Loss=4.0030e-02  LR=1.00e-03
# Epoch  80/100  Loss=4.8390e-01  Valid Loss=2.1919e-02  LR=1.00e-03
# Epoch  90/100  Loss=4.5152e-01  Valid Loss=2.4098e-02  LR=1.00e-03
# Epoch 100/100  Loss=4.0750e-01  Valid Loss=2.0802e-02  LR=5.00e-04
#
# Best model from epoch 96 with validation loss: 1.9740e-02
# NMSE: -36.1242 dB
#
# ============================================================
# Pruning Iteration 6/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 73.82% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=4.2077e+00  Valid Loss=1.7768e-01  LR=1.00e-03
# Epoch  20/100  Loss=1.9182e+00  Valid Loss=8.1073e-02  LR=1.00e-03
# Epoch  30/100  Loss=1.2227e+00  Valid Loss=5.6482e-02  LR=1.00e-03
# Epoch  40/100  Loss=9.4650e-01  Valid Loss=5.6179e-02  LR=1.00e-03
# Epoch  50/100  Loss=7.5764e-01  Valid Loss=4.0367e-02  LR=1.00e-03
# Epoch  60/100  Loss=6.7214e-01  Valid Loss=3.2936e-02  LR=1.00e-03
# Epoch  70/100  Loss=5.8767e-01  Valid Loss=3.0838e-02  LR=1.00e-03
# Epoch  80/100  Loss=5.5752e-01  Valid Loss=6.4602e-02  LR=1.00e-03
# Epoch  90/100  Loss=5.2692e-01  Valid Loss=3.0039e-02  LR=1.00e-03
# Epoch 100/100  Loss=5.1095e-01  Valid Loss=2.4426e-02  LR=1.00e-03
#
# Best model from epoch 92 with validation loss: 2.2827e-02
# NMSE: -35.5923 dB
#
# ============================================================
# Pruning Iteration 7/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 79.06% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.0353e+00  Valid Loss=8.4465e-02  LR=1.00e-03
# Epoch  20/100  Loss=9.5052e-01  Valid Loss=4.6969e-02  LR=1.00e-03
# Epoch  30/100  Loss=7.5829e-01  Valid Loss=3.5316e-02  LR=1.00e-03
# Epoch  40/100  Loss=6.9317e-01  Valid Loss=3.1814e-02  LR=1.00e-03
# Epoch  50/100  Loss=6.4218e-01  Valid Loss=3.3587e-02  LR=1.00e-03
# Epoch  60/100  Loss=6.2010e-01  Valid Loss=3.4589e-02  LR=1.00e-03
# Epoch  70/100  Loss=5.5699e-01  Valid Loss=2.6716e-02  LR=5.00e-04
# Epoch  80/100  Loss=5.4242e-01  Valid Loss=3.5407e-02  LR=5.00e-04
# Epoch  90/100  Loss=5.2745e-01  Valid Loss=2.4976e-02  LR=2.50e-04
# Epoch 100/100  Loss=5.1944e-01  Valid Loss=2.3944e-02  LR=2.50e-04
#
# Best model from epoch 100 with validation loss: 2.3944e-02
# NMSE: -35.3382 dB
#
# ============================================================
# Pruning Iteration 8/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 83.23% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.1065e+01  Valid Loss=4.3349e-01  LR=1.00e-03
# Epoch  20/100  Loss=5.4968e+00  Valid Loss=2.4200e-01  LR=1.00e-03
# Epoch  30/100  Loss=3.7191e+00  Valid Loss=1.6206e-01  LR=1.00e-03
# Epoch  40/100  Loss=2.7099e+00  Valid Loss=1.1451e-01  LR=1.00e-03
# Epoch  50/100  Loss=2.0817e+00  Valid Loss=9.7511e-02  LR=1.00e-03
# Epoch  60/100  Loss=1.6887e+00  Valid Loss=7.9502e-02  LR=1.00e-03
# Epoch  70/100  Loss=1.3052e+00  Valid Loss=6.2860e-02  LR=1.00e-03
# Epoch  80/100  Loss=1.1036e+00  Valid Loss=4.8391e-02  LR=1.00e-03
# Epoch  90/100  Loss=9.3543e-01  Valid Loss=3.9479e-02  LR=1.00e-03
# Epoch 100/100  Loss=8.6705e-01  Valid Loss=5.1130e-02  LR=1.00e-03
#
# Best model from epoch 96 with validation loss: 3.7471e-02
# NMSE: -32.9834 dB
#
# ============================================================
# Pruning Iteration 9/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 86.59% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.4349e+02  Valid Loss=6.0009e+00  LR=1.00e-03
# Epoch  20/100  Loss=4.7664e+01  Valid Loss=2.1851e+00  LR=1.00e-03
# Epoch  30/100  Loss=2.5001e+01  Valid Loss=1.1206e+00  LR=1.00e-03
# Epoch  40/100  Loss=1.6366e+01  Valid Loss=7.9281e-01  LR=1.00e-03
# Epoch  50/100  Loss=1.1964e+01  Valid Loss=5.3288e-01  LR=1.00e-03
# Epoch  60/100  Loss=8.9655e+00  Valid Loss=4.2232e-01  LR=1.00e-03
# Epoch  70/100  Loss=7.0644e+00  Valid Loss=3.3384e-01  LR=1.00e-03
# Epoch  80/100  Loss=5.9683e+00  Valid Loss=2.9908e-01  LR=1.00e-03
# Epoch  90/100  Loss=4.9608e+00  Valid Loss=2.6648e-01  LR=1.00e-03
# Epoch 100/100  Loss=4.1409e+00  Valid Loss=2.0704e-01  LR=1.00e-03
#
# Best model from epoch 98 with validation loss: 2.0328e-01
# NMSE: -26.1304 dB
#
# ============================================================
# Pruning Iteration 10/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 89.26% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=8.8817e+02  Valid Loss=4.4103e+01  LR=1.00e-03
# Epoch  20/100  Loss=8.8625e+02  Valid Loss=4.2682e+01  LR=5.00e-04
# Epoch  30/100  Loss=8.8506e+02  Valid Loss=4.2449e+01  LR=2.50e-04
# Epoch  40/100  Loss=8.8482e+02  Valid Loss=4.2566e+01  LR=1.25e-04
# Epoch  50/100  Loss=8.8470e+02  Valid Loss=4.2421e+01  LR=1.25e-04
# Epoch  60/100  Loss=8.8490e+02  Valid Loss=4.2414e+01  LR=1.25e-04
# Epoch  70/100  Loss=8.8450e+02  Valid Loss=4.2433e+01  LR=6.25e-05
# Epoch  80/100  Loss=8.8423e+02  Valid Loss=4.2446e+01  LR=3.13e-05
# Epoch  90/100  Loss=8.8416e+02  Valid Loss=4.2417e+01  LR=1.56e-05
# Epoch 100/100  Loss=8.8413e+02  Valid Loss=4.2430e+01  LR=7.81e-06
#
# Best model from epoch 53 with validation loss: 4.2239e+01
# NMSE: -3.0516 dB
#
# ============================================================
# Pruning Iteration 11/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 91.40% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.7729e+03  Valid Loss=8.6131e+01  LR=1.00e-03
# Epoch  20/100  Loss=1.7713e+03  Valid Loss=8.6286e+01  LR=5.00e-04
# Epoch  30/100  Loss=1.7702e+03  Valid Loss=8.6435e+01  LR=2.50e-04
# Epoch  40/100  Loss=1.7699e+03  Valid Loss=8.6162e+01  LR=1.25e-04
# Epoch  50/100  Loss=1.7700e+03  Valid Loss=8.6386e+01  LR=6.25e-05
# Epoch  60/100  Loss=1.7697e+03  Valid Loss=8.6246e+01  LR=3.13e-05
# Epoch  70/100  Loss=1.7696e+03  Valid Loss=8.6267e+01  LR=1.56e-05
# Epoch  80/100  Loss=1.7695e+03  Valid Loss=8.6289e+01  LR=7.81e-06
# Epoch  90/100  Loss=1.7695e+03  Valid Loss=8.6259e+01  LR=3.91e-06
# Epoch 100/100  Loss=1.7695e+03  Valid Loss=8.6268e+01  LR=1.95e-06
#
# Best model from epoch 1 with validation loss: 8.5493e+01
# NMSE: 0.0612 dB
#
# ============================================================
# Pruning Iteration 12/12
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 93.11% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.7717e+03  Valid Loss=8.6131e+01  LR=1.00e-03
# Epoch  20/100  Loss=1.7716e+03  Valid Loss=8.6845e+01  LR=1.00e-03
# Epoch  30/100  Loss=1.7705e+03  Valid Loss=8.6119e+01  LR=1.00e-03
# Epoch  40/100  Loss=1.7700e+03  Valid Loss=8.6202e+01  LR=5.00e-04
# Epoch  50/100  Loss=1.7693e+03  Valid Loss=8.6302e+01  LR=2.50e-04
# Epoch  60/100  Loss=1.7694e+03  Valid Loss=8.6262e+01  LR=1.25e-04
# Epoch  70/100  Loss=1.7691e+03  Valid Loss=8.6234e+01  LR=6.25e-05
# Epoch  80/100  Loss=1.7689e+03  Valid Loss=8.6219e+01  LR=3.13e-05
# Epoch  90/100  Loss=1.7689e+03  Valid Loss=8.6262e+01  LR=1.56e-05
# Epoch 100/100  Loss=1.7689e+03  Valid Loss=8.6239e+01  LR=1.56e-05
#
# Best model from epoch 24 with validation loss: 8.5716e+01
# NMSE: 0.0109 dB
#
# Parameter range: 128 - 1,872
# NMSE range: -36.72 - 0.06 dB

# %% [markdown]
# ## 4. Node Pruning Experiments
#
# Running node-based pruning on all network architectures.

# %%
# Store node pruning experiment results
node_pruning_results = {}

print("\n" + "="*70)
print("NODE PRUNING EXPERIMENTS")
print("="*70)
# Out:
# ======================================================================
# NODE PRUNING EXPERIMENTS
# ======================================================================

# %%
# 4.1 Node Pruning - OneLayerNetwork
print("\n" + "="*70)
print("Node Pruning - OneLayerNetwork")
print("="*70)

exp_node_one = NodePruningExperiment(
    nn_model=models['OneLayer'],
    num_prune_iterations=12,
    prune_amount=0.2,
    retrain_epochs=retrain_epochs,
    training_dataset=dataManager.get_training_data(),
    valid_dataset=dataManager.get_validation_data(),
    test_dataset=dataManager.get_test_data()
)

# Run experiment and store results
initial_nmse = exp_node_one.original_nn_model.calculate_forward_nmse(exp_node_one.test_dataset)
prune_pcts, nmse_results, valid_losses, best_epochs, all_valid_losses = exp_node_one.prune()

# Calculate parameter counts
base_params = baseline_results['OneLayer']['params']
param_counts = [base_params] + [calc_effective_params(base_params, pct) for pct in prune_pcts]

node_pruning_results['OneLayer'] = {
    'params': param_counts,
    'nmse': [initial_nmse] + nmse_results,
    'valid_losses': all_valid_losses,
    'best_epochs': best_epochs
}

print(f"\nParameter range: {min(param_counts):,} - {max(param_counts):,}")
print(f"NMSE range: {min([initial_nmse] + nmse_results):.2f} - {max([initial_nmse] + nmse_results):.2f} dB")
# Out:
# ======================================================================
# Node Pruning - OneLayerNetwork
# ======================================================================
#
# ============================================================
# Pruning Iteration 1/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 2 hidden nodes (with forward connections)
# Current pruning: 16.67% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.2859e-01  Valid Loss=1.3049e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.8249e-01  Valid Loss=8.3946e-03  LR=5.00e-04
# Epoch  30/100  Loss=1.8460e-01  Valid Loss=8.0892e-03  LR=5.00e-04
# Epoch  40/100  Loss=1.7967e-01  Valid Loss=7.7941e-03  LR=5.00e-04
# Epoch  50/100  Loss=1.7871e-01  Valid Loss=7.8989e-03  LR=5.00e-04
# Epoch  60/100  Loss=1.5539e-01  Valid Loss=8.0477e-03  LR=2.50e-04
# Epoch  70/100  Loss=1.4925e-01  Valid Loss=7.7602e-03  LR=1.25e-04
# Epoch  80/100  Loss=1.4576e-01  Valid Loss=7.5252e-03  LR=6.25e-05
# Epoch  90/100  Loss=1.4596e-01  Valid Loss=7.5162e-03  LR=6.25e-05
# Epoch 100/100  Loss=1.4272e-01  Valid Loss=7.5469e-03  LR=3.13e-05
#
# Best model from epoch 85 with validation loss: 7.5126e-03
# NMSE: -40.6937 dB
#
# ============================================================
# Pruning Iteration 2/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 2 hidden nodes (with forward connections)
# Current pruning: 33.33% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.1438e-01  Valid Loss=1.3242e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.7900e-01  Valid Loss=8.3159e-03  LR=5.00e-04
# Epoch  30/100  Loss=1.8175e-01  Valid Loss=8.0443e-03  LR=5.00e-04
# Epoch  40/100  Loss=1.7954e-01  Valid Loss=7.7619e-03  LR=5.00e-04
# Epoch  50/100  Loss=1.7460e-01  Valid Loss=7.7122e-03  LR=5.00e-04
# Epoch  60/100  Loss=1.5269e-01  Valid Loss=7.9157e-03  LR=2.50e-04
# Epoch  70/100  Loss=1.4713e-01  Valid Loss=7.6571e-03  LR=1.25e-04
# Epoch  80/100  Loss=1.4460e-01  Valid Loss=7.4339e-03  LR=6.25e-05
# Epoch  90/100  Loss=1.4414e-01  Valid Loss=7.4049e-03  LR=6.25e-05
# Epoch 100/100  Loss=1.4204e-01  Valid Loss=7.4406e-03  LR=3.13e-05
#
# Best model from epoch 89 with validation loss: 7.4045e-03
# NMSE: -40.7678 dB
#
# ============================================================
# Pruning Iteration 3/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 1 hidden nodes (with forward connections)
# Current pruning: 41.67% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.0371e-01  Valid Loss=1.0021e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.6738e-01  Valid Loss=8.4618e-03  LR=5.00e-04
# Epoch  30/100  Loss=1.7863e-01  Valid Loss=8.5278e-03  LR=5.00e-04
# Epoch  40/100  Loss=1.5578e-01  Valid Loss=8.0352e-03  LR=2.50e-04
# Epoch  50/100  Loss=1.5695e-01  Valid Loss=7.8742e-03  LR=2.50e-04
# Epoch  60/100  Loss=1.5792e-01  Valid Loss=7.8061e-03  LR=2.50e-04
# Epoch  70/100  Loss=1.5772e-01  Valid Loss=7.7670e-03  LR=2.50e-04
# Epoch  80/100  Loss=1.5714e-01  Valid Loss=7.7315e-03  LR=2.50e-04
# Epoch  90/100  Loss=1.5668e-01  Valid Loss=7.7239e-03  LR=2.50e-04
# Epoch 100/100  Loss=1.5620e-01  Valid Loss=7.7110e-03  LR=2.50e-04
#
# Best model from epoch 97 with validation loss: 7.7046e-03
# NMSE: -40.6917 dB
#
# ============================================================
# Pruning Iteration 4/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 1 hidden nodes (with forward connections)
# Current pruning: 50.00% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.3268e-01  Valid Loss=1.6258e-02  LR=1.00e-03
# Epoch  20/100  Loss=3.0777e-01  Valid Loss=1.4420e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.1581e-01  Valid Loss=1.0738e-02  LR=1.00e-03
# Epoch  40/100  Loss=2.1899e-01  Valid Loss=1.1034e-02  LR=5.00e-04
# Epoch  50/100  Loss=1.8573e-01  Valid Loss=9.3669e-03  LR=5.00e-04
# Epoch  60/100  Loss=1.8598e-01  Valid Loss=9.1038e-03  LR=5.00e-04
# Epoch  70/100  Loss=1.8802e-01  Valid Loss=9.1319e-03  LR=2.50e-04
# Epoch  80/100  Loss=1.6959e-01  Valid Loss=8.9052e-03  LR=2.50e-04
# Epoch  90/100  Loss=1.6968e-01  Valid Loss=8.7415e-03  LR=2.50e-04
# Epoch 100/100  Loss=1.6946e-01  Valid Loss=8.6746e-03  LR=2.50e-04
#
# Best model from epoch 100 with validation loss: 8.6746e-03
# NMSE: -40.1711 dB
#
# ============================================================
# Pruning Iteration 5/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 1 hidden nodes (with forward connections)
# Current pruning: 58.33% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.7911e-01  Valid Loss=1.4665e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.7956e-01  Valid Loss=1.4320e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.7840e-01  Valid Loss=1.3712e-02  LR=1.00e-03
# Epoch  40/100  Loss=2.7602e-01  Valid Loss=1.3393e-02  LR=1.00e-03
# Epoch  50/100  Loss=2.7317e-01  Valid Loss=1.3154e-02  LR=1.00e-03
# Epoch  60/100  Loss=2.7124e-01  Valid Loss=1.3005e-02  LR=1.00e-03
# Epoch  70/100  Loss=2.6942e-01  Valid Loss=1.2899e-02  LR=1.00e-03
# Epoch  80/100  Loss=2.6781e-01  Valid Loss=1.2796e-02  LR=1.00e-03
# Epoch  90/100  Loss=2.6652e-01  Valid Loss=1.2705e-02  LR=1.00e-03
# Epoch 100/100  Loss=2.6474e-01  Valid Loss=1.2623e-02  LR=1.00e-03
#
# Best model from epoch 100 with validation loss: 1.2623e-02
# NMSE: -38.3157 dB
#
# ============================================================
# Pruning Iteration 6/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 1 hidden nodes (with forward connections)
# Current pruning: 66.67% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.0060e-01  Valid Loss=1.4396e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.5032e-01  Valid Loss=1.2465e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.3305e-01  Valid Loss=1.1141e-02  LR=1.00e-03
# Epoch  40/100  Loss=2.2660e-01  Valid Loss=1.1014e-02  LR=1.00e-03
# Epoch  50/100  Loss=2.3279e-01  Valid Loss=1.0701e-02  LR=1.00e-03
# Epoch  60/100  Loss=2.2568e-01  Valid Loss=1.0865e-02  LR=1.00e-03
# Epoch  70/100  Loss=2.1185e-01  Valid Loss=1.0228e-02  LR=1.00e-03
# Epoch  80/100  Loss=2.1466e-01  Valid Loss=9.7161e-03  LR=1.00e-03
# Epoch  90/100  Loss=2.1284e-01  Valid Loss=9.4437e-03  LR=1.00e-03
# Epoch 100/100  Loss=2.0933e-01  Valid Loss=9.2337e-03  LR=1.00e-03
#
# Best model from epoch 100 with validation loss: 9.2337e-03
# NMSE: -39.4962 dB
#
# ============================================================
# Pruning Iteration 7/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 1 hidden nodes (with forward connections)
# Current pruning: 75.00% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.6427e-01  Valid Loss=1.2432e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.4579e-01  Valid Loss=1.1832e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.5000e-01  Valid Loss=1.1762e-02  LR=1.00e-03
# Epoch  40/100  Loss=2.4701e-01  Valid Loss=1.1575e-02  LR=1.00e-03
# Epoch  50/100  Loss=2.4289e-01  Valid Loss=1.1531e-02  LR=1.00e-03
# Epoch  60/100  Loss=2.4059e-01  Valid Loss=1.1340e-02  LR=1.00e-03
# Epoch  70/100  Loss=2.4122e-01  Valid Loss=1.1118e-02  LR=1.00e-03
# Epoch  80/100  Loss=2.4004e-01  Valid Loss=1.0971e-02  LR=1.00e-03
# Epoch  90/100  Loss=2.3894e-01  Valid Loss=1.0884e-02  LR=1.00e-03
# Epoch 100/100  Loss=2.3760e-01  Valid Loss=1.0806e-02  LR=1.00e-03
#
# Best model from epoch 100 with validation loss: 1.0806e-02
# NMSE: -38.8156 dB
#
# ============================================================
# Pruning Iteration 8/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 1 hidden nodes (with forward connections)
# Current pruning: 83.33% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=4.2275e-01  Valid Loss=1.7713e-02  LR=1.00e-03
# Epoch  20/100  Loss=3.8546e-01  Valid Loss=1.6183e-02  LR=1.00e-03
# Epoch  30/100  Loss=3.7450e-01  Valid Loss=1.5790e-02  LR=1.00e-03
# Epoch  40/100  Loss=3.6921e-01  Valid Loss=1.5606e-02  LR=1.00e-03
# Epoch  50/100  Loss=3.6593e-01  Valid Loss=1.5493e-02  LR=1.00e-03
# Epoch  60/100  Loss=3.6361e-01  Valid Loss=1.5413e-02  LR=1.00e-03
# Epoch  70/100  Loss=3.6187e-01  Valid Loss=1.5356e-02  LR=1.00e-03
# Epoch  80/100  Loss=3.6051e-01  Valid Loss=1.5312e-02  LR=1.00e-03
# Epoch  90/100  Loss=3.5942e-01  Valid Loss=1.5278e-02  LR=1.00e-03
# Epoch 100/100  Loss=3.5851e-01  Valid Loss=1.5250e-02  LR=1.00e-03
#
# Best model from epoch 100 with validation loss: 1.5250e-02
# NMSE: -36.8324 dB
#
# ============================================================
# Pruning Iteration 9/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 1 hidden nodes (with forward connections)
# Current pruning: 91.67% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=5.8168e+00  Valid Loss=2.5408e-01  LR=1.00e-03
# Epoch  20/100  Loss=2.4977e+00  Valid Loss=1.2043e-01  LR=1.00e-03
# Epoch  30/100  Loss=1.9750e+00  Valid Loss=9.5576e-02  LR=1.00e-03
# Epoch  40/100  Loss=1.6101e+00  Valid Loss=7.6498e-02  LR=1.00e-03
# Epoch  50/100  Loss=1.3966e+00  Valid Loss=6.5692e-02  LR=1.00e-03
# Epoch  60/100  Loss=1.2931e+00  Valid Loss=6.0234e-02  LR=1.00e-03
# Epoch  70/100  Loss=1.2614e+00  Valid Loss=5.8220e-02  LR=1.00e-03
# Epoch  80/100  Loss=1.2565e+00  Valid Loss=5.7435e-02  LR=1.00e-03
# Epoch  90/100  Loss=1.2534e+00  Valid Loss=5.7148e-02  LR=1.00e-03
# Epoch 100/100  Loss=1.2497e+00  Valid Loss=5.6947e-02  LR=1.00e-03
#
# Best model from epoch 100 with validation loss: 5.6947e-02
# NMSE: -31.6046 dB
#
# ============================================================
# Pruning Iteration 10/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 1 hidden nodes (with forward connections)
# Current pruning: 100.00% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.6406e+02  Valid Loss=1.7415e+01  LR=1.00e-03
# Epoch  20/100  Loss=3.5733e+02  Valid Loss=1.7302e+01  LR=1.00e-03
# Epoch  30/100  Loss=3.5717e+02  Valid Loss=1.7298e+01  LR=5.00e-04
# Epoch  40/100  Loss=3.5703e+02  Valid Loss=1.7295e+01  LR=2.50e-04
# Epoch  50/100  Loss=3.5695e+02  Valid Loss=1.7293e+01  LR=1.25e-04
# Epoch  60/100  Loss=3.5690e+02  Valid Loss=1.7292e+01  LR=6.25e-05
# Epoch  70/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  80/100  Loss=3.5685e+02  Valid Loss=1.7291e+01  LR=1.56e-05
# Epoch  90/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=7.81e-06
# Epoch 100/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=7.81e-06
#
# Best model from epoch 13 with validation loss: 1.7275e+01
# NMSE: -7.4601 dB
#
# ============================================================
# Pruning Iteration 11/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# All hidden nodes are already pruned.
# Current pruning: 100.00% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.5774e+02  Valid Loss=1.7317e+01  LR=1.00e-03
# Epoch  20/100  Loss=3.5729e+02  Valid Loss=1.7302e+01  LR=5.00e-04
# Epoch  30/100  Loss=3.5707e+02  Valid Loss=1.7296e+01  LR=2.50e-04
# Epoch  40/100  Loss=3.5695e+02  Valid Loss=1.7293e+01  LR=1.25e-04
# Epoch  50/100  Loss=3.5690e+02  Valid Loss=1.7292e+01  LR=6.25e-05
# Epoch  60/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  70/100  Loss=3.5685e+02  Valid Loss=1.7291e+01  LR=1.56e-05
# Epoch  80/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=7.81e-06
# Epoch  90/100  Loss=3.5684e+02  Valid Loss=1.7290e+01  LR=3.91e-06
# Epoch 100/100  Loss=3.5684e+02  Valid Loss=1.7290e+01  LR=1.95e-06
#
# Best model from epoch 1 with validation loss: 1.7288e+01
# NMSE: -7.4734 dB
#
# ============================================================
# Pruning Iteration 12/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# All hidden nodes are already pruned.
# Current pruning: 100.00% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.5774e+02  Valid Loss=1.7317e+01  LR=1.00e-03
# Epoch  20/100  Loss=3.5729e+02  Valid Loss=1.7302e+01  LR=5.00e-04
# Epoch  30/100  Loss=3.5707e+02  Valid Loss=1.7296e+01  LR=2.50e-04
# Epoch  40/100  Loss=3.5706e+02  Valid Loss=1.7295e+01  LR=2.50e-04
# Epoch  50/100  Loss=3.5695e+02  Valid Loss=1.7293e+01  LR=1.25e-04
# Epoch  60/100  Loss=3.5695e+02  Valid Loss=1.7292e+01  LR=1.25e-04
# Epoch  70/100  Loss=3.5689e+02  Valid Loss=1.7291e+01  LR=6.25e-05
# Epoch  80/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  90/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=1.56e-05
# Epoch 100/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=7.81e-06
#
# Best model from epoch 100 with validation loss: 1.7290e+01
# NMSE: -7.4750 dB
#
# Parameter range: 0 - 960
# NMSE range: -40.77 - -7.46 dB

# %%
# 4.2 Node Pruning - ThreeLayerNetwork
print("\n" + "="*70)
print("Node Pruning - ThreeLayerNetwork")
print("="*70)

exp_node_three = NodePruningExperiment(
    nn_model=models['ThreeLayer'],
    num_prune_iterations=12,
    prune_amount=0.2,
    retrain_epochs=retrain_epochs,
    training_dataset=dataManager.get_training_data(),
    valid_dataset=dataManager.get_validation_data(),
    test_dataset=dataManager.get_test_data()
)

# Run experiment and store results
initial_nmse = exp_node_three.original_nn_model.calculate_forward_nmse(exp_node_three.test_dataset)
prune_pcts, nmse_results, valid_losses, best_epochs, all_valid_losses = exp_node_three.prune()

# Calculate parameter counts
base_params = baseline_results['ThreeLayer']['params']
param_counts = [base_params] + [calc_effective_params(base_params, pct) for pct in prune_pcts]

node_pruning_results['ThreeLayer'] = {
    'params': param_counts,
    'nmse': [initial_nmse] + nmse_results,
    'valid_losses': all_valid_losses,
    'best_epochs': best_epochs
}

print(f"\nParameter range: {min(param_counts):,} - {max(param_counts):,}")
print(f"NMSE range: {min([initial_nmse] + nmse_results):.2f} - {max([initial_nmse] + nmse_results):.2f} dB")
# Out:
# ======================================================================
# Node Pruning - ThreeLayerNetwork
# ======================================================================
#
# ============================================================
# Pruning Iteration 1/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 9 hidden nodes (with forward connections)
# Current pruning: 20.32% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.3634e-01  Valid Loss=2.2742e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.1294e-01  Valid Loss=1.0769e-02  LR=5.00e-04
# Epoch  30/100  Loss=2.4524e-01  Valid Loss=1.1993e-02  LR=5.00e-04
# Epoch  40/100  Loss=1.8229e-01  Valid Loss=8.9185e-03  LR=2.50e-04
# Epoch  50/100  Loss=1.6671e-01  Valid Loss=8.3746e-03  LR=1.25e-04
# Epoch  60/100  Loss=1.5759e-01  Valid Loss=7.8624e-03  LR=6.25e-05
# Epoch  70/100  Loss=1.5423e-01  Valid Loss=7.6499e-03  LR=3.13e-05
# Epoch  80/100  Loss=1.5429e-01  Valid Loss=7.6586e-03  LR=3.13e-05
# Epoch  90/100  Loss=1.5129e-01  Valid Loss=7.5455e-03  LR=1.56e-05
# Epoch 100/100  Loss=1.4891e-01  Valid Loss=7.5831e-03  LR=7.81e-06
#
# Best model from epoch 86 with validation loss: 7.5448e-03
# NMSE: -40.4533 dB
#
# ============================================================
# Pruning Iteration 2/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 7 hidden nodes (with forward connections)
# Current pruning: 35.39% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.4204e-01  Valid Loss=1.2060e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.0383e-01  Valid Loss=8.8035e-03  LR=5.00e-04
# Epoch  30/100  Loss=2.0367e-01  Valid Loss=1.1215e-02  LR=5.00e-04
# Epoch  40/100  Loss=1.7887e-01  Valid Loss=8.3278e-03  LR=2.50e-04
# Epoch  50/100  Loss=1.7822e-01  Valid Loss=8.2323e-03  LR=2.50e-04
# Epoch  60/100  Loss=1.6372e-01  Valid Loss=8.2598e-03  LR=1.25e-04
# Epoch  70/100  Loss=1.5626e-01  Valid Loss=7.8072e-03  LR=6.25e-05
# Epoch  80/100  Loss=1.5489e-01  Valid Loss=7.7726e-03  LR=6.25e-05
# Epoch  90/100  Loss=1.5458e-01  Valid Loss=7.7164e-03  LR=6.25e-05
# Epoch 100/100  Loss=1.5447e-01  Valid Loss=7.6705e-03  LR=6.25e-05
#
# Best model from epoch 100 with validation loss: 7.6705e-03
# NMSE: -40.4085 dB
#
# ============================================================
# Pruning Iteration 3/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 5 hidden nodes (with forward connections)
# Current pruning: 50.64% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.8074e-01  Valid Loss=2.2220e-02  LR=1.00e-03
# Epoch  20/100  Loss=3.5538e-01  Valid Loss=1.9793e-02  LR=1.00e-03
# Epoch  30/100  Loss=3.3048e-01  Valid Loss=1.8630e-02  LR=1.00e-03
# Epoch  40/100  Loss=3.0173e-01  Valid Loss=1.8482e-02  LR=1.00e-03
# Epoch  50/100  Loss=3.0416e-01  Valid Loss=1.6862e-02  LR=1.00e-03
# Epoch  60/100  Loss=2.9755e-01  Valid Loss=1.6049e-02  LR=1.00e-03
# Epoch  70/100  Loss=2.9110e-01  Valid Loss=1.5559e-02  LR=1.00e-03
# Epoch  80/100  Loss=2.7107e-01  Valid Loss=1.5327e-02  LR=1.00e-03
# Epoch  90/100  Loss=2.7171e-01  Valid Loss=1.5228e-02  LR=1.00e-03
# Epoch 100/100  Loss=2.7598e-01  Valid Loss=1.5059e-02  LR=1.00e-03
#
# Best model from epoch 100 with validation loss: 1.5059e-02
# NMSE: -37.6422 dB
#
# ============================================================
# Pruning Iteration 4/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 4 hidden nodes (with forward connections)
# Current pruning: 53.19% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=6.5691e-01  Valid Loss=3.1520e-02  LR=1.00e-03
# Epoch  20/100  Loss=4.7920e-01  Valid Loss=1.9834e-02  LR=1.00e-03
# Epoch  30/100  Loss=3.8903e-01  Valid Loss=1.4386e-02  LR=1.00e-03
# Epoch  40/100  Loss=3.3660e-01  Valid Loss=1.1796e-02  LR=1.00e-03
# Epoch  50/100  Loss=2.6618e-01  Valid Loss=1.2170e-02  LR=1.00e-03
# Epoch  60/100  Loss=1.8722e-01  Valid Loss=9.2413e-03  LR=5.00e-04
# Epoch  70/100  Loss=1.9218e-01  Valid Loss=9.1773e-03  LR=5.00e-04
# Epoch  80/100  Loss=1.6598e-01  Valid Loss=8.4428e-03  LR=2.50e-04
# Epoch  90/100  Loss=1.6660e-01  Valid Loss=8.4244e-03  LR=2.50e-04
# Epoch 100/100  Loss=1.5832e-01  Valid Loss=8.2595e-03  LR=1.25e-04
#
# Best model from epoch 100 with validation loss: 8.2595e-03
# NMSE: -40.3732 dB
#
# ============================================================
# Pruning Iteration 5/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 4 hidden nodes (with forward connections)
# Current pruning: 62.45% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.9383e-01  Valid Loss=1.4811e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.3917e-01  Valid Loss=1.2173e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.2392e-01  Valid Loss=1.2295e-02  LR=1.00e-03
# Epoch  40/100  Loss=1.8620e-01  Valid Loss=8.8248e-03  LR=5.00e-04
# Epoch  50/100  Loss=1.8956e-01  Valid Loss=8.4994e-03  LR=5.00e-04
# Epoch  60/100  Loss=1.8835e-01  Valid Loss=8.4738e-03  LR=5.00e-04
# Epoch  70/100  Loss=1.6703e-01  Valid Loss=8.2065e-03  LR=2.50e-04
# Epoch  80/100  Loss=1.6905e-01  Valid Loss=8.0696e-03  LR=2.50e-04
# Epoch  90/100  Loss=1.6830e-01  Valid Loss=8.0198e-03  LR=2.50e-04
# Epoch 100/100  Loss=1.6500e-01  Valid Loss=8.1314e-03  LR=2.50e-04
#
# Best model from epoch 90 with validation loss: 8.0198e-03
# NMSE: -40.3567 dB
#
# ============================================================
# Pruning Iteration 6/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 3 hidden nodes (with forward connections)
# Current pruning: 68.65% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.5222e+00  Valid Loss=7.6357e-02  LR=1.00e-03
# Epoch  20/100  Loss=8.0213e-01  Valid Loss=3.6927e-02  LR=1.00e-03
# Epoch  30/100  Loss=6.1226e-01  Valid Loss=2.7433e-02  LR=1.00e-03
# Epoch  40/100  Loss=4.4901e-01  Valid Loss=2.0410e-02  LR=1.00e-03
# Epoch  50/100  Loss=3.4747e-01  Valid Loss=1.6172e-02  LR=1.00e-03
# Epoch  60/100  Loss=3.1777e-01  Valid Loss=1.5672e-02  LR=1.00e-03
# Epoch  70/100  Loss=2.7508e-01  Valid Loss=1.2957e-02  LR=5.00e-04
# Epoch  80/100  Loss=2.6603e-01  Valid Loss=1.2167e-02  LR=5.00e-04
# Epoch  90/100  Loss=2.6349e-01  Valid Loss=1.1805e-02  LR=5.00e-04
# Epoch 100/100  Loss=2.5531e-01  Valid Loss=1.1514e-02  LR=5.00e-04
#
# Best model from epoch 100 with validation loss: 1.1514e-02
# NMSE: -38.6469 dB
#
# ============================================================
# Pruning Iteration 7/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 2 hidden nodes (with forward connections)
# Current pruning: 74.33% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.0193e-01  Valid Loss=1.6710e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.7383e-01  Valid Loss=1.3964e-02  LR=1.00e-03
# Epoch  30/100  Loss=2.6776e-01  Valid Loss=1.3220e-02  LR=1.00e-03
# Epoch  40/100  Loss=2.6156e-01  Valid Loss=1.2992e-02  LR=1.00e-03
# Epoch  50/100  Loss=2.6946e-01  Valid Loss=1.3228e-02  LR=1.00e-03
# Epoch  60/100  Loss=2.3452e-01  Valid Loss=1.0599e-02  LR=5.00e-04
# Epoch  70/100  Loss=2.2505e-01  Valid Loss=1.0154e-02  LR=5.00e-04
# Epoch  80/100  Loss=2.2269e-01  Valid Loss=1.0225e-02  LR=5.00e-04
# Epoch  90/100  Loss=2.0838e-01  Valid Loss=1.0090e-02  LR=2.50e-04
# Epoch 100/100  Loss=2.0711e-01  Valid Loss=9.9848e-03  LR=2.50e-04
#
# Best model from epoch 100 with validation loss: 9.9848e-03
# NMSE: -39.2933 dB
#
# ============================================================
# Pruning Iteration 8/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 2 hidden nodes (with forward connections)
# Current pruning: 77.52% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.1991e+00  Valid Loss=5.5470e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.1331e+00  Valid Loss=5.2142e-02  LR=1.00e-03
# Epoch  30/100  Loss=1.1247e+00  Valid Loss=5.2046e-02  LR=1.00e-03
# Epoch  40/100  Loss=1.1189e+00  Valid Loss=5.1293e-02  LR=1.00e-03
# Epoch  50/100  Loss=1.1205e+00  Valid Loss=5.0955e-02  LR=1.00e-03
# Epoch  60/100  Loss=1.1180e+00  Valid Loss=5.0916e-02  LR=1.00e-03
# Epoch  70/100  Loss=1.1165e+00  Valid Loss=5.0773e-02  LR=1.00e-03
# Epoch  80/100  Loss=1.1162e+00  Valid Loss=5.0606e-02  LR=1.00e-03
# Epoch  90/100  Loss=1.1135e+00  Valid Loss=5.0593e-02  LR=1.00e-03
# Epoch 100/100  Loss=1.1138e+00  Valid Loss=5.0583e-02  LR=1.00e-03
#
# Best model from epoch 99 with validation loss: 5.0557e-02
# NMSE: -32.2894 dB
#
# ============================================================
# Pruning Iteration 9/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 1 hidden nodes (with forward connections)
# Current pruning: 77.87% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.7366e+02  Valid Loss=1.7710e+01  LR=1.00e-03
# Epoch  20/100  Loss=3.5726e+02  Valid Loss=1.7299e+01  LR=1.00e-03
# Epoch  30/100  Loss=3.5715e+02  Valid Loss=1.7298e+01  LR=5.00e-04
# Epoch  40/100  Loss=3.5703e+02  Valid Loss=1.7295e+01  LR=2.50e-04
# Epoch  50/100  Loss=3.5695e+02  Valid Loss=1.7293e+01  LR=1.25e-04
# Epoch  60/100  Loss=3.5689e+02  Valid Loss=1.7292e+01  LR=6.25e-05
# Epoch  70/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  80/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=1.56e-05
# Epoch  90/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=1.56e-05
# Epoch 100/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=7.81e-06
#
# Best model from epoch 14 with validation loss: 1.7274e+01
# NMSE: -7.4559 dB
#
# ============================================================
# Pruning Iteration 10/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# All hidden nodes are already pruned.
# Current pruning: 77.87% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.5774e+02  Valid Loss=1.7317e+01  LR=1.00e-03
# Epoch  20/100  Loss=3.5729e+02  Valid Loss=1.7302e+01  LR=5.00e-04
# Epoch  30/100  Loss=3.5707e+02  Valid Loss=1.7296e+01  LR=2.50e-04
# Epoch  40/100  Loss=3.5695e+02  Valid Loss=1.7293e+01  LR=1.25e-04
# Epoch  50/100  Loss=3.5690e+02  Valid Loss=1.7292e+01  LR=6.25e-05
# Epoch  60/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  70/100  Loss=3.5685e+02  Valid Loss=1.7291e+01  LR=1.56e-05
# Epoch  80/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=7.81e-06
# Epoch  90/100  Loss=3.5684e+02  Valid Loss=1.7290e+01  LR=3.91e-06
# Epoch 100/100  Loss=3.5684e+02  Valid Loss=1.7290e+01  LR=1.95e-06
#
# Best model from epoch 1 with validation loss: 1.7286e+01
# NMSE: -7.4721 dB
#
# ============================================================
# Pruning Iteration 11/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# All hidden nodes are already pruned.
# Current pruning: 77.87% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.5774e+02  Valid Loss=1.7317e+01  LR=1.00e-03
# Epoch  20/100  Loss=3.5729e+02  Valid Loss=1.7302e+01  LR=5.00e-04
# Epoch  30/100  Loss=3.5707e+02  Valid Loss=1.7296e+01  LR=2.50e-04
# Epoch  40/100  Loss=3.5706e+02  Valid Loss=1.7295e+01  LR=1.25e-04
# Epoch  50/100  Loss=3.5695e+02  Valid Loss=1.7292e+01  LR=1.25e-04
# Epoch  60/100  Loss=3.5695e+02  Valid Loss=1.7292e+01  LR=1.25e-04
# Epoch  70/100  Loss=3.5689e+02  Valid Loss=1.7291e+01  LR=6.25e-05
# Epoch  80/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  90/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=1.56e-05
# Epoch 100/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=1.56e-05
#
# Best model from epoch 100 with validation loss: 1.7290e+01
# NMSE: -7.4750 dB
#
# ============================================================
# Pruning Iteration 12/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# All hidden nodes are already pruned.
# Current pruning: 77.87% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.5774e+02  Valid Loss=1.7317e+01  LR=1.00e-03
# Epoch  20/100  Loss=3.5729e+02  Valid Loss=1.7302e+01  LR=5.00e-04
# Epoch  30/100  Loss=3.5707e+02  Valid Loss=1.7296e+01  LR=2.50e-04
# Epoch  40/100  Loss=3.5696e+02  Valid Loss=1.7294e+01  LR=1.25e-04
# Epoch  50/100  Loss=3.5695e+02  Valid Loss=1.7292e+01  LR=1.25e-04
# Epoch  60/100  Loss=3.5690e+02  Valid Loss=1.7292e+01  LR=6.25e-05
# Epoch  70/100  Loss=3.5689e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  80/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  90/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=1.56e-05
# Epoch 100/100  Loss=3.5684e+02  Valid Loss=1.7290e+01  LR=7.81e-06
#
# Best model from epoch 100 with validation loss: 1.7290e+01
# NMSE: -7.4750 dB
#
# Parameter range: 624 - 2,820
# NMSE range: -40.45 - -7.46 dB

# %%
# 4.3 Node Pruning - MultiLayerNetwork
print("\n" + "="*70)
print("Node Pruning - MultiLayerNetwork")
print("="*70)

exp_node_multi = NodePruningExperiment(
    nn_model=models['MultiLayer'],
    num_prune_iterations=12,
    prune_amount=0.2,
    retrain_epochs=retrain_epochs,
    training_dataset=dataManager.get_training_data(),
    valid_dataset=dataManager.get_validation_data(),
    test_dataset=dataManager.get_test_data()
)

# Run experiment and store results
initial_nmse = exp_node_multi.original_nn_model.calculate_forward_nmse(exp_node_multi.test_dataset)
prune_pcts, nmse_results, valid_losses, best_epochs, all_valid_losses = exp_node_multi.prune()

# Calculate parameter counts
base_params = baseline_results['MultiLayer']['params']
param_counts = [base_params] + [calc_effective_params(base_params, pct) for pct in prune_pcts]

node_pruning_results['MultiLayer'] = {
    'params': param_counts,
    'nmse': [initial_nmse] + nmse_results,
    'valid_losses': all_valid_losses,
    'best_epochs': best_epochs
}

print(f"\nParameter range: {min(param_counts):,} - {max(param_counts):,}")
print(f"NMSE range: {min([initial_nmse] + nmse_results):.2f} - {max([initial_nmse] + nmse_results):.2f} dB")
# Out:
# ======================================================================
# Node Pruning - MultiLayerNetwork
# ======================================================================
#
# ============================================================
# Pruning Iteration 1/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 43 hidden nodes (with forward connections)
# Current pruning: 26.08% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=5.1410e-01  Valid Loss=1.8783e-02  LR=1.00e-03
# Epoch  20/100  Loss=3.9401e-01  Valid Loss=1.1372e-02  LR=1.00e-03
# Epoch  30/100  Loss=3.4177e-01  Valid Loss=1.0397e-02  LR=1.00e-03
# Epoch  40/100  Loss=2.0196e-01  Valid Loss=1.1481e-02  LR=5.00e-04
# Epoch  50/100  Loss=1.8650e-01  Valid Loss=9.1371e-03  LR=2.50e-04
# Epoch  60/100  Loss=1.8223e-01  Valid Loss=1.1182e-02  LR=2.50e-04
# Epoch  70/100  Loss=1.6083e-01  Valid Loss=8.1508e-03  LR=1.25e-04
# Epoch  80/100  Loss=1.6422e-01  Valid Loss=8.0460e-03  LR=1.25e-04
# Epoch  90/100  Loss=1.4856e-01  Valid Loss=7.8219e-03  LR=6.25e-05
# Epoch 100/100  Loss=1.4380e-01  Valid Loss=7.8324e-03  LR=3.13e-05
#
# Best model from epoch 87 with validation loss: 7.7983e-03
# NMSE: -40.7245 dB
#
# ============================================================
# Pruning Iteration 2/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 34 hidden nodes (with forward connections)
# Current pruning: 38.85% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=4.2701e-01  Valid Loss=2.3459e-02  LR=1.00e-03
# Epoch  20/100  Loss=2.9999e-01  Valid Loss=2.6360e-02  LR=1.00e-03
# Epoch  30/100  Loss=1.9919e-01  Valid Loss=1.2953e-02  LR=5.00e-04
# Epoch  40/100  Loss=1.8720e-01  Valid Loss=1.0830e-02  LR=2.50e-04
# Epoch  50/100  Loss=1.8211e-01  Valid Loss=1.1780e-02  LR=1.25e-04
# Epoch  60/100  Loss=1.7079e-01  Valid Loss=8.1804e-03  LR=1.25e-04
# Epoch  70/100  Loss=1.5369e-01  Valid Loss=8.0429e-03  LR=6.25e-05
# Epoch  80/100  Loss=1.5663e-01  Valid Loss=8.0788e-03  LR=3.13e-05
# Epoch  90/100  Loss=1.4810e-01  Valid Loss=7.8996e-03  LR=3.13e-05
# Epoch 100/100  Loss=1.4657e-01  Valid Loss=7.7930e-03  LR=1.56e-05
#
# Best model from epoch 95 with validation loss: 7.7710e-03
# NMSE: -40.5858 dB
#
# ============================================================
# Pruning Iteration 3/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 27 hidden nodes (with forward connections)
# Current pruning: 45.30% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=2.2651e+00  Valid Loss=9.8585e-02  LR=1.00e-03
# Epoch  20/100  Loss=1.1927e+00  Valid Loss=5.5967e-02  LR=1.00e-03
# Epoch  30/100  Loss=1.1462e+00  Valid Loss=5.2470e-02  LR=1.00e-03
# Epoch  40/100  Loss=1.1695e+00  Valid Loss=5.2097e-02  LR=1.00e-03
# Epoch  50/100  Loss=1.1993e+00  Valid Loss=5.2260e-02  LR=1.00e-03
# Epoch  60/100  Loss=1.0883e+00  Valid Loss=5.0895e-02  LR=5.00e-04
# Epoch  70/100  Loss=1.0839e+00  Valid Loss=5.0836e-02  LR=5.00e-04
# Epoch  80/100  Loss=1.0765e+00  Valid Loss=5.0595e-02  LR=2.50e-04
# Epoch  90/100  Loss=1.0639e+00  Valid Loss=4.9956e-02  LR=1.25e-04
# Epoch 100/100  Loss=1.0635e+00  Valid Loss=4.9912e-02  LR=1.25e-04
#
# Best model from epoch 95 with validation loss: 4.9908e-02
# NMSE: -32.3600 dB
#
# ============================================================
# Pruning Iteration 4/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 22 hidden nodes (with forward connections)
# Current pruning: 52.33% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=4.5198e+02  Valid Loss=2.0636e+01  LR=1.00e-03
# Epoch  20/100  Loss=3.5711e+02  Valid Loss=1.7283e+01  LR=1.00e-03
# Epoch  30/100  Loss=3.5711e+02  Valid Loss=1.7300e+01  LR=5.00e-04
# Epoch  40/100  Loss=3.5715e+02  Valid Loss=1.7297e+01  LR=2.50e-04
# Epoch  50/100  Loss=3.5702e+02  Valid Loss=1.7294e+01  LR=2.50e-04
# Epoch  60/100  Loss=3.5694e+02  Valid Loss=1.7292e+01  LR=1.25e-04
# Epoch  70/100  Loss=3.5689e+02  Valid Loss=1.7291e+01  LR=6.25e-05
# Epoch  80/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  90/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=1.56e-05
# Epoch 100/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=7.81e-06
#
# Best model from epoch 18 with validation loss: 1.7274e+01
# NMSE: -7.4574 dB
#
# ============================================================
# Pruning Iteration 5/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 17 hidden nodes (with forward connections)
# Current pruning: 67.49% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.5774e+02  Valid Loss=1.7317e+01  LR=1.00e-03
# Epoch  20/100  Loss=3.5729e+02  Valid Loss=1.7302e+01  LR=5.00e-04
# Epoch  30/100  Loss=3.5707e+02  Valid Loss=1.7296e+01  LR=2.50e-04
# Epoch  40/100  Loss=3.5695e+02  Valid Loss=1.7293e+01  LR=1.25e-04
# Epoch  50/100  Loss=3.5690e+02  Valid Loss=1.7292e+01  LR=6.25e-05
# Epoch  60/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  70/100  Loss=3.5685e+02  Valid Loss=1.7291e+01  LR=1.56e-05
# Epoch  80/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=7.81e-06
# Epoch  90/100  Loss=3.5684e+02  Valid Loss=1.7290e+01  LR=3.91e-06
# Epoch 100/100  Loss=3.5684e+02  Valid Loss=1.7290e+01  LR=1.95e-06
#
# Best model from epoch 1 with validation loss: 1.7286e+01
# NMSE: -7.4726 dB
#
# ============================================================
# Pruning Iteration 6/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 14 hidden nodes (with forward connections)
# Current pruning: 79.98% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.5774e+02  Valid Loss=1.7317e+01  LR=1.00e-03
# Epoch  20/100  Loss=3.5729e+02  Valid Loss=1.7302e+01  LR=5.00e-04
# Epoch  30/100  Loss=3.5707e+02  Valid Loss=1.7296e+01  LR=2.50e-04
# Epoch  40/100  Loss=3.5696e+02  Valid Loss=1.7294e+01  LR=1.25e-04
# Epoch  50/100  Loss=3.5695e+02  Valid Loss=1.7292e+01  LR=1.25e-04
# Epoch  60/100  Loss=3.5690e+02  Valid Loss=1.7292e+01  LR=6.25e-05
# Epoch  70/100  Loss=3.5689e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  80/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  90/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=1.56e-05
# Epoch 100/100  Loss=3.5684e+02  Valid Loss=1.7290e+01  LR=7.81e-06
#
# Best model from epoch 100 with validation loss: 1.7290e+01
# NMSE: -7.4750 dB
#
# ============================================================
# Pruning Iteration 7/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 11 hidden nodes (with forward connections)
# Current pruning: 83.14% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.5774e+02  Valid Loss=1.7317e+01  LR=1.00e-03
# Epoch  20/100  Loss=3.5729e+02  Valid Loss=1.7302e+01  LR=5.00e-04
# Epoch  30/100  Loss=3.5707e+02  Valid Loss=1.7296e+01  LR=2.50e-04
# Epoch  40/100  Loss=3.5696e+02  Valid Loss=1.7294e+01  LR=1.25e-04
# Epoch  50/100  Loss=3.5695e+02  Valid Loss=1.7292e+01  LR=1.25e-04
# Epoch  60/100  Loss=3.5690e+02  Valid Loss=1.7292e+01  LR=6.25e-05
# Epoch  70/100  Loss=3.5689e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  80/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  90/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=1.56e-05
# Epoch 100/100  Loss=3.5684e+02  Valid Loss=1.7290e+01  LR=7.81e-06
#
# Best model from epoch 100 with validation loss: 1.7290e+01
# NMSE: -7.4750 dB
#
# ============================================================
# Pruning Iteration 8/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 9 hidden nodes (with forward connections)
# Current pruning: 85.29% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.5774e+02  Valid Loss=1.7317e+01  LR=1.00e-03
# Epoch  20/100  Loss=3.5729e+02  Valid Loss=1.7302e+01  LR=5.00e-04
# Epoch  30/100  Loss=3.5707e+02  Valid Loss=1.7296e+01  LR=2.50e-04
# Epoch  40/100  Loss=3.5696e+02  Valid Loss=1.7294e+01  LR=1.25e-04
# Epoch  50/100  Loss=3.5695e+02  Valid Loss=1.7292e+01  LR=1.25e-04
# Epoch  60/100  Loss=3.5690e+02  Valid Loss=1.7292e+01  LR=6.25e-05
# Epoch  70/100  Loss=3.5689e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  80/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  90/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=1.56e-05
# Epoch 100/100  Loss=3.5684e+02  Valid Loss=1.7290e+01  LR=7.81e-06
#
# Best model from epoch 100 with validation loss: 1.7290e+01
# NMSE: -7.4750 dB
#
# ============================================================
# Pruning Iteration 9/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 6 hidden nodes (with forward connections)
# Current pruning: 88.41% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.5774e+02  Valid Loss=1.7317e+01  LR=1.00e-03
# Epoch  20/100  Loss=3.5729e+02  Valid Loss=1.7302e+01  LR=5.00e-04
# Epoch  30/100  Loss=3.5707e+02  Valid Loss=1.7296e+01  LR=2.50e-04
# Epoch  40/100  Loss=3.5696e+02  Valid Loss=1.7294e+01  LR=1.25e-04
# Epoch  50/100  Loss=3.5695e+02  Valid Loss=1.7292e+01  LR=1.25e-04
# Epoch  60/100  Loss=3.5690e+02  Valid Loss=1.7292e+01  LR=6.25e-05
# Epoch  70/100  Loss=3.5689e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  80/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  90/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=1.56e-05
# Epoch 100/100  Loss=3.5684e+02  Valid Loss=1.7290e+01  LR=7.81e-06
#
# Best model from epoch 100 with validation loss: 1.7290e+01
# NMSE: -7.4750 dB
#
# ============================================================
# Pruning Iteration 10/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 5 hidden nodes (with forward connections)
# Current pruning: 89.25% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.5774e+02  Valid Loss=1.7317e+01  LR=1.00e-03
# Epoch  20/100  Loss=3.5729e+02  Valid Loss=1.7302e+01  LR=5.00e-04
# Epoch  30/100  Loss=3.5707e+02  Valid Loss=1.7296e+01  LR=2.50e-04
# Epoch  40/100  Loss=3.5696e+02  Valid Loss=1.7294e+01  LR=1.25e-04
# Epoch  50/100  Loss=3.5695e+02  Valid Loss=1.7292e+01  LR=1.25e-04
# Epoch  60/100  Loss=3.5690e+02  Valid Loss=1.7292e+01  LR=6.25e-05
# Epoch  70/100  Loss=3.5689e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  80/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  90/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=1.56e-05
# Epoch 100/100  Loss=3.5684e+02  Valid Loss=1.7290e+01  LR=7.81e-06
#
# Best model from epoch 100 with validation loss: 1.7290e+01
# NMSE: -7.4750 dB
#
# ============================================================
# Pruning Iteration 11/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 4 hidden nodes (with forward connections)
# Current pruning: 90.52% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.5774e+02  Valid Loss=1.7317e+01  LR=1.00e-03
# Epoch  20/100  Loss=3.5729e+02  Valid Loss=1.7302e+01  LR=5.00e-04
# Epoch  30/100  Loss=3.5707e+02  Valid Loss=1.7296e+01  LR=2.50e-04
# Epoch  40/100  Loss=3.5696e+02  Valid Loss=1.7294e+01  LR=1.25e-04
# Epoch  50/100  Loss=3.5695e+02  Valid Loss=1.7292e+01  LR=1.25e-04
# Epoch  60/100  Loss=3.5690e+02  Valid Loss=1.7292e+01  LR=6.25e-05
# Epoch  70/100  Loss=3.5689e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  80/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  90/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=1.56e-05
# Epoch 100/100  Loss=3.5684e+02  Valid Loss=1.7290e+01  LR=7.81e-06
#
# Best model from epoch 100 with validation loss: 1.7290e+01
# NMSE: -7.4750 dB
#
# ============================================================
# Pruning Iteration 12/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 3 hidden nodes (with forward connections)
# Current pruning: 92.20% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=3.5774e+02  Valid Loss=1.7317e+01  LR=1.00e-03
# Epoch  20/100  Loss=3.5729e+02  Valid Loss=1.7302e+01  LR=5.00e-04
# Epoch  30/100  Loss=3.5707e+02  Valid Loss=1.7296e+01  LR=2.50e-04
# Epoch  40/100  Loss=3.5696e+02  Valid Loss=1.7294e+01  LR=1.25e-04
# Epoch  50/100  Loss=3.5695e+02  Valid Loss=1.7292e+01  LR=1.25e-04
# Epoch  60/100  Loss=3.5690e+02  Valid Loss=1.7292e+01  LR=6.25e-05
# Epoch  70/100  Loss=3.5689e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  80/100  Loss=3.5687e+02  Valid Loss=1.7291e+01  LR=3.13e-05
# Epoch  90/100  Loss=3.5685e+02  Valid Loss=1.7290e+01  LR=1.56e-05
# Epoch 100/100  Loss=3.5684e+02  Valid Loss=1.7290e+01  LR=7.81e-06
#
# Best model from epoch 100 with validation loss: 1.7290e+01
# NMSE: -7.4750 dB
#
# Parameter range: 839 - 10,768
# NMSE range: -40.72 - -7.46 dB

# %%
# 4.4 Node Pruning - PGJANET
print("\n" + "="*70)
print("Node Pruning - PGJANET")
print("="*70)

exp_node_pgjanet = NodePruningExperiment(
    nn_model=models['PGJANET'],
    num_prune_iterations=12,
    prune_amount=0.2,
    retrain_epochs=retrain_epochs,
    training_dataset=dataManager.get_training_data(),
    valid_dataset=dataManager.get_validation_data(),
    test_dataset=dataManager.get_test_data()
)

# Run experiment and store results
initial_nmse = exp_node_pgjanet.original_nn_model.calculate_forward_nmse(exp_node_pgjanet.test_dataset)
prune_pcts, nmse_results, valid_losses, best_epochs, all_valid_losses = exp_node_pgjanet.prune()

# Calculate parameter counts
base_params = baseline_results['PGJANET']['params']
param_counts = [base_params] + [calc_effective_params(base_params, pct) for pct in prune_pcts]

node_pruning_results['PGJANET'] = {
    'params': param_counts,
    'nmse': [initial_nmse] + nmse_results,
    'valid_losses': all_valid_losses,
    'best_epochs': best_epochs
}

print(f"\nParameter range: {min(param_counts):,} - {max(param_counts):,}")
print(f"NMSE range: {min([initial_nmse] + nmse_results):.2f} - {max([initial_nmse] + nmse_results):.2f} dB")
# Out:
# ======================================================================
# Node Pruning - PGJANET
# ======================================================================
#
# ============================================================
# Pruning Iteration 1/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 16 hidden nodes (with forward connections)
# Current pruning: 26.34% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=8.7034e+01  Valid Loss=3.6557e+00  LR=1.00e-03
# Epoch  20/100  Loss=5.5473e+01  Valid Loss=3.1094e+00  LR=1.00e-03
# Epoch  30/100  Loss=1.7536e+01  Valid Loss=7.7113e-01  LR=1.00e-03
# Epoch  40/100  Loss=9.4046e+00  Valid Loss=6.1124e-01  LR=1.00e-03
# Epoch  50/100  Loss=6.6729e+00  Valid Loss=3.4121e-01  LR=1.00e-03
# Epoch  60/100  Loss=5.6165e+00  Valid Loss=3.8069e-01  LR=1.00e-03
# Epoch  70/100  Loss=4.3804e+00  Valid Loss=2.1588e-01  LR=1.00e-03
# Epoch  80/100  Loss=3.5644e+00  Valid Loss=3.1850e-01  LR=1.00e-03
# Epoch  90/100  Loss=3.1127e+00  Valid Loss=1.6206e-01  LR=5.00e-04
# Epoch 100/100  Loss=2.8987e+00  Valid Loss=1.4229e-01  LR=5.00e-04
#
# Best model from epoch 100 with validation loss: 1.4229e-01
# NMSE: -28.1574 dB
#
# ============================================================
# Pruning Iteration 2/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 12 hidden nodes (with forward connections)
# Current pruning: 40.33% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.6069e+02  Valid Loss=6.9566e+00  LR=1.00e-03
# Epoch  20/100  Loss=1.3353e+02  Valid Loss=5.9669e+00  LR=1.00e-03
# Epoch  30/100  Loss=1.2218e+02  Valid Loss=5.4006e+00  LR=1.00e-03
# Epoch  40/100  Loss=1.1192e+02  Valid Loss=5.7785e+00  LR=1.00e-03
# Epoch  50/100  Loss=1.0274e+02  Valid Loss=4.4867e+00  LR=1.00e-03
# Epoch  60/100  Loss=1.0283e+02  Valid Loss=4.7590e+00  LR=1.00e-03
# Epoch  70/100  Loss=8.8336e+01  Valid Loss=3.8697e+00  LR=1.00e-03
# Epoch  80/100  Loss=8.0608e+01  Valid Loss=3.4215e+00  LR=1.00e-03
# Epoch  90/100  Loss=7.4036e+01  Valid Loss=3.3605e+00  LR=1.00e-03
# Epoch 100/100  Loss=6.8344e+01  Valid Loss=2.9766e+00  LR=1.00e-03
#
# Best model from epoch 94 with validation loss: 2.9338e+00
# NMSE: -14.3494 dB
#
# ============================================================
# Pruning Iteration 3/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 10 hidden nodes (with forward connections)
# Current pruning: 49.84% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=9.8341e+02  Valid Loss=4.6860e+01  LR=1.00e-03
# Epoch  20/100  Loss=9.7623e+02  Valid Loss=4.7329e+01  LR=1.00e-03
# Epoch  30/100  Loss=9.7772e+02  Valid Loss=4.6028e+01  LR=1.00e-03
# Epoch  40/100  Loss=9.7524e+02  Valid Loss=4.6214e+01  LR=1.00e-03
# Epoch  50/100  Loss=9.7416e+02  Valid Loss=4.6168e+01  LR=5.00e-04
# Epoch  60/100  Loss=9.7119e+02  Valid Loss=4.6330e+01  LR=2.50e-04
# Epoch  70/100  Loss=9.7123e+02  Valid Loss=4.6312e+01  LR=2.50e-04
# Epoch  80/100  Loss=9.7100e+02  Valid Loss=4.6027e+01  LR=2.50e-04
# Epoch  90/100  Loss=9.6946e+02  Valid Loss=4.6348e+01  LR=1.25e-04
# Epoch 100/100  Loss=9.6942e+02  Valid Loss=4.6133e+01  LR=6.25e-05
#
# Best model from epoch 72 with validation loss: 4.6002e+01
# NMSE: -2.6950 dB
#
# ============================================================
# Pruning Iteration 4/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 8 hidden nodes (with forward connections)
# Current pruning: 57.96% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=9.8465e+02  Valid Loss=4.6949e+01  LR=1.00e-03
# Epoch  20/100  Loss=9.8058e+02  Valid Loss=4.6858e+01  LR=1.00e-03
# Epoch  30/100  Loss=9.7875e+02  Valid Loss=4.6757e+01  LR=1.00e-03
# Epoch  40/100  Loss=9.7967e+02  Valid Loss=4.7419e+01  LR=1.00e-03
# Epoch  50/100  Loss=9.7265e+02  Valid Loss=4.6236e+01  LR=5.00e-04
# Epoch  60/100  Loss=9.7012e+02  Valid Loss=4.6354e+01  LR=5.00e-04
# Epoch  70/100  Loss=9.6982e+02  Valid Loss=4.6093e+01  LR=5.00e-04
# Epoch  80/100  Loss=9.6696e+02  Valid Loss=4.6235e+01  LR=2.50e-04
# Epoch  90/100  Loss=9.6584e+02  Valid Loss=4.6126e+01  LR=1.25e-04
# Epoch 100/100  Loss=9.6536e+02  Valid Loss=4.6149e+01  LR=6.25e-05
#
# Best model from epoch 61 with validation loss: 4.6046e+01
# NMSE: -2.7080 dB
#
# ============================================================
# Pruning Iteration 5/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 6 hidden nodes (with forward connections)
# Current pruning: 66.35% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.7709e+03  Valid Loss=8.6348e+01  LR=1.00e-03
# Epoch  20/100  Loss=1.7704e+03  Valid Loss=8.6204e+01  LR=5.00e-04
# Epoch  30/100  Loss=1.7696e+03  Valid Loss=8.6215e+01  LR=2.50e-04
# Epoch  40/100  Loss=1.7696e+03  Valid Loss=8.6248e+01  LR=1.25e-04
# Epoch  50/100  Loss=1.7695e+03  Valid Loss=8.6261e+01  LR=6.25e-05
# Epoch  60/100  Loss=1.7692e+03  Valid Loss=8.6303e+01  LR=3.13e-05
# Epoch  70/100  Loss=1.7692e+03  Valid Loss=8.6269e+01  LR=1.56e-05
# Epoch  80/100  Loss=1.7692e+03  Valid Loss=8.6287e+01  LR=1.56e-05
# Epoch  90/100  Loss=1.7692e+03  Valid Loss=8.6307e+01  LR=7.81e-06
# Epoch 100/100  Loss=1.7692e+03  Valid Loss=8.6303e+01  LR=3.91e-06
#
# Best model from epoch 15 with validation loss: 8.5966e+01
# NMSE: 0.0055 dB
#
# ============================================================
# Pruning Iteration 6/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 5 hidden nodes (with forward connections)
# Current pruning: 74.52% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.7704e+03  Valid Loss=8.6289e+01  LR=1.00e-03
# Epoch  20/100  Loss=1.7696e+03  Valid Loss=8.6299e+01  LR=5.00e-04
# Epoch  30/100  Loss=1.7693e+03  Valid Loss=8.6322e+01  LR=2.50e-04
# Epoch  40/100  Loss=1.7695e+03  Valid Loss=8.6253e+01  LR=1.25e-04
# Epoch  50/100  Loss=1.7693e+03  Valid Loss=8.6307e+01  LR=6.25e-05
# Epoch  60/100  Loss=1.7692e+03  Valid Loss=8.6280e+01  LR=3.13e-05
# Epoch  70/100  Loss=1.7692e+03  Valid Loss=8.6290e+01  LR=1.56e-05
# Epoch  80/100  Loss=1.7692e+03  Valid Loss=8.6284e+01  LR=1.56e-05
# Epoch  90/100  Loss=1.7692e+03  Valid Loss=8.6288e+01  LR=7.81e-06
# Epoch 100/100  Loss=1.7692e+03  Valid Loss=8.6287e+01  LR=3.91e-06
#
# Best model from epoch 4 with validation loss: 8.6187e+01
# NMSE: 0.0012 dB
#
# ============================================================
# Pruning Iteration 7/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 4 hidden nodes (with forward connections)
# Current pruning: 80.29% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.7700e+03  Valid Loss=8.6299e+01  LR=1.00e-03
# Epoch  20/100  Loss=1.7697e+03  Valid Loss=8.6302e+01  LR=5.00e-04
# Epoch  30/100  Loss=1.7695e+03  Valid Loss=8.6335e+01  LR=2.50e-04
# Epoch  40/100  Loss=1.7694e+03  Valid Loss=8.6293e+01  LR=1.25e-04
# Epoch  50/100  Loss=1.7692e+03  Valid Loss=8.6305e+01  LR=6.25e-05
# Epoch  60/100  Loss=1.7692e+03  Valid Loss=8.6311e+01  LR=3.13e-05
# Epoch  70/100  Loss=1.7692e+03  Valid Loss=8.6302e+01  LR=1.56e-05
# Epoch  80/100  Loss=1.7692e+03  Valid Loss=8.6281e+01  LR=7.81e-06
# Epoch  90/100  Loss=1.7692e+03  Valid Loss=8.6286e+01  LR=3.91e-06
# Epoch 100/100  Loss=1.7692e+03  Valid Loss=8.6283e+01  LR=3.91e-06
#
# Best model from epoch 2 with validation loss: 8.6195e+01
# NMSE: 0.0009 dB
#
# ============================================================
# Pruning Iteration 8/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 3 hidden nodes (with forward connections)
# Current pruning: 84.03% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.7701e+03  Valid Loss=8.6376e+01  LR=1.00e-03
# Epoch  20/100  Loss=1.7694e+03  Valid Loss=8.6314e+01  LR=5.00e-04
# Epoch  30/100  Loss=1.7693e+03  Valid Loss=8.6312e+01  LR=2.50e-04
# Epoch  40/100  Loss=1.7692e+03  Valid Loss=8.6284e+01  LR=1.25e-04
# Epoch  50/100  Loss=1.7692e+03  Valid Loss=8.6332e+01  LR=6.25e-05
# Epoch  60/100  Loss=1.7692e+03  Valid Loss=8.6291e+01  LR=3.13e-05
# Epoch  70/100  Loss=1.7692e+03  Valid Loss=8.6290e+01  LR=1.56e-05
# Epoch  80/100  Loss=1.7692e+03  Valid Loss=8.6280e+01  LR=1.56e-05
# Epoch  90/100  Loss=1.7692e+03  Valid Loss=8.6284e+01  LR=7.81e-06
# Epoch 100/100  Loss=1.7692e+03  Valid Loss=8.6281e+01  LR=3.91e-06
#
# Best model from epoch 4 with validation loss: 8.6155e+01
# NMSE: 0.0008 dB
#
# ============================================================
# Pruning Iteration 9/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 3 hidden nodes (with forward connections)
# Current pruning: 88.14% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.7693e+03  Valid Loss=8.6363e+01  LR=1.00e-03
# Epoch  20/100  Loss=1.7693e+03  Valid Loss=8.6238e+01  LR=5.00e-04
# Epoch  30/100  Loss=1.7693e+03  Valid Loss=8.6248e+01  LR=2.50e-04
# Epoch  40/100  Loss=1.7692e+03  Valid Loss=8.6301e+01  LR=1.25e-04
# Epoch  50/100  Loss=1.7692e+03  Valid Loss=8.6262e+01  LR=6.25e-05
# Epoch  60/100  Loss=1.7692e+03  Valid Loss=8.6304e+01  LR=3.13e-05
# Epoch  70/100  Loss=1.7692e+03  Valid Loss=8.6285e+01  LR=1.56e-05
# Epoch  80/100  Loss=1.7692e+03  Valid Loss=8.6290e+01  LR=7.81e-06
# Epoch  90/100  Loss=1.7692e+03  Valid Loss=8.6292e+01  LR=7.81e-06
# Epoch 100/100  Loss=1.7692e+03  Valid Loss=8.6293e+01  LR=3.91e-06
#
# Best model from epoch 3 with validation loss: 8.6155e+01
# NMSE: 0.0005 dB
#
# ============================================================
# Pruning Iteration 10/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# Pruned 2 hidden nodes (with forward connections)
# Current pruning: 90.54% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.7694e+03  Valid Loss=8.6344e+01  LR=1.00e-03
# Epoch  20/100  Loss=1.7694e+03  Valid Loss=8.6352e+01  LR=5.00e-04
# Epoch  30/100  Loss=1.7693e+03  Valid Loss=8.6301e+01  LR=5.00e-04
# Epoch  40/100  Loss=1.7693e+03  Valid Loss=8.6279e+01  LR=2.50e-04
# Epoch  50/100  Loss=1.7692e+03  Valid Loss=8.6280e+01  LR=1.25e-04
# Epoch  60/100  Loss=1.7692e+03  Valid Loss=8.6292e+01  LR=6.25e-05
# Epoch  70/100  Loss=1.7692e+03  Valid Loss=8.6288e+01  LR=3.13e-05
# Epoch  80/100  Loss=1.7692e+03  Valid Loss=8.6302e+01  LR=1.56e-05
# Epoch  90/100  Loss=1.7692e+03  Valid Loss=8.6302e+01  LR=7.81e-06
# Epoch 100/100  Loss=1.7692e+03  Valid Loss=8.6297e+01  LR=3.91e-06
#
# Best model from epoch 9 with validation loss: 8.6214e+01
# NMSE: 0.0007 dB
#
# ============================================================
# Pruning Iteration 11/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# All hidden nodes are already pruned.
# Current pruning: 90.54% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.7697e+03  Valid Loss=8.6353e+01  LR=1.00e-03
# Epoch  20/100  Loss=1.7693e+03  Valid Loss=8.6255e+01  LR=5.00e-04
# Epoch  30/100  Loss=1.7692e+03  Valid Loss=8.6260e+01  LR=2.50e-04
# Epoch  40/100  Loss=1.7692e+03  Valid Loss=8.6284e+01  LR=1.25e-04
# Epoch  50/100  Loss=1.7692e+03  Valid Loss=8.6260e+01  LR=6.25e-05
# Epoch  60/100  Loss=1.7692e+03  Valid Loss=8.6264e+01  LR=3.13e-05
# Epoch  70/100  Loss=1.7692e+03  Valid Loss=8.6281e+01  LR=1.56e-05
# Epoch  80/100  Loss=1.7692e+03  Valid Loss=8.6284e+01  LR=7.81e-06
# Epoch  90/100  Loss=1.7692e+03  Valid Loss=8.6282e+01  LR=7.81e-06
# Epoch 100/100  Loss=1.7692e+03  Valid Loss=8.6283e+01  LR=3.91e-06
#
# Best model from epoch 3 with validation loss: 8.6188e+01
# NMSE: 0.0022 dB
#
# ============================================================
# Pruning Iteration 12/12
# ============================================================
# Pruning weakest 20.0% of hidden nodes...
# All hidden nodes are already pruned.
# Current pruning: 90.54% of weights are zero
# Retraining for 100 epochs...
# Epoch  10/100  Loss=1.7694e+03  Valid Loss=8.6317e+01  LR=1.00e-03
# Epoch  20/100  Loss=1.7695e+03  Valid Loss=8.6306e+01  LR=5.00e-04
# Epoch  30/100  Loss=1.7693e+03  Valid Loss=8.6309e+01  LR=2.50e-04
# Epoch  40/100  Loss=1.7692e+03  Valid Loss=8.6288e+01  LR=1.25e-04
# Epoch  50/100  Loss=1.7692e+03  Valid Loss=8.6299e+01  LR=6.25e-05
# Epoch  60/100  Loss=1.7692e+03  Valid Loss=8.6289e+01  LR=3.13e-05
# Epoch  70/100  Loss=1.7692e+03  Valid Loss=8.6296e+01  LR=1.56e-05
# Epoch  80/100  Loss=1.7692e+03  Valid Loss=8.6301e+01  LR=7.81e-06
# Epoch  90/100  Loss=1.7692e+03  Valid Loss=8.6291e+01  LR=3.91e-06
# Epoch 100/100  Loss=1.7692e+03  Valid Loss=8.6294e+01  LR=3.91e-06
#
# Best model from epoch 2 with validation loss: 8.6205e+01
# NMSE: 0.0008 dB
#
# Parameter range: 177 - 1,872
# NMSE range: -36.27 - 0.01 dB

# %% [markdown]
# ## 5. Comprehensive Analysis and Visualization
#
# Now we'll create detailed comparisons across all experiments using **parameter count** as the primary metric.

# %%
# All pruning results are now stored in:
# - linear_pruning_results[model_name] = {'params': [...], 'nmse': [...], 'valid_losses': [...], 'best_epochs': [...]}
# - node_pruning_results[model_name] = {'params': [...], 'nmse': [...], 'valid_losses': [...], 'best_epochs': [...]}

print("All pruning experiments completed!")
print("Results are stored and ready for visualization.")
# Out:
# All pruning experiments completed!
# Results are stored and ready for visualization.

# %% [markdown]
# ### 5.1 NMSE vs Parameter Count - All Models

# %%
# Plot NMSE vs Parameter Count
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Color scheme for models
model_colors = {
    'OneLayer': '#1f77b4',
    'ThreeLayer': '#ff7f0e',
    'MultiLayer': '#2ca02c',
    'PGJANET': '#8b1b6a'
}

# Left plot: Linear Pruning
ax_linear = axes[0]
for model_name, results in linear_pruning_results.items():
    params = results['params']
    nmse = results['nmse']
    
    ax_linear.plot(params, nmse, 
                   marker='o', linewidth=2.5, markersize=8,
                   color=model_colors[model_name],
                   label=f'{model_name}')

ax_linear.set_xlabel('Number of Parameters', fontsize=13, fontweight='bold')
ax_linear.set_ylabel('NMSE (dB)', fontsize=13, fontweight='bold')
ax_linear.set_title('Linear/Magnitude Pruning', fontsize=14, fontweight='bold')
ax_linear.legend(fontsize=10, loc='best')
ax_linear.grid(True, alpha=0.4, linestyle='--')
ax_linear.invert_xaxis()  # Fewer params on right

# Right plot: Node Pruning
ax_node = axes[1]
for model_name, results in node_pruning_results.items():
    params = results['params']
    nmse = results['nmse']
    
    ax_node.plot(params, nmse,
                 marker='s', linewidth=2.5, markersize=8,
                 color=model_colors[model_name],
                 label=f'{model_name}')

ax_node.set_xlabel('Number of Parameters', fontsize=13, fontweight='bold')
ax_node.set_ylabel('NMSE (dB)', fontsize=13, fontweight='bold')
ax_node.set_title('Node Pruning', fontsize=14, fontweight='bold')
ax_node.legend(fontsize=10, loc='best')
ax_node.grid(True, alpha=0.4, linestyle='--')
ax_node.invert_xaxis()  # Fewer params on right

plt.suptitle('Model Performance vs Parameter Count', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.2 Combined Comparison - All Models and Methods

# %%
# Single plot comparing all combinations
fig, ax = plt.subplots(figsize=(14, 8))

# Line styles for pruning methods
pruning_styles = {
    'Linear': {'linestyle': '-', 'marker': 'o'},
    'Node': {'linestyle': '--', 'marker': 's'}
}

for model_name in ['OneLayer', 'ThreeLayer', 'MultiLayer', 'PGJANET']:
    # Linear pruning
    linear_results = linear_pruning_results[model_name]
    ax.plot(linear_results['params'], linear_results['nmse'],
            color=model_colors[model_name],
            linewidth=2.5, markersize=9,
            linestyle=pruning_styles['Linear']['linestyle'],
            marker=pruning_styles['Linear']['marker'],
            label=f'{model_name} - Linear')
    
    # Node pruning
    node_results = node_pruning_results[model_name]
    ax.plot(node_results['params'], node_results['nmse'],
            color=model_colors[model_name],
            linewidth=2.5, markersize=9,
            linestyle=pruning_styles['Node']['linestyle'],
            marker=pruning_styles['Node']['marker'],
            label=f'{model_name} - Node')

ax.set_xlabel('Number of Parameters', fontsize=14, fontweight='bold')
ax.set_ylabel('NMSE (dB)', fontsize=14, fontweight='bold')
ax.set_title('All Pruning Experiments: Performance vs Model Size', fontsize=16, fontweight='bold')
ax.legend(fontsize=11, loc='best', ncol=2)
ax.grid(True, alpha=0.4, linestyle='--')
ax.invert_xaxis()  # Fewer params on right

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.3 Parameter Efficiency Table

# %%
# Create efficiency comparison table at key parameter counts
key_param_counts = [500, 1000, 2000, 3000, 5000]

def get_nmse_at_param_count(results_dict, target_params):
    """Interpolate NMSE at a given parameter count"""
    params = np.array(results_dict['params'])
    nmse = np.array(results_dict['nmse'])
    
    # Sort by params (descending to handle inverted x-axis)
    sort_idx = np.argsort(params)[::-1]
    params_sorted = params[sort_idx]
    nmse_sorted = nmse[sort_idx]
    
    if target_params >= params_sorted.min() and target_params <= params_sorted.max():
        return np.interp(target_params, params_sorted[::-1], nmse_sorted[::-1])
    else:
        return np.nan

# Build efficiency data
efficiency_data = []

for param_count in key_param_counts:
    row = {'Parameters': param_count}
    
    for model_name in ['OneLayer', 'ThreeLayer', 'MultiLayer', 'PGJANET']:
        # Linear pruning
        nmse_linear = get_nmse_at_param_count(
            linear_pruning_results[model_name],
            param_count
        )
        row[f'{model_name}_Linear'] = nmse_linear
        
        # Node pruning
        nmse_node = get_nmse_at_param_count(
            node_pruning_results[model_name],
            param_count
        )
        row[f'{model_name}_Node'] = nmse_node
    
    efficiency_data.append(row)

efficiency_df = pd.DataFrame(efficiency_data)

print("\n" + "="*120)
print("NMSE (dB) AT KEY PARAMETER COUNTS")
print("="*120)
print(efficiency_df.to_string(index=False, float_format=lambda x: f'{x:.2f}' if not np.isnan(x) else 'N/A'))
print("="*120)
# Out:
# ========================================================================================================================
# NMSE (dB) AT KEY PARAMETER COUNTS
# ========================================================================================================================
#  Parameters  OneLayer_Linear  OneLayer_Node  ThreeLayer_Linear  ThreeLayer_Node  MultiLayer_Linear  MultiLayer_Node  PGJANET_Linear  PGJANET_Node
#         500           -39.47         -40.30             -40.10              NaN                NaN              NaN          -35.64          0.00
#        1000              NaN            NaN             -40.97           -39.78             -40.93            -7.47          -36.58         -6.69
#        2000              NaN            NaN             -40.54           -40.43             -40.98            -7.47             NaN           NaN
#        3000              NaN            NaN                NaN              NaN             -40.89            -7.47             NaN           NaN
#        5000              NaN            NaN                NaN              NaN             -40.93            -7.46             NaN           NaN
# ========================================================================================================================

# %% [markdown]
# ### 5.4 Best Performance per Parameter Budget

# %%
# For each parameter budget, find the best model/method combination
best_configs = []

for param_count in key_param_counts:
    best_nmse = float('inf')
    best_config = None
    
    for model_name in ['OneLayer', 'ThreeLayer', 'MultiLayer', 'PGJANET']:
        # Check linear pruning
        nmse_linear = get_nmse_at_param_count(
            linear_pruning_results[model_name],
            param_count
        )
        if not np.isnan(nmse_linear) and nmse_linear < best_nmse:
            best_nmse = nmse_linear
            best_config = f'{model_name} (Linear)'
        
        # Check node pruning
        nmse_node = get_nmse_at_param_count(
            node_pruning_results[model_name],
            param_count
        )
        if not np.isnan(nmse_node) and nmse_node < best_nmse:
            best_nmse = nmse_node
            best_config = f'{model_name} (Node)'
    
    best_configs.append({
        'Parameter Budget': param_count,
        'Best Configuration': best_config,
        'NMSE (dB)': best_nmse if best_config else np.nan
    })

best_configs_df = pd.DataFrame(best_configs)

print("\n" + "="*80)
print("BEST CONFIGURATION FOR EACH PARAMETER BUDGET")
print("="*80)
print(best_configs_df.to_string(index=False, float_format=lambda x: f'{x:.2f}' if not np.isnan(x) else 'N/A'))
print("="*80)
# Out:
# ================================================================================
# BEST CONFIGURATION FOR EACH PARAMETER BUDGET
# ================================================================================
#  Parameter Budget  Best Configuration  NMSE (dB)
#               500     OneLayer (Node)     -40.30
#              1000 ThreeLayer (Linear)     -40.97
#              2000 MultiLayer (Linear)     -40.98
#              3000 MultiLayer (Linear)     -40.89
#              5000 MultiLayer (Linear)     -40.93
# ================================================================================

# %% [markdown]
# ### 5.5 Pareto Frontier Analysis

# %%
# Identify Pareto optimal configurations (best NMSE for each parameter count)
all_points = []

for model_name in ['OneLayer', 'ThreeLayer', 'MultiLayer', 'PGJANET']:
    # Linear pruning points
    for params, nmse in zip(linear_pruning_results[model_name]['params'],
                            linear_pruning_results[model_name]['nmse']):
        all_points.append({
            'params': params,
            'nmse': nmse,
            'model': model_name,
            'method': 'Linear'
        })
    
    # Node pruning points
    for params, nmse in zip(node_pruning_results[model_name]['params'],
                            node_pruning_results[model_name]['nmse']):
        all_points.append({
            'params': params,
            'nmse': nmse,
            'model': model_name,
            'method': 'Node'
        })

all_points_df = pd.DataFrame(all_points)

# Sort by parameter count
all_points_df = all_points_df.sort_values('params')

# Find Pareto frontier (for each parameter level, keep the best NMSE)
pareto_frontier = []
best_nmse_so_far = float('inf')

for _, row in all_points_df.iterrows():
    if row['nmse'] < best_nmse_so_far:
        best_nmse_so_far = row['nmse']
        pareto_frontier.append(row)

pareto_df = pd.DataFrame(pareto_frontier)

# Plot Pareto frontier
fig, ax = plt.subplots(figsize=(14, 8))

# Plot all points with transparency
for model_name in ['OneLayer', 'ThreeLayer', 'MultiLayer', 'PGJANET']:
    linear_results = linear_pruning_results[model_name]
    ax.scatter(linear_results['params'], linear_results['nmse'],
               color=model_colors[model_name], alpha=0.3, s=60)
    
    node_results = node_pruning_results[model_name]
    ax.scatter(node_results['params'], node_results['nmse'],
               color=model_colors[model_name], alpha=0.3, s=60, marker='s')

# Highlight Pareto frontier
ax.plot(pareto_df['params'], pareto_df['nmse'],
        color='red', linewidth=3, linestyle='-', marker='*', markersize=15,
        label='Pareto Frontier', zorder=10)

ax.set_xlabel('Number of Parameters', fontsize=14, fontweight='bold')
ax.set_ylabel('NMSE (dB)', fontsize=14, fontweight='bold')
ax.set_title('Pareto Frontier: Optimal Performance-Efficiency Trade-off', fontsize=16, fontweight='bold')
ax.legend(fontsize=12)
ax.grid(True, alpha=0.4, linestyle='--')
ax.invert_xaxis()  # Fewer params on right

plt.tight_layout()
plt.show()

# Display Pareto optimal configurations
print("\n" + "="*100)
print("PARETO OPTIMAL CONFIGURATIONS")
print("="*100)
print(pareto_df[['params', 'nmse', 'model', 'method']].to_string(index=False))
print("="*100)
# Out:
# ====================================================================================================
# PARETO OPTIMAL CONFIGURATIONS
# ====================================================================================================
#  params       nmse      model method
#       0  -7.473408   OneLayer   Node
#       0  -7.474972   OneLayer   Node
#      65 -35.221308   OneLayer Linear
#      82 -38.470038   OneLayer Linear
#     103 -38.692695   OneLayer Linear
#     129 -38.943639   OneLayer Linear
#     160 -39.127961   OneLayer Linear
#     194 -39.347932 ThreeLayer Linear
#     200 -40.847927   OneLayer Linear
#     250 -40.896082   OneLayer Linear
#     591 -40.927042 ThreeLayer Linear
#     738 -41.009551 ThreeLayer Linear
#    1155 -41.099548 MultiLayer Linear
# ====================================================================================================

# %% [markdown]
# ### 5.6 Performance Degradation Analysis

# %%
# Analyze how much performance degrades as parameters decrease
degradation_threshold = 1.0  # dB

min_params_data = []

for model_name in ['OneLayer', 'ThreeLayer', 'MultiLayer', 'PGJANET']:
    baseline_nmse = baseline_results[model_name]['nmse']
    
    # Linear pruning
    linear_params = np.array(linear_pruning_results[model_name]['params'])
    linear_nmse = np.array(linear_pruning_results[model_name]['nmse'])
    linear_degradation = linear_nmse - baseline_nmse
    
    acceptable_linear = linear_params[linear_degradation <= degradation_threshold]
    min_params_linear = acceptable_linear.min() if len(acceptable_linear) > 0 else np.nan
    
    # Node pruning
    node_params = np.array(node_pruning_results[model_name]['params'])
    node_nmse = np.array(node_pruning_results[model_name]['nmse'])
    node_degradation = node_nmse - baseline_nmse
    
    acceptable_node = node_params[node_degradation <= degradation_threshold]
    min_params_node = acceptable_node.min() if len(acceptable_node) > 0 else np.nan
    
    min_params_data.append({
        'Model': model_name,
        'Baseline Params': baseline_results[model_name]['params'],
        'Baseline NMSE': baseline_nmse,
        'Min Params (Linear)': min_params_linear,
        'Reduction (Linear)': f"{(1 - min_params_linear/baseline_results[model_name]['params'])*100:.1f}%" if not np.isnan(min_params_linear) else 'N/A',
        'Min Params (Node)': min_params_node,
        'Reduction (Node)': f"{(1 - min_params_node/baseline_results[model_name]['params'])*100:.1f}%" if not np.isnan(min_params_node) else 'N/A'
    })

min_params_df = pd.DataFrame(min_params_data)

print("\n" + "="*120)
print(f"MINIMUM PARAMETERS TO MAINTAIN PERFORMANCE (< {degradation_threshold} dB degradation)")
print("="*120)
print(min_params_df.to_string(index=False))
print("="*120)
# Out:
# ========================================================================================================================
# MINIMUM PARAMETERS TO MAINTAIN PERFORMANCE (< 1.0 dB degradation)
# ========================================================================================================================
#      Model  Baseline Params  Baseline NMSE  Min Params (Linear) Reduction (Linear)  Min Params (Node) Reduction (Node)
#   OneLayer              960     -40.637776                  200              79.2%                480            50.0%
# ThreeLayer             2820     -40.061011                  194              93.1%                724            74.3%
# MultiLayer            10768     -40.420816                  739              93.1%               6585            38.8%
#    PGJANET             1872     -36.267994                  392              79.1%               1872             0.0%
# ========================================================================================================================

# %% [markdown]
# ## 6. Key Findings and Conclusions

# %%
print("\n" + "="*100)
print("KEY FINDINGS")
print("="*100)

print("\n1. BASELINE PERFORMANCE:")
for name, results in sorted(baseline_results.items(), key=lambda x: x[1]['params']):
    print(f"   - {name}: {results['nmse']:.2f} dB NMSE with {results['params']:,} parameters")

print(f"\n2. PARAMETER REDUCTION (< {degradation_threshold} dB degradation):")
for _, row in min_params_df.iterrows():
    print(f"   - {row['Model']}:")
    print(f"      Linear: {row['Baseline Params']:,} → {int(row['Min Params (Linear)']):,} ({row['Reduction (Linear)']})" if not np.isnan(row['Min Params (Linear)']) else f"      Linear: N/A")
    print(f"      Node:   {row['Baseline Params']:,} → {int(row['Min Params (Node)']):,} ({row['Reduction (Node)']})" if not np.isnan(row['Min Params (Node)']) else f"      Node: N/A")

print("\n3. PARETO OPTIMAL CONFIGURATIONS:")
print(f"   - Best configuration varies by parameter budget")
print(f"   - Larger models can be pruned more aggressively")
print(f"   - {len(pareto_df)} distinct optimal points found")

print("\n4. METHOD COMPARISON:")
print("   - Linear pruning typically allows more aggressive parameter reduction")
print("   - Node pruning provides structured sparsity")
print("   - Best method depends on parameter budget and deployment constraints")

print("\n5. PRACTICAL RECOMMENDATIONS:")
if len(pareto_df) > 0:
    best_at_1000 = best_configs_df[best_configs_df['Parameter Budget'] == 1000]['Best Configuration'].values
    if len(best_at_1000) > 0:
        print(f"   - For ~1000 parameters: {best_at_1000[0]}")
    best_at_2000 = best_configs_df[best_configs_df['Parameter Budget'] == 2000]['Best Configuration'].values
    if len(best_at_2000) > 0:
        print(f"   - For ~2000 parameters: {best_at_2000[0]}")

print("\n" + "="*100)
# Out:
# ====================================================================================================
# KEY FINDINGS
# ====================================================================================================
#
# 1. BASELINE PERFORMANCE:
#    - OneLayer: -40.64 dB NMSE with 960 parameters
#    - PGJANET: -36.27 dB NMSE with 1,872 parameters
#    - ThreeLayer: -40.06 dB NMSE with 2,820 parameters
#    - MultiLayer: -40.42 dB NMSE with 10,768 parameters
#
# 2. PARAMETER REDUCTION (< 1.0 dB degradation):
#    - OneLayer:
#       Linear: 960 → 200 (79.2%)
#       Node:   960 → 480 (50.0%)
#    - ThreeLayer:
#       Linear: 2,820 → 194 (93.1%)
#       Node:   2,820 → 724 (74.3%)
#    - MultiLayer:
#       Linear: 10,768 → 739 (93.1%)
#       Node:   10,768 → 6,585 (38.8%)
#    - PGJANET:
#       Linear: 1,872 → 392 (79.1%)
#       Node:   1,872 → 1,872 (0.0%)
#
# 3. PARETO OPTIMAL CONFIGURATIONS:
#    - Best configuration varies by parameter budget
#    - Larger models can be pruned more aggressively
#    - 13 distinct optimal points found
#
# 4. METHOD COMPARISON:
#    - Linear pruning typically allows more aggressive parameter reduction
#    - Node pruning provides structured sparsity
#    - Best method depends on parameter budget and deployment constraints
#
# 5. PRACTICAL RECOMMENDATIONS:
#    - For ~1000 parameters: ThreeLayer (Linear)
#    - For ~2000 parameters: MultiLayer (Linear)
#
# ====================================================================================================

# %% [markdown]
# ## Summary
#
# This notebook demonstrates a **parameter-centric** analysis of neural network pruning for DPD applications:
#
# ### Key Insights:
# - **Absolute parameter count** is the relevant metric for deployment, not relative pruning percentage
# - Different model architectures achieve optimal efficiency at different parameter budgets
# - The **Pareto frontier** identifies the best configuration for any given parameter constraint
# - Pruning can reduce parameters by 50-80% with minimal performance loss
#
# ### Deployment Guidelines:
# 1. **Identify your parameter budget** (e.g., hardware constraints, memory limits)
# 2. **Select from Pareto frontier** the configuration that fits your budget
# 3. **Choose pruning method** based on whether you need structured (node) or unstructured (linear) sparsity
# 4. **Validate performance** meets your NMSE requirements
#
# This approach ensures you're making decisions based on **actual deployment constraints** rather than arbitrary pruning percentages.
