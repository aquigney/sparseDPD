# %%
from sparseDPD import DataManager, PNTDNN_NeuralNetwork, Volterra, LinearExperiment, AdaptivePruningExperiment

# Load the ideal predistorted signal, and plot
ideal_predistored_dataset = DataManager(num_training_points=50000, num_test_points=5000, num_validaiton_points=5000, filepath='200M_6_5PAPR.mat')

ideal_predistored_dataset.plot_pa_characteristics()

print(len(ideal_predistored_dataset.input_data))
# Out:
# === PA Characteristic Summary ===
# Input amplitude range: 0.0000 to 0.9384
# Output amplitude range: 0.0003 to 1.0917
# Estimated small-signal gain: 1.0596
# Phase distortion range: -139.61° to 1039.85°
# 80000

# %%
# Print Volterra Performance
volterra_forward_model = Volterra(num_nl_orders=3, num_memory_levels=15, dataset=ideal_predistored_dataset.training_dataset)

print(f" Volterra NMSE: {volterra_forward_model.calculate_volterra_nmse(ideal_predistored_dataset.test_dataset)} dB")
# Out:
#  Volterra NMSE: -36.78570189648688 dB

# %%
# Model the ideal predistorted (This will actually be modelled as a forward model)
pntdnn_ideal_predistorted = PNTDNN_NeuralNetwork(num_memory_levels=15, model_type="OneLayerNetwork", forward_model=True)

# train this model
pntdnn_ideal_predistorted.get_best_model(
    num_epochs = 1000,
    training_dataset=ideal_predistored_dataset.training_dataset,
    validation_dataset=ideal_predistored_dataset.validation_dataset
)

# Save the model, so it can be used later
pntdnn_ideal_predistorted.write_nn_to_file(file_path="pntdnn_ideal_predistorted_forward_model.pt")
# Out:
# Using cuda device
# Epoch  10/1000  Loss=1.1843e+03  Valid Loss=1.1044e+02  LR=1.00e-03  NMSE=-7.7072 dB
# Epoch  20/1000  Loss=2.0988e+02  Valid Loss=1.7803e+01  LR=1.00e-03  NMSE=-15.6337 dB
# Epoch  30/1000  Loss=8.3957e+01  Valid Loss=7.5732e+00  LR=1.00e-03  NMSE=-19.3459 dB
# Epoch  40/1000  Loss=4.7880e+01  Valid Loss=4.3724e+00  LR=1.00e-03  NMSE=-21.7314 dB
# Epoch  50/1000  Loss=3.0512e+01  Valid Loss=2.8445e+00  LR=1.00e-03  NMSE=-23.5986 dB
# Epoch  60/1000  Loss=2.0735e+01  Valid Loss=1.9861e+00  LR=1.00e-03  NMSE=-25.1586 dB
# Epoch  70/1000  Loss=1.4842e+01  Valid Loss=1.4610e+00  LR=1.00e-03  NMSE=-26.4921 dB
# Epoch  80/1000  Loss=1.1206e+01  Valid Loss=1.1212e+00  LR=1.00e-03  NMSE=-27.6419 dB
# Epoch  90/1000  Loss=8.8513e+00  Valid Loss=8.9156e-01  LR=1.00e-03  NMSE=-28.6372 dB
# Epoch 100/1000  Loss=7.2064e+00  Valid Loss=7.2841e-01  LR=1.00e-03  NMSE=-29.5149 dB
# Epoch 110/1000  Loss=5.9922e+00  Valid Loss=6.0667e-01  LR=1.00e-03  NMSE=-30.3091 dB
# Epoch 120/1000  Loss=5.0577e+00  Valid Loss=5.1291e-01  LR=1.00e-03  NMSE=-31.0382 dB
# Epoch 130/1000  Loss=4.3285e+00  Valid Loss=4.4026e-01  LR=1.00e-03  NMSE=-31.7016 dB
# Epoch 140/1000  Loss=3.7600e+00  Valid Loss=3.8476e-01  LR=1.00e-03  NMSE=-32.2868 dB
# Epoch 150/1000  Loss=3.3171e+00  Valid Loss=3.4262e-01  LR=1.00e-03  NMSE=-32.7905 dB
# Epoch 160/1000  Loss=2.9756e+00  Valid Loss=3.0978e-01  LR=1.00e-03  NMSE=-33.2282 dB
# Epoch 170/1000  Loss=2.7176e+00  Valid Loss=2.8380e-01  LR=1.00e-03  NMSE=-33.6086 dB
# Epoch 180/1000  Loss=2.5291e+00  Valid Loss=2.6403e-01  LR=1.00e-03  NMSE=-33.9221 dB
# Epoch 190/1000  Loss=2.3927e+00  Valid Loss=2.4951e-01  LR=1.00e-03  NMSE=-34.1677 dB
# Epoch 200/1000  Loss=2.2918e+00  Valid Loss=2.3906e-01  LR=1.00e-03  NMSE=-34.3537 dB
# Epoch 210/1000  Loss=2.2139e+00  Valid Loss=2.3154e-01  LR=1.00e-03  NMSE=-34.4925 dB
# Epoch 220/1000  Loss=2.1501e+00  Valid Loss=2.2563e-01  LR=1.00e-03  NMSE=-34.6046 dB
# Epoch 230/1000  Loss=2.0925e+00  Valid Loss=2.2043e-01  LR=1.00e-03  NMSE=-34.7060 dB
# Epoch 240/1000  Loss=2.0377e+00  Valid Loss=2.1492e-01  LR=1.00e-03  NMSE=-34.8160 dB
# Epoch 250/1000  Loss=1.9899e+00  Valid Loss=2.0962e-01  LR=1.00e-03  NMSE=-34.9243 dB
# Epoch 260/1000  Loss=1.9490e+00  Valid Loss=2.0507e-01  LR=1.00e-03  NMSE=-35.0196 dB
# Epoch 270/1000  Loss=1.9105e+00  Valid Loss=2.0089e-01  LR=1.00e-03  NMSE=-35.1090 dB
# Epoch 280/1000  Loss=1.8729e+00  Valid Loss=1.9669e-01  LR=1.00e-03  NMSE=-35.2008 dB
# Epoch 290/1000  Loss=1.8334e+00  Valid Loss=1.9256e-01  LR=1.00e-03  NMSE=-35.2929 dB
# Epoch 300/1000  Loss=1.7899e+00  Valid Loss=1.8771e-01  LR=1.00e-03  NMSE=-35.4038 dB
# Epoch 310/1000  Loss=1.7411e+00  Valid Loss=1.8170e-01  LR=1.00e-03  NMSE=-35.5450 dB
# Epoch 320/1000  Loss=1.6870e+00  Valid Loss=1.7441e-01  LR=1.00e-03  NMSE=-35.7229 dB
# Epoch 330/1000  Loss=1.6427e+00  Valid Loss=1.6791e-01  LR=1.00e-03  NMSE=-35.8878 dB
# Epoch 340/1000  Loss=1.6076e+00  Valid Loss=1.6267e-01  LR=1.00e-03  NMSE=-36.0255 dB
# Epoch 350/1000  Loss=1.5776e+00  Valid Loss=1.5855e-01  LR=1.00e-03  NMSE=-36.1371 dB
# Epoch 360/1000  Loss=1.5498e+00  Valid Loss=1.5501e-01  LR=1.00e-03  NMSE=-36.2352 dB
# Epoch 370/1000  Loss=1.5244e+00  Valid Loss=1.5179e-01  LR=1.00e-03  NMSE=-36.3262 dB
# Epoch 380/1000  Loss=1.5002e+00  Valid Loss=1.4882e-01  LR=1.00e-03  NMSE=-36.4119 dB
# Epoch 390/1000  Loss=1.4776e+00  Valid Loss=1.4610e-01  LR=1.00e-03  NMSE=-36.4921 dB
# Epoch 400/1000  Loss=1.4562e+00  Valid Loss=1.4357e-01  LR=1.00e-03  NMSE=-36.5679 dB
# Epoch 410/1000  Loss=1.4356e+00  Valid Loss=1.4118e-01  LR=1.00e-03  NMSE=-36.6409 dB
# Epoch 420/1000  Loss=1.4158e+00  Valid Loss=1.3887e-01  LR=1.00e-03  NMSE=-36.7127 dB
# Epoch 430/1000  Loss=1.3960e+00  Valid Loss=1.3661e-01  LR=1.00e-03  NMSE=-36.7839 dB
# Epoch 440/1000  Loss=1.3756e+00  Valid Loss=1.3424e-01  LR=1.00e-03  NMSE=-36.8598 dB
# Epoch 450/1000  Loss=1.3554e+00  Valid Loss=1.3185e-01  LR=1.00e-03  NMSE=-36.9378 dB
# Epoch 460/1000  Loss=1.3330e+00  Valid Loss=1.2926e-01  LR=1.00e-03  NMSE=-37.0242 dB
# Epoch 470/1000  Loss=1.3107e+00  Valid Loss=1.2664e-01  LR=1.00e-03  NMSE=-37.1129 dB
# Epoch 480/1000  Loss=1.2875e+00  Valid Loss=1.2365e-01  LR=1.00e-03  NMSE=-37.2167 dB
# Epoch 490/1000  Loss=1.2620e+00  Valid Loss=1.2034e-01  LR=1.00e-03  NMSE=-37.3345 dB
# Epoch 500/1000  Loss=1.2323e+00  Valid Loss=1.1694e-01  LR=1.00e-03  NMSE=-37.4591 dB
# Epoch 510/1000  Loss=1.1886e+00  Valid Loss=1.1279e-01  LR=1.00e-03  NMSE=-37.6159 dB
# Epoch 520/1000  Loss=1.1398e+00  Valid Loss=1.0716e-01  LR=1.00e-03  NMSE=-37.8382 dB
# Epoch 530/1000  Loss=1.0726e+00  Valid Loss=1.0032e-01  LR=1.00e-03  NMSE=-38.1248 dB
# Epoch 540/1000  Loss=1.0140e+00  Valid Loss=9.4887e-02  LR=1.00e-03  NMSE=-38.3666 dB
# Epoch 550/1000  Loss=9.7412e-01  Valid Loss=9.0794e-02  LR=1.00e-03  NMSE=-38.5581 dB
# Epoch 560/1000  Loss=9.4131e-01  Valid Loss=8.7323e-02  LR=1.00e-03  NMSE=-38.7274 dB
# Epoch 570/1000  Loss=9.1466e-01  Valid Loss=8.4443e-02  LR=1.00e-03  NMSE=-38.8730 dB
# Epoch 580/1000  Loss=8.8815e-01  Valid Loss=8.1600e-02  LR=1.00e-03  NMSE=-39.0218 dB
# Epoch 590/1000  Loss=8.6495e-01  Valid Loss=7.9197e-02  LR=1.00e-03  NMSE=-39.1516 dB
# Epoch 600/1000  Loss=8.4584e-01  Valid Loss=7.7095e-02  LR=1.00e-03  NMSE=-39.2684 dB
# Epoch 610/1000  Loss=8.2884e-01  Valid Loss=7.5109e-02  LR=1.00e-03  NMSE=-39.3818 dB
# Epoch 620/1000  Loss=8.1114e-01  Valid Loss=7.3336e-02  LR=1.00e-03  NMSE=-39.4855 dB
# Epoch 630/1000  Loss=7.9651e-01  Valid Loss=7.1850e-02  LR=1.00e-03  NMSE=-39.5744 dB
# Epoch 640/1000  Loss=7.8322e-01  Valid Loss=7.0496e-02  LR=1.00e-03  NMSE=-39.6570 dB
# Epoch 650/1000  Loss=7.7164e-01  Valid Loss=6.9294e-02  LR=1.00e-03  NMSE=-39.7317 dB
# Epoch 660/1000  Loss=7.6071e-01  Valid Loss=6.8191e-02  LR=1.00e-03  NMSE=-39.8014 dB
# Epoch 670/1000  Loss=7.5067e-01  Valid Loss=6.7185e-02  LR=1.00e-03  NMSE=-39.8659 dB
# Epoch 680/1000  Loss=7.4194e-01  Valid Loss=6.6245e-02  LR=1.00e-03  NMSE=-39.9271 dB
# Epoch 690/1000  Loss=7.3332e-01  Valid Loss=6.5378e-02  LR=1.00e-03  NMSE=-39.9844 dB
# Epoch 700/1000  Loss=7.2612e-01  Valid Loss=6.4616e-02  LR=1.00e-03  NMSE=-40.0353 dB
# Epoch 710/1000  Loss=7.1943e-01  Valid Loss=6.3908e-02  LR=1.00e-03  NMSE=-40.0831 dB
# Epoch 720/1000  Loss=7.1318e-01  Valid Loss=6.3256e-02  LR=1.00e-03  NMSE=-40.1276 dB
# Epoch 730/1000  Loss=7.0822e-01  Valid Loss=6.2689e-02  LR=1.00e-03  NMSE=-40.1667 dB
# Epoch 740/1000  Loss=7.0322e-01  Valid Loss=6.2168e-02  LR=1.00e-03  NMSE=-40.2030 dB
# Epoch 750/1000  Loss=6.9894e-01  Valid Loss=6.1691e-02  LR=1.00e-03  NMSE=-40.2364 dB
# Epoch 760/1000  Loss=6.9457e-01  Valid Loss=6.1253e-02  LR=1.00e-03  NMSE=-40.2674 dB
# Epoch 770/1000  Loss=6.9114e-01  Valid Loss=6.0879e-02  LR=1.00e-03  NMSE=-40.2940 dB
# Epoch 780/1000  Loss=6.8809e-01  Valid Loss=6.0531e-02  LR=1.00e-03  NMSE=-40.3189 dB
# Epoch 790/1000  Loss=6.8520e-01  Valid Loss=6.0192e-02  LR=1.00e-03  NMSE=-40.3433 dB
# Epoch 800/1000  Loss=6.8248e-01  Valid Loss=5.9884e-02  LR=1.00e-03  NMSE=-40.3656 dB
# Epoch 810/1000  Loss=6.7968e-01  Valid Loss=5.9599e-02  LR=1.00e-03  NMSE=-40.3862 dB
# Epoch 820/1000  Loss=6.7726e-01  Valid Loss=5.9332e-02  LR=1.00e-03  NMSE=-40.4058 dB
# Epoch 830/1000  Loss=6.7507e-01  Valid Loss=5.9099e-02  LR=1.00e-03  NMSE=-40.4229 dB
# Epoch 840/1000  Loss=6.7307e-01  Valid Loss=5.8871e-02  LR=1.00e-03  NMSE=-40.4396 dB
# Epoch 850/1000  Loss=6.7093e-01  Valid Loss=5.8652e-02  LR=1.00e-03  NMSE=-40.4558 dB
# Epoch 860/1000  Loss=6.6894e-01  Valid Loss=5.8442e-02  LR=1.00e-03  NMSE=-40.4714 dB
# Epoch 870/1000  Loss=6.6742e-01  Valid Loss=5.8261e-02  LR=1.00e-03  NMSE=-40.4849 dB
# Epoch 880/1000  Loss=6.6553e-01  Valid Loss=5.8057e-02  LR=1.00e-03  NMSE=-40.5001 dB
# Epoch 890/1000  Loss=6.6382e-01  Valid Loss=5.7873e-02  LR=1.00e-03  NMSE=-40.5139 dB
# Epoch 900/1000  Loss=6.6219e-01  Valid Loss=5.7702e-02  LR=1.00e-03  NMSE=-40.5268 dB
# Epoch 910/1000  Loss=6.6057e-01  Valid Loss=5.7531e-02  LR=1.00e-03  NMSE=-40.5396 dB
# Epoch 920/1000  Loss=6.5916e-01  Valid Loss=5.7392e-02  LR=1.00e-03  NMSE=-40.5502 dB
# Epoch 930/1000  Loss=6.5781e-01  Valid Loss=5.7244e-02  LR=1.00e-03  NMSE=-40.5614 dB
# Epoch 940/1000  Loss=6.5618e-01  Valid Loss=5.7089e-02  LR=1.00e-03  NMSE=-40.5731 dB
# Epoch 950/1000  Loss=6.5494e-01  Valid Loss=5.6960e-02  LR=1.00e-03  NMSE=-40.5830 dB
# Epoch 960/1000  Loss=6.5356e-01  Valid Loss=5.6819e-02  LR=1.00e-03  NMSE=-40.5937 dB
# Epoch 970/1000  Loss=6.5258e-01  Valid Loss=5.6699e-02  LR=1.00e-03  NMSE=-40.6029 dB
# Epoch 980/1000  Loss=6.5125e-01  Valid Loss=5.6563e-02  LR=1.00e-03  NMSE=-40.6134 dB
# Epoch 990/1000  Loss=6.4980e-01  Valid Loss=5.6441e-02  LR=1.00e-03  NMSE=-40.6227 dB
# Epoch 1000/1000  Loss=6.4856e-01  Valid Loss=5.6322e-02  LR=1.00e-03  NMSE=-40.6319 dB
#
# Best model from epoch 1000 with validation loss: 5.6322e-02

# %%
# Linearly prune the model
# Load the model
pntdnn_ideal_predistorted = PNTDNN_NeuralNetwork(num_memory_levels=15, model_type="OneLayerNetwork", forward_model=True, nn_file_path="pntdnn_ideal_predistorted_forward_model.pt")

pntdnn_ideal_pruning_experiment = LinearExperiment(
    nn_model= pntdnn_ideal_predistorted,
    num_prune_iterations=10,
    prune_amount=0.2,
    retrain_epochs=300,
    training_dataset=ideal_predistored_dataset.training_dataset,
    valid_dataset=ideal_predistored_dataset.validation_dataset,
    test_dataset=ideal_predistored_dataset.test_dataset,
    nmse_tolerance=-38
)
pntdnn_ideal_pruning_experiment.run()

# Save the best model
pntdnn_ideal_pruning_experiment.best_model.write_nn_to_file(file_path="pntdnn_ideal_predistorted_forward_model_linear_pruned.pt")
# Out:
# Using cuda device
#
# ============================================================
# Pruning Iteration 1/10
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 20.00% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=5.7187e-01  Valid Loss=5.7919e-02  LR=1.00e-03  NMSE=-40.5105 dB
# Epoch  20/300  Loss=5.6771e-01  Valid Loss=5.5549e-02  LR=1.00e-03  NMSE=-40.6919 dB
# Epoch  30/300  Loss=5.7184e-01  Valid Loss=5.4901e-02  LR=1.00e-03  NMSE=-40.7429 dB
# Epoch  40/300  Loss=5.9749e-01  Valid Loss=5.4375e-02  LR=1.00e-03  NMSE=-40.7846 dB
# Epoch  50/300  Loss=6.1067e-01  Valid Loss=5.3517e-02  LR=1.00e-03  NMSE=-40.8537 dB
# Epoch  60/300  Loss=6.0285e-01  Valid Loss=5.2581e-02  LR=1.00e-03  NMSE=-40.9303 dB
# Epoch  70/300  Loss=5.9776e-01  Valid Loss=5.2104e-02  LR=1.00e-03  NMSE=-40.9700 dB
# Epoch  80/300  Loss=5.9437e-01  Valid Loss=5.1750e-02  LR=1.00e-03  NMSE=-40.9996 dB
# Epoch  90/300  Loss=5.9216e-01  Valid Loss=5.1419e-02  LR=1.00e-03  NMSE=-41.0274 dB
# Epoch 100/300  Loss=5.8966e-01  Valid Loss=5.1159e-02  LR=1.00e-03  NMSE=-41.0494 dB
# Epoch 110/300  Loss=5.8727e-01  Valid Loss=5.0936e-02  LR=1.00e-03  NMSE=-41.0684 dB
# Epoch 120/300  Loss=5.8528e-01  Valid Loss=5.0702e-02  LR=1.00e-03  NMSE=-41.0884 dB
# Epoch 130/300  Loss=5.8405e-01  Valid Loss=5.0492e-02  LR=1.00e-03  NMSE=-41.1065 dB
# Epoch 140/300  Loss=5.8243e-01  Valid Loss=5.0298e-02  LR=1.00e-03  NMSE=-41.1232 dB
# Epoch 150/300  Loss=5.8039e-01  Valid Loss=5.0113e-02  LR=1.00e-03  NMSE=-41.1392 dB
# Epoch 160/300  Loss=5.7865e-01  Valid Loss=4.9941e-02  LR=1.00e-03  NMSE=-41.1541 dB
# Epoch 170/300  Loss=5.7753e-01  Valid Loss=4.9769e-02  LR=1.00e-03  NMSE=-41.1691 dB
# Epoch 180/300  Loss=5.7634e-01  Valid Loss=4.9614e-02  LR=1.00e-03  NMSE=-41.1826 dB
# Epoch 190/300  Loss=5.7508e-01  Valid Loss=4.9468e-02  LR=1.00e-03  NMSE=-41.1954 dB
# Epoch 200/300  Loss=5.7384e-01  Valid Loss=4.9336e-02  LR=1.00e-03  NMSE=-41.2070 dB
# Epoch 210/300  Loss=5.7285e-01  Valid Loss=4.9202e-02  LR=1.00e-03  NMSE=-41.2189 dB
# Epoch 220/300  Loss=5.7188e-01  Valid Loss=4.9074e-02  LR=1.00e-03  NMSE=-41.2302 dB
# Epoch 230/300  Loss=5.7089e-01  Valid Loss=4.8949e-02  LR=1.00e-03  NMSE=-41.2412 dB
# Epoch 240/300  Loss=5.6966e-01  Valid Loss=4.8834e-02  LR=1.00e-03  NMSE=-41.2514 dB
# Epoch 250/300  Loss=5.6886e-01  Valid Loss=4.8731e-02  LR=1.00e-03  NMSE=-41.2606 dB
# Epoch 260/300  Loss=5.6804e-01  Valid Loss=4.8618e-02  LR=1.00e-03  NMSE=-41.2707 dB
# Epoch 270/300  Loss=5.6717e-01  Valid Loss=4.8516e-02  LR=1.00e-03  NMSE=-41.2798 dB
# Epoch 280/300  Loss=5.6622e-01  Valid Loss=4.8409e-02  LR=1.00e-03  NMSE=-41.2894 dB
# Epoch 290/300  Loss=5.6559e-01  Valid Loss=4.8317e-02  LR=1.00e-03  NMSE=-41.2976 dB
# Epoch 300/300  Loss=5.6483e-01  Valid Loss=4.8215e-02  LR=1.00e-03  NMSE=-41.3068 dB
#
# Best model from epoch 299 with validation loss: 4.8212e-02
# NMSE: -40.6761 dB
#
# ============================================================
# Pruning Iteration 2/10
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 35.97% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=6.6010e-01  Valid Loss=6.6906e-02  LR=1.00e-03  NMSE=-39.8840 dB
# Epoch  20/300  Loss=5.6454e-01  Valid Loss=5.6884e-02  LR=1.00e-03  NMSE=-40.5888 dB
# Epoch  30/300  Loss=5.4881e-01  Valid Loss=5.3755e-02  LR=1.00e-03  NMSE=-40.8345 dB
# Epoch  40/300  Loss=5.6571e-01  Valid Loss=5.2418e-02  LR=1.00e-03  NMSE=-40.9438 dB
# Epoch  50/300  Loss=5.6251e-01  Valid Loss=5.1417e-02  LR=1.00e-03  NMSE=-41.0276 dB
# Epoch  60/300  Loss=5.5576e-01  Valid Loss=5.0438e-02  LR=1.00e-03  NMSE=-41.1111 dB
# Epoch  70/300  Loss=5.5284e-01  Valid Loss=4.9786e-02  LR=1.00e-03  NMSE=-41.1676 dB
# Epoch  80/300  Loss=5.5093e-01  Valid Loss=4.9298e-02  LR=1.00e-03  NMSE=-41.2104 dB
# Epoch  90/300  Loss=5.4964e-01  Valid Loss=4.8904e-02  LR=1.00e-03  NMSE=-41.2452 dB
# Epoch 100/300  Loss=5.4862e-01  Valid Loss=4.8601e-02  LR=1.00e-03  NMSE=-41.2722 dB
# Epoch 110/300  Loss=5.4735e-01  Valid Loss=4.8357e-02  LR=1.00e-03  NMSE=-41.2940 dB
# Epoch 120/300  Loss=5.4589e-01  Valid Loss=4.8149e-02  LR=1.00e-03  NMSE=-41.3128 dB
# Epoch 130/300  Loss=5.4457e-01  Valid Loss=4.7963e-02  LR=1.00e-03  NMSE=-41.3296 dB
# Epoch 140/300  Loss=5.4334e-01  Valid Loss=4.7795e-02  LR=1.00e-03  NMSE=-41.3448 dB
# Epoch 150/300  Loss=5.4231e-01  Valid Loss=4.7655e-02  LR=1.00e-03  NMSE=-41.3576 dB
# Epoch 160/300  Loss=5.4128e-01  Valid Loss=4.7523e-02  LR=1.00e-03  NMSE=-41.3696 dB
# Epoch 170/300  Loss=5.4041e-01  Valid Loss=4.7397e-02  LR=1.00e-03  NMSE=-41.3811 dB
# Epoch 180/300  Loss=5.3942e-01  Valid Loss=4.7278e-02  LR=1.00e-03  NMSE=-41.3921 dB
# Epoch 190/300  Loss=5.3831e-01  Valid Loss=4.7156e-02  LR=1.00e-03  NMSE=-41.4033 dB
# Epoch 200/300  Loss=5.3723e-01  Valid Loss=4.7046e-02  LR=1.00e-03  NMSE=-41.4135 dB
# Epoch 210/300  Loss=5.3621e-01  Valid Loss=4.6935e-02  LR=1.00e-03  NMSE=-41.4237 dB
# Epoch 220/300  Loss=5.3525e-01  Valid Loss=4.6822e-02  LR=1.00e-03  NMSE=-41.4341 dB
# Epoch 230/300  Loss=5.3446e-01  Valid Loss=4.6714e-02  LR=1.00e-03  NMSE=-41.4442 dB
# Epoch 240/300  Loss=5.3375e-01  Valid Loss=4.6606e-02  LR=1.00e-03  NMSE=-41.4542 dB
# Epoch 250/300  Loss=5.3318e-01  Valid Loss=4.6517e-02  LR=1.00e-03  NMSE=-41.4625 dB
# Epoch 260/300  Loss=5.3251e-01  Valid Loss=4.6441e-02  LR=1.00e-03  NMSE=-41.4696 dB
# Epoch 270/300  Loss=5.3187e-01  Valid Loss=4.6362e-02  LR=1.00e-03  NMSE=-41.4770 dB
# Epoch 280/300  Loss=5.3123e-01  Valid Loss=4.6291e-02  LR=1.00e-03  NMSE=-41.4837 dB
# Epoch 290/300  Loss=5.3064e-01  Valid Loss=4.6222e-02  LR=1.00e-03  NMSE=-41.4902 dB
# Epoch 300/300  Loss=5.3020e-01  Valid Loss=4.6147e-02  LR=1.00e-03  NMSE=-41.4972 dB
#
# Best model from epoch 300 with validation loss: 4.6147e-02
# NMSE: -40.8249 dB
#
# ============================================================
# Pruning Iteration 3/10
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 48.75% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=8.6729e-01  Valid Loss=8.2869e-02  LR=1.00e-03  NMSE=-38.9547 dB
# Epoch  20/300  Loss=6.8914e-01  Valid Loss=6.8627e-02  LR=1.00e-03  NMSE=-39.7737 dB
# Epoch  30/300  Loss=6.4589e-01  Valid Loss=6.4091e-02  LR=1.00e-03  NMSE=-40.0707 dB
# Epoch  40/300  Loss=6.3582e-01  Valid Loss=6.1632e-02  LR=1.00e-03  NMSE=-40.2406 dB
# Epoch  50/300  Loss=6.3772e-01  Valid Loss=6.1402e-02  LR=1.00e-03  NMSE=-40.2569 dB
# Epoch  60/300  Loss=5.7863e-01  Valid Loss=5.8591e-02  LR=5.00e-04  NMSE=-40.4604 dB
# Epoch  70/300  Loss=5.7766e-01  Valid Loss=5.8004e-02  LR=5.00e-04  NMSE=-40.5041 dB
# Epoch  80/300  Loss=5.7367e-01  Valid Loss=5.6792e-02  LR=5.00e-04  NMSE=-40.5958 dB
# Epoch  90/300  Loss=5.6937e-01  Valid Loss=5.6232e-02  LR=5.00e-04  NMSE=-40.6388 dB
# Epoch 100/300  Loss=5.6677e-01  Valid Loss=5.5677e-02  LR=5.00e-04  NMSE=-40.6819 dB
# Epoch 110/300  Loss=5.6569e-01  Valid Loss=5.5127e-02  LR=5.00e-04  NMSE=-40.7250 dB
# Epoch 120/300  Loss=5.6551e-01  Valid Loss=5.4618e-02  LR=5.00e-04  NMSE=-40.7653 dB
# Epoch 130/300  Loss=5.6568e-01  Valid Loss=5.4211e-02  LR=5.00e-04  NMSE=-40.7978 dB
# Epoch 140/300  Loss=5.6557e-01  Valid Loss=5.3941e-02  LR=5.00e-04  NMSE=-40.8195 dB
# Epoch 150/300  Loss=5.6480e-01  Valid Loss=5.3784e-02  LR=5.00e-04  NMSE=-40.8322 dB
# Epoch 160/300  Loss=5.6328e-01  Valid Loss=5.3684e-02  LR=5.00e-04  NMSE=-40.8402 dB
# Epoch 170/300  Loss=5.6126e-01  Valid Loss=5.3599e-02  LR=5.00e-04  NMSE=-40.8471 dB
# Epoch 180/300  Loss=5.5889e-01  Valid Loss=5.3500e-02  LR=5.00e-04  NMSE=-40.8552 dB
# Epoch 190/300  Loss=5.5638e-01  Valid Loss=5.3399e-02  LR=5.00e-04  NMSE=-40.8633 dB
# Epoch 200/300  Loss=5.5389e-01  Valid Loss=5.3288e-02  LR=5.00e-04  NMSE=-40.8723 dB
# Epoch 210/300  Loss=5.5132e-01  Valid Loss=5.3165e-02  LR=5.00e-04  NMSE=-40.8824 dB
# Epoch 220/300  Loss=5.4874e-01  Valid Loss=5.3037e-02  LR=5.00e-04  NMSE=-40.8929 dB
# Epoch 230/300  Loss=5.4621e-01  Valid Loss=5.2913e-02  LR=5.00e-04  NMSE=-40.9030 dB
# Epoch 240/300  Loss=5.4361e-01  Valid Loss=5.2805e-02  LR=5.00e-04  NMSE=-40.9119 dB
# Epoch 250/300  Loss=5.4114e-01  Valid Loss=5.2722e-02  LR=5.00e-04  NMSE=-40.9188 dB
# Epoch 260/300  Loss=5.3873e-01  Valid Loss=5.2674e-02  LR=5.00e-04  NMSE=-40.9227 dB
# Epoch 270/300  Loss=5.3634e-01  Valid Loss=5.2643e-02  LR=5.00e-04  NMSE=-40.9253 dB
# Epoch 280/300  Loss=5.3395e-01  Valid Loss=5.2631e-02  LR=5.00e-04  NMSE=-40.9263 dB
# Epoch 290/300  Loss=4.9587e-01  Valid Loss=4.9310e-02  LR=2.50e-04  NMSE=-41.2094 dB
# Epoch 300/300  Loss=4.9612e-01  Valid Loss=4.9228e-02  LR=2.50e-04  NMSE=-41.2165 dB
#
# Best model from epoch 291 with validation loss: 4.9187e-02
# NMSE: -40.5475 dB
#
# ============================================================
# Pruning Iteration 4/10
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 59.03% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=1.3795e+00  Valid Loss=1.2746e-01  LR=1.00e-03  NMSE=-37.0849 dB
# Epoch  20/300  Loss=1.0419e+00  Valid Loss=1.0244e-01  LR=1.00e-03  NMSE=-38.0339 dB
# Epoch  30/300  Loss=9.0032e-01  Valid Loss=9.2483e-02  LR=1.00e-03  NMSE=-38.4780 dB
# Epoch  40/300  Loss=8.1580e-01  Valid Loss=8.5542e-02  LR=1.00e-03  NMSE=-38.8169 dB
# Epoch  50/300  Loss=7.5976e-01  Valid Loss=7.9654e-02  LR=1.00e-03  NMSE=-39.1266 dB
# Epoch  60/300  Loss=7.2287e-01  Valid Loss=7.5338e-02  LR=1.00e-03  NMSE=-39.3685 dB
# Epoch  70/300  Loss=6.9517e-01  Valid Loss=7.0494e-02  LR=1.00e-03  NMSE=-39.6571 dB
# Epoch  80/300  Loss=6.6760e-01  Valid Loss=6.7949e-02  LR=1.00e-03  NMSE=-39.8169 dB
# Epoch  90/300  Loss=6.4707e-01  Valid Loss=6.5699e-02  LR=1.00e-03  NMSE=-39.9631 dB
# Epoch 100/300  Loss=6.3141e-01  Valid Loss=6.3802e-02  LR=1.00e-03  NMSE=-40.0903 dB
# Epoch 110/300  Loss=6.1876e-01  Valid Loss=6.2184e-02  LR=1.00e-03  NMSE=-40.2018 dB
# Epoch 120/300  Loss=6.0904e-01  Valid Loss=6.0784e-02  LR=1.00e-03  NMSE=-40.3008 dB
# Epoch 130/300  Loss=6.0252e-01  Valid Loss=5.9562e-02  LR=1.00e-03  NMSE=-40.3890 dB
# Epoch 140/300  Loss=6.0020e-01  Valid Loss=5.8445e-02  LR=1.00e-03  NMSE=-40.4712 dB
# Epoch 150/300  Loss=6.0075e-01  Valid Loss=5.7512e-02  LR=1.00e-03  NMSE=-40.5411 dB
# Epoch 160/300  Loss=5.9968e-01  Valid Loss=5.6795e-02  LR=1.00e-03  NMSE=-40.5955 dB
# Epoch 170/300  Loss=5.9622e-01  Valid Loss=5.6212e-02  LR=1.00e-03  NMSE=-40.6403 dB
# Epoch 180/300  Loss=5.9241e-01  Valid Loss=5.5708e-02  LR=1.00e-03  NMSE=-40.6795 dB
# Epoch 190/300  Loss=5.8901e-01  Valid Loss=5.5288e-02  LR=1.00e-03  NMSE=-40.7124 dB
# Epoch 200/300  Loss=5.8590e-01  Valid Loss=5.4929e-02  LR=1.00e-03  NMSE=-40.7406 dB
# Epoch 210/300  Loss=5.8317e-01  Valid Loss=5.4609e-02  LR=1.00e-03  NMSE=-40.7660 dB
# Epoch 220/300  Loss=5.8056e-01  Valid Loss=5.4321e-02  LR=1.00e-03  NMSE=-40.7890 dB
# Epoch 230/300  Loss=5.7812e-01  Valid Loss=5.4059e-02  LR=1.00e-03  NMSE=-40.8099 dB
# Epoch 240/300  Loss=5.7595e-01  Valid Loss=5.3816e-02  LR=1.00e-03  NMSE=-40.8296 dB
# Epoch 250/300  Loss=5.7403e-01  Valid Loss=5.3605e-02  LR=1.00e-03  NMSE=-40.8466 dB
# Epoch 260/300  Loss=5.7214e-01  Valid Loss=5.3407e-02  LR=1.00e-03  NMSE=-40.8627 dB
# Epoch 270/300  Loss=5.7046e-01  Valid Loss=5.3226e-02  LR=1.00e-03  NMSE=-40.8774 dB
# Epoch 280/300  Loss=5.6884e-01  Valid Loss=5.3051e-02  LR=1.00e-03  NMSE=-40.8917 dB
# Epoch 290/300  Loss=5.6731e-01  Valid Loss=5.2889e-02  LR=1.00e-03  NMSE=-40.9050 dB
# Epoch 300/300  Loss=5.6583e-01  Valid Loss=5.2738e-02  LR=1.00e-03  NMSE=-40.9174 dB
#
# Best model from epoch 300 with validation loss: 5.2738e-02
# NMSE: -40.3603 dB
#
# ============================================================
# Pruning Iteration 5/10
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 67.22% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=1.2321e+00  Valid Loss=1.1860e-01  LR=1.00e-03  NMSE=-37.3977 dB
# Epoch  20/300  Loss=8.9549e-01  Valid Loss=9.2567e-02  LR=1.00e-03  NMSE=-38.4741 dB
# Epoch  30/300  Loss=7.6146e-01  Valid Loss=7.8081e-02  LR=1.00e-03  NMSE=-39.2132 dB
# Epoch  40/300  Loss=6.9649e-01  Valid Loss=7.0567e-02  LR=1.00e-03  NMSE=-39.6526 dB
# Epoch  50/300  Loss=6.5824e-01  Valid Loss=6.5159e-02  LR=1.00e-03  NMSE=-39.9989 dB
# Epoch  60/300  Loss=6.2889e-01  Valid Loss=6.2650e-02  LR=1.00e-03  NMSE=-40.1694 dB
# Epoch  70/300  Loss=6.1087e-01  Valid Loss=6.0812e-02  LR=1.00e-03  NMSE=-40.2988 dB
# Epoch  80/300  Loss=5.9905e-01  Valid Loss=5.9527e-02  LR=1.00e-03  NMSE=-40.3915 dB
# Epoch  90/300  Loss=5.9143e-01  Valid Loss=5.8537e-02  LR=1.00e-03  NMSE=-40.4643 dB
# Epoch 100/300  Loss=5.8751e-01  Valid Loss=5.7696e-02  LR=1.00e-03  NMSE=-40.5272 dB
# Epoch 110/300  Loss=5.8714e-01  Valid Loss=5.6965e-02  LR=1.00e-03  NMSE=-40.5826 dB
# Epoch 120/300  Loss=5.8810e-01  Valid Loss=5.6399e-02  LR=1.00e-03  NMSE=-40.6259 dB
# Epoch 130/300  Loss=5.8711e-01  Valid Loss=5.5992e-02  LR=1.00e-03  NMSE=-40.6574 dB
# Epoch 140/300  Loss=5.8475e-01  Valid Loss=5.5676e-02  LR=1.00e-03  NMSE=-40.6820 dB
# Epoch 150/300  Loss=5.8213e-01  Valid Loss=5.5406e-02  LR=1.00e-03  NMSE=-40.7031 dB
# Epoch 160/300  Loss=5.7961e-01  Valid Loss=5.5171e-02  LR=1.00e-03  NMSE=-40.7216 dB
# Epoch 170/300  Loss=5.7733e-01  Valid Loss=5.4965e-02  LR=1.00e-03  NMSE=-40.7378 dB
# Epoch 180/300  Loss=5.7515e-01  Valid Loss=5.4785e-02  LR=1.00e-03  NMSE=-40.7520 dB
# Epoch 190/300  Loss=5.7309e-01  Valid Loss=5.4620e-02  LR=1.00e-03  NMSE=-40.7652 dB
# Epoch 200/300  Loss=5.7124e-01  Valid Loss=5.4463e-02  LR=1.00e-03  NMSE=-40.7777 dB
# Epoch 210/300  Loss=5.6953e-01  Valid Loss=5.4310e-02  LR=1.00e-03  NMSE=-40.7898 dB
# Epoch 220/300  Loss=5.6792e-01  Valid Loss=5.4160e-02  LR=1.00e-03  NMSE=-40.8018 dB
# Epoch 230/300  Loss=5.6641e-01  Valid Loss=5.4015e-02  LR=1.00e-03  NMSE=-40.8135 dB
# Epoch 240/300  Loss=5.6508e-01  Valid Loss=5.3880e-02  LR=1.00e-03  NMSE=-40.8244 dB
# Epoch 250/300  Loss=5.6381e-01  Valid Loss=5.3741e-02  LR=1.00e-03  NMSE=-40.8356 dB
# Epoch 260/300  Loss=5.6262e-01  Valid Loss=5.3609e-02  LR=1.00e-03  NMSE=-40.8463 dB
# Epoch 270/300  Loss=5.6146e-01  Valid Loss=5.3484e-02  LR=1.00e-03  NMSE=-40.8564 dB
# Epoch 280/300  Loss=5.6041e-01  Valid Loss=5.3367e-02  LR=1.00e-03  NMSE=-40.8659 dB
# Epoch 290/300  Loss=5.5939e-01  Valid Loss=5.3252e-02  LR=1.00e-03  NMSE=-40.8753 dB
# Epoch 300/300  Loss=5.5844e-01  Valid Loss=5.3145e-02  LR=1.00e-03  NMSE=-40.8840 dB
#
# Best model from epoch 300 with validation loss: 5.3145e-02
# NMSE: -40.3694 dB
#
# ============================================================
# Pruning Iteration 6/10
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 73.75% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=1.2247e+00  Valid Loss=1.2154e-01  LR=1.00e-03  NMSE=-37.2915 dB
# Epoch  20/300  Loss=8.4799e-01  Valid Loss=8.5124e-02  LR=1.00e-03  NMSE=-38.8381 dB
# Epoch  30/300  Loss=7.4564e-01  Valid Loss=7.5015e-02  LR=1.00e-03  NMSE=-39.3872 dB
# Epoch  40/300  Loss=6.9637e-01  Valid Loss=6.9659e-02  LR=1.00e-03  NMSE=-39.7089 dB
# Epoch  50/300  Loss=6.6526e-01  Valid Loss=6.6026e-02  LR=1.00e-03  NMSE=-39.9415 dB
# Epoch  60/300  Loss=6.4550e-01  Valid Loss=6.4307e-02  LR=1.00e-03  NMSE=-40.0561 dB
# Epoch  70/300  Loss=6.3202e-01  Valid Loss=6.2978e-02  LR=1.00e-03  NMSE=-40.1468 dB
# Epoch  80/300  Loss=6.2193e-01  Valid Loss=6.1890e-02  LR=1.00e-03  NMSE=-40.2225 dB
# Epoch  90/300  Loss=6.1441e-01  Valid Loss=6.0950e-02  LR=1.00e-03  NMSE=-40.2889 dB
# Epoch 100/300  Loss=6.0912e-01  Valid Loss=6.0099e-02  LR=1.00e-03  NMSE=-40.3500 dB
# Epoch 110/300  Loss=6.0533e-01  Valid Loss=5.9333e-02  LR=1.00e-03  NMSE=-40.4057 dB
# Epoch 120/300  Loss=6.0182e-01  Valid Loss=5.8685e-02  LR=1.00e-03  NMSE=-40.4534 dB
# Epoch 130/300  Loss=5.9798e-01  Valid Loss=5.8146e-02  LR=1.00e-03  NMSE=-40.4935 dB
# Epoch 140/300  Loss=5.9426e-01  Valid Loss=5.7702e-02  LR=1.00e-03  NMSE=-40.5267 dB
# Epoch 150/300  Loss=5.9101e-01  Valid Loss=5.7325e-02  LR=1.00e-03  NMSE=-40.5552 dB
# Epoch 160/300  Loss=5.8816e-01  Valid Loss=5.6993e-02  LR=1.00e-03  NMSE=-40.5805 dB
# Epoch 170/300  Loss=5.8569e-01  Valid Loss=5.6715e-02  LR=1.00e-03  NMSE=-40.6017 dB
# Epoch 180/300  Loss=5.8355e-01  Valid Loss=5.6485e-02  LR=1.00e-03  NMSE=-40.6193 dB
# Epoch 190/300  Loss=5.8168e-01  Valid Loss=5.6297e-02  LR=1.00e-03  NMSE=-40.6338 dB
# Epoch 200/300  Loss=5.8006e-01  Valid Loss=5.6134e-02  LR=1.00e-03  NMSE=-40.6464 dB
# Epoch 210/300  Loss=5.7859e-01  Valid Loss=5.5994e-02  LR=1.00e-03  NMSE=-40.6573 dB
# Epoch 220/300  Loss=5.7724e-01  Valid Loss=5.5856e-02  LR=1.00e-03  NMSE=-40.6680 dB
# Epoch 230/300  Loss=5.7600e-01  Valid Loss=5.5721e-02  LR=1.00e-03  NMSE=-40.6785 dB
# Epoch 240/300  Loss=5.7483e-01  Valid Loss=5.5592e-02  LR=1.00e-03  NMSE=-40.6885 dB
# Epoch 250/300  Loss=5.7374e-01  Valid Loss=5.5459e-02  LR=1.00e-03  NMSE=-40.6989 dB
# Epoch 260/300  Loss=5.7264e-01  Valid Loss=5.5342e-02  LR=1.00e-03  NMSE=-40.7081 dB
# Epoch 270/300  Loss=5.7163e-01  Valid Loss=5.5235e-02  LR=1.00e-03  NMSE=-40.7165 dB
# Epoch 280/300  Loss=5.7066e-01  Valid Loss=5.5141e-02  LR=1.00e-03  NMSE=-40.7239 dB
# Epoch 290/300  Loss=5.6977e-01  Valid Loss=5.5061e-02  LR=1.00e-03  NMSE=-40.7302 dB
# Epoch 300/300  Loss=5.6894e-01  Valid Loss=5.4988e-02  LR=1.00e-03  NMSE=-40.7360 dB
#
# Best model from epoch 300 with validation loss: 5.4988e-02
# NMSE: -40.2418 dB
#
# ============================================================
# Pruning Iteration 7/10
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 79.03% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=1.4462e+00  Valid Loss=1.3493e-01  LR=1.00e-03  NMSE=-36.8376 dB
# Epoch  20/300  Loss=9.3193e-01  Valid Loss=9.5210e-02  LR=1.00e-03  NMSE=-38.3518 dB
# Epoch  30/300  Loss=8.2388e-01  Valid Loss=8.4557e-02  LR=1.00e-03  NMSE=-38.8672 dB
# Epoch  40/300  Loss=7.8941e-01  Valid Loss=8.0398e-02  LR=1.00e-03  NMSE=-39.0862 dB
# Epoch  50/300  Loss=7.7610e-01  Valid Loss=7.8270e-02  LR=1.00e-03  NMSE=-39.2027 dB
# Epoch  60/300  Loss=7.6899e-01  Valid Loss=7.6963e-02  LR=1.00e-03  NMSE=-39.2758 dB
# Epoch  70/300  Loss=7.6283e-01  Valid Loss=7.6014e-02  LR=1.00e-03  NMSE=-39.3297 dB
# Epoch  80/300  Loss=7.5672e-01  Valid Loss=7.5200e-02  LR=1.00e-03  NMSE=-39.3765 dB
# Epoch  90/300  Loss=7.5076e-01  Valid Loss=7.4479e-02  LR=1.00e-03  NMSE=-39.4183 dB
# Epoch 100/300  Loss=7.4495e-01  Valid Loss=7.3821e-02  LR=1.00e-03  NMSE=-39.4568 dB
# Epoch 110/300  Loss=7.3917e-01  Valid Loss=7.3204e-02  LR=1.00e-03  NMSE=-39.4933 dB
# Epoch 120/300  Loss=7.3345e-01  Valid Loss=7.2624e-02  LR=1.00e-03  NMSE=-39.5279 dB
# Epoch 130/300  Loss=7.2778e-01  Valid Loss=7.2056e-02  LR=1.00e-03  NMSE=-39.5619 dB
# Epoch 140/300  Loss=7.2224e-01  Valid Loss=7.1509e-02  LR=1.00e-03  NMSE=-39.5951 dB
# Epoch 150/300  Loss=7.1697e-01  Valid Loss=7.0987e-02  LR=1.00e-03  NMSE=-39.6268 dB
# Epoch 160/300  Loss=7.1189e-01  Valid Loss=7.0496e-02  LR=1.00e-03  NMSE=-39.6570 dB
# Epoch 170/300  Loss=7.0701e-01  Valid Loss=7.0024e-02  LR=1.00e-03  NMSE=-39.6862 dB
# Epoch 180/300  Loss=7.0236e-01  Valid Loss=6.9578e-02  LR=1.00e-03  NMSE=-39.7139 dB
# Epoch 190/300  Loss=6.9794e-01  Valid Loss=6.9154e-02  LR=1.00e-03  NMSE=-39.7405 dB
# Epoch 200/300  Loss=6.9378e-01  Valid Loss=6.8756e-02  LR=1.00e-03  NMSE=-39.7655 dB
# Epoch 210/300  Loss=6.8990e-01  Valid Loss=6.8381e-02  LR=1.00e-03  NMSE=-39.7893 dB
# Epoch 220/300  Loss=6.8633e-01  Valid Loss=6.8032e-02  LR=1.00e-03  NMSE=-39.8115 dB
# Epoch 230/300  Loss=6.8301e-01  Valid Loss=6.7714e-02  LR=1.00e-03  NMSE=-39.8319 dB
# Epoch 240/300  Loss=6.7999e-01  Valid Loss=6.7417e-02  LR=1.00e-03  NMSE=-39.8510 dB
# Epoch 250/300  Loss=6.7720e-01  Valid Loss=6.7135e-02  LR=1.00e-03  NMSE=-39.8691 dB
# Epoch 260/300  Loss=6.7464e-01  Valid Loss=6.6878e-02  LR=1.00e-03  NMSE=-39.8858 dB
# Epoch 270/300  Loss=6.7231e-01  Valid Loss=6.6640e-02  LR=1.00e-03  NMSE=-39.9013 dB
# Epoch 280/300  Loss=6.7016e-01  Valid Loss=6.6427e-02  LR=1.00e-03  NMSE=-39.9152 dB
# Epoch 290/300  Loss=6.6824e-01  Valid Loss=6.6225e-02  LR=1.00e-03  NMSE=-39.9284 dB
# Epoch 300/300  Loss=6.6650e-01  Valid Loss=6.6043e-02  LR=1.00e-03  NMSE=-39.9404 dB
#
# Best model from epoch 300 with validation loss: 6.6043e-02
# NMSE: -39.6409 dB
#
# ============================================================
# Pruning Iteration 8/10
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 83.19% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=1.9014e+00  Valid Loss=1.7854e-01  LR=1.00e-03  NMSE=-35.6213 dB
# Epoch  20/300  Loss=1.2050e+00  Valid Loss=1.1771e-01  LR=1.00e-03  NMSE=-37.4305 dB
# Epoch  30/300  Loss=1.0608e+00  Valid Loss=1.0530e-01  LR=1.00e-03  NMSE=-37.9145 dB
# Epoch  40/300  Loss=1.0038e+00  Valid Loss=9.8973e-02  LR=1.00e-03  NMSE=-38.1835 dB
# Epoch  50/300  Loss=9.7165e-01  Valid Loss=9.5318e-02  LR=1.00e-03  NMSE=-38.3469 dB
# Epoch  60/300  Loss=9.5005e-01  Valid Loss=9.2773e-02  LR=1.00e-03  NMSE=-38.4644 dB
# Epoch  70/300  Loss=9.3523e-01  Valid Loss=9.0837e-02  LR=1.00e-03  NMSE=-38.5560 dB
# Epoch  80/300  Loss=9.2350e-01  Valid Loss=8.9284e-02  LR=1.00e-03  NMSE=-38.6309 dB
# Epoch  90/300  Loss=9.1185e-01  Valid Loss=8.7929e-02  LR=1.00e-03  NMSE=-38.6974 dB
# Epoch 100/300  Loss=8.9941e-01  Valid Loss=8.6599e-02  LR=1.00e-03  NMSE=-38.7635 dB
# Epoch 110/300  Loss=8.8621e-01  Valid Loss=8.5261e-02  LR=1.00e-03  NMSE=-38.8312 dB
# Epoch 120/300  Loss=8.7305e-01  Valid Loss=8.3987e-02  LR=1.00e-03  NMSE=-38.8965 dB
# Epoch 130/300  Loss=8.6124e-01  Valid Loss=8.2901e-02  LR=1.00e-03  NMSE=-38.9531 dB
# Epoch 140/300  Loss=8.5146e-01  Valid Loss=8.2043e-02  LR=1.00e-03  NMSE=-38.9982 dB
# Epoch 150/300  Loss=8.4344e-01  Valid Loss=8.1364e-02  LR=1.00e-03  NMSE=-39.0343 dB
# Epoch 160/300  Loss=8.3671e-01  Valid Loss=8.0807e-02  LR=1.00e-03  NMSE=-39.0642 dB
# Epoch 170/300  Loss=8.3075e-01  Valid Loss=8.0313e-02  LR=1.00e-03  NMSE=-39.0908 dB
# Epoch 180/300  Loss=8.2533e-01  Valid Loss=7.9849e-02  LR=1.00e-03  NMSE=-39.1159 dB
# Epoch 190/300  Loss=8.2029e-01  Valid Loss=7.9417e-02  LR=1.00e-03  NMSE=-39.1395 dB
# Epoch 200/300  Loss=8.1558e-01  Valid Loss=7.9013e-02  LR=1.00e-03  NMSE=-39.1617 dB
# Epoch 210/300  Loss=8.1121e-01  Valid Loss=7.8629e-02  LR=1.00e-03  NMSE=-39.1828 dB
# Epoch 220/300  Loss=8.0713e-01  Valid Loss=7.8276e-02  LR=1.00e-03  NMSE=-39.2024 dB
# Epoch 230/300  Loss=8.0333e-01  Valid Loss=7.7947e-02  LR=1.00e-03  NMSE=-39.2207 dB
# Epoch 240/300  Loss=7.9981e-01  Valid Loss=7.7632e-02  LR=1.00e-03  NMSE=-39.2383 dB
# Epoch 250/300  Loss=7.9652e-01  Valid Loss=7.7335e-02  LR=1.00e-03  NMSE=-39.2549 dB
# Epoch 260/300  Loss=7.9343e-01  Valid Loss=7.7066e-02  LR=1.00e-03  NMSE=-39.2701 dB
# Epoch 270/300  Loss=7.9056e-01  Valid Loss=7.6809e-02  LR=1.00e-03  NMSE=-39.2846 dB
# Epoch 280/300  Loss=7.8788e-01  Valid Loss=7.6576e-02  LR=1.00e-03  NMSE=-39.2978 dB
# Epoch 290/300  Loss=7.8537e-01  Valid Loss=7.6351e-02  LR=1.00e-03  NMSE=-39.3105 dB
# Epoch 300/300  Loss=7.8302e-01  Valid Loss=7.6146e-02  LR=1.00e-03  NMSE=-39.3222 dB
#
# Best model from epoch 300 with validation loss: 7.6146e-02
# NMSE: -38.9123 dB
#
# ============================================================
# Pruning Iteration 9/10
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 86.53% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=1.2675e+00  Valid Loss=1.2510e-01  LR=1.00e-03  NMSE=-37.1662 dB
# Epoch  20/300  Loss=1.1713e+00  Valid Loss=1.1426e-01  LR=1.00e-03  NMSE=-37.5597 dB
# Epoch  30/300  Loss=1.1370e+00  Valid Loss=1.1032e-01  LR=1.00e-03  NMSE=-37.7121 dB
# Epoch  40/300  Loss=1.1184e+00  Valid Loss=1.0836e-01  LR=1.00e-03  NMSE=-37.7898 dB
# Epoch  50/300  Loss=1.1046e+00  Valid Loss=1.0694e-01  LR=1.00e-03  NMSE=-37.8473 dB
# Epoch  60/300  Loss=1.0925e+00  Valid Loss=1.0572e-01  LR=1.00e-03  NMSE=-37.8973 dB
# Epoch  70/300  Loss=1.0812e+00  Valid Loss=1.0460e-01  LR=1.00e-03  NMSE=-37.9432 dB
# Epoch  80/300  Loss=1.0705e+00  Valid Loss=1.0356e-01  LR=1.00e-03  NMSE=-37.9867 dB
# Epoch  90/300  Loss=1.0604e+00  Valid Loss=1.0259e-01  LR=1.00e-03  NMSE=-38.0277 dB
# Epoch 100/300  Loss=1.0509e+00  Valid Loss=1.0169e-01  LR=1.00e-03  NMSE=-38.0660 dB
# Epoch 110/300  Loss=1.0419e+00  Valid Loss=1.0086e-01  LR=1.00e-03  NMSE=-38.1015 dB
# Epoch 120/300  Loss=1.0334e+00  Valid Loss=1.0007e-01  LR=1.00e-03  NMSE=-38.1358 dB
# Epoch 130/300  Loss=1.0254e+00  Valid Loss=9.9338e-02  LR=1.00e-03  NMSE=-38.1675 dB
# Epoch 140/300  Loss=1.0178e+00  Valid Loss=9.8646e-02  LR=1.00e-03  NMSE=-38.1979 dB
# Epoch 150/300  Loss=1.0107e+00  Valid Loss=9.7993e-02  LR=1.00e-03  NMSE=-38.2267 dB
# Epoch 160/300  Loss=1.0040e+00  Valid Loss=9.7374e-02  LR=1.00e-03  NMSE=-38.2542 dB
# Epoch 170/300  Loss=9.9772e-01  Valid Loss=9.6799e-02  LR=1.00e-03  NMSE=-38.2799 dB
# Epoch 180/300  Loss=9.9185e-01  Valid Loss=9.6260e-02  LR=1.00e-03  NMSE=-38.3042 dB
# Epoch 190/300  Loss=9.8639e-01  Valid Loss=9.5773e-02  LR=1.00e-03  NMSE=-38.3262 dB
# Epoch 200/300  Loss=9.8131e-01  Valid Loss=9.5326e-02  LR=1.00e-03  NMSE=-38.3466 dB
# Epoch 210/300  Loss=9.7661e-01  Valid Loss=9.4932e-02  LR=1.00e-03  NMSE=-38.3645 dB
# Epoch 220/300  Loss=9.7222e-01  Valid Loss=9.4580e-02  LR=1.00e-03  NMSE=-38.3807 dB
# Epoch 230/300  Loss=9.6814e-01  Valid Loss=9.4275e-02  LR=1.00e-03  NMSE=-38.3947 dB
# Epoch 240/300  Loss=9.6427e-01  Valid Loss=9.3996e-02  LR=1.00e-03  NMSE=-38.4076 dB
# Epoch 250/300  Loss=9.6060e-01  Valid Loss=9.3735e-02  LR=1.00e-03  NMSE=-38.4196 dB
# Epoch 260/300  Loss=9.5712e-01  Valid Loss=9.3473e-02  LR=1.00e-03  NMSE=-38.4318 dB
# Epoch 270/300  Loss=9.5386e-01  Valid Loss=9.3210e-02  LR=1.00e-03  NMSE=-38.4441 dB
# Epoch 280/300  Loss=9.5078e-01  Valid Loss=9.2935e-02  LR=1.00e-03  NMSE=-38.4569 dB
# Epoch 290/300  Loss=9.4791e-01  Valid Loss=9.2664e-02  LR=1.00e-03  NMSE=-38.4696 dB
# Epoch 300/300  Loss=9.4526e-01  Valid Loss=9.2409e-02  LR=1.00e-03  NMSE=-38.4815 dB
#
# Best model from epoch 300 with validation loss: 9.2409e-02
# NMSE: -38.1514 dB
#
# ============================================================
# Pruning Iteration 10/10
# ============================================================
# Pruning 20.0% of remaining weights...
# Current pruning: 89.17% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=3.2035e+00  Valid Loss=3.0109e-01  LR=1.00e-03  NMSE=-33.3517 dB
# Epoch  20/300  Loss=1.5536e+00  Valid Loss=1.4955e-01  LR=1.00e-03  NMSE=-36.3909 dB
# Epoch  30/300  Loss=1.2239e+00  Valid Loss=1.1859e-01  LR=1.00e-03  NMSE=-37.3981 dB
# Epoch  40/300  Loss=1.1678e+00  Valid Loss=1.1270e-01  LR=1.00e-03  NMSE=-37.6194 dB
# Epoch  50/300  Loss=1.1540e+00  Valid Loss=1.1067e-01  LR=1.00e-03  NMSE=-37.6983 dB
# Epoch  60/300  Loss=1.1500e+00  Valid Loss=1.0975e-01  LR=1.00e-03  NMSE=-37.7346 dB
# Epoch  70/300  Loss=1.1480e+00  Valid Loss=1.1014e-01  LR=1.00e-03  NMSE=-37.7192 dB
# Epoch  80/300  Loss=1.1138e+00  Valid Loss=1.0807e-01  LR=5.00e-04  NMSE=-37.8017 dB
# Epoch  90/300  Loss=1.1116e+00  Valid Loss=1.0772e-01  LR=5.00e-04  NMSE=-37.8157 dB
# Epoch 100/300  Loss=1.1098e+00  Valid Loss=1.0739e-01  LR=5.00e-04  NMSE=-37.8291 dB
# Epoch 110/300  Loss=1.1084e+00  Valid Loss=1.0707e-01  LR=5.00e-04  NMSE=-37.8421 dB
# Epoch 120/300  Loss=1.1074e+00  Valid Loss=1.0675e-01  LR=5.00e-04  NMSE=-37.8550 dB
# Epoch 130/300  Loss=1.1067e+00  Valid Loss=1.0644e-01  LR=5.00e-04  NMSE=-37.8677 dB
# Epoch 140/300  Loss=1.1064e+00  Valid Loss=1.0614e-01  LR=5.00e-04  NMSE=-37.8799 dB
# Epoch 150/300  Loss=1.1061e+00  Valid Loss=1.0586e-01  LR=5.00e-04  NMSE=-37.8913 dB
# Epoch 160/300  Loss=1.1058e+00  Valid Loss=1.0561e-01  LR=5.00e-04  NMSE=-37.9015 dB
# Epoch 170/300  Loss=1.1053e+00  Valid Loss=1.0539e-01  LR=5.00e-04  NMSE=-37.9106 dB
# Epoch 180/300  Loss=1.1046e+00  Valid Loss=1.0519e-01  LR=5.00e-04  NMSE=-37.9189 dB
# Epoch 190/300  Loss=1.1037e+00  Valid Loss=1.0501e-01  LR=5.00e-04  NMSE=-37.9263 dB
# Epoch 200/300  Loss=1.1026e+00  Valid Loss=1.0485e-01  LR=5.00e-04  NMSE=-37.9331 dB
# Epoch 210/300  Loss=1.1015e+00  Valid Loss=1.0468e-01  LR=5.00e-04  NMSE=-37.9399 dB
# Epoch 220/300  Loss=1.1004e+00  Valid Loss=1.0452e-01  LR=5.00e-04  NMSE=-37.9468 dB
# Epoch 230/300  Loss=1.0991e+00  Valid Loss=1.0434e-01  LR=5.00e-04  NMSE=-37.9541 dB
# Epoch 240/300  Loss=1.0978e+00  Valid Loss=1.0416e-01  LR=5.00e-04  NMSE=-37.9616 dB
# Epoch 250/300  Loss=1.0965e+00  Valid Loss=1.0398e-01  LR=5.00e-04  NMSE=-37.9692 dB
# Epoch 260/300  Loss=1.0951e+00  Valid Loss=1.0381e-01  LR=5.00e-04  NMSE=-37.9765 dB
# Epoch 270/300  Loss=1.0938e+00  Valid Loss=1.0364e-01  LR=5.00e-04  NMSE=-37.9834 dB
# Epoch 280/300  Loss=1.0924e+00  Valid Loss=1.0348e-01  LR=5.00e-04  NMSE=-37.9899 dB
# Epoch 290/300  Loss=1.0912e+00  Valid Loss=1.0334e-01  LR=5.00e-04  NMSE=-37.9962 dB
# Epoch 300/300  Loss=1.0899e+00  Valid Loss=1.0320e-01  LR=5.00e-04  NMSE=-38.0020 dB
#
# Best model from epoch 300 with validation loss: 1.0320e-01
# NMSE: -37.6290 dB

# %%
# Use adaptive pruning
pntdnn_ideal_predistorted = PNTDNN_NeuralNetwork(num_memory_levels=15, model_type="OneLayerNetwork", forward_model=True, nn_file_path="pntdnn_ideal_predistorted_forward_model.pt")

adaptive_pruning_experiment_PNTDNN = AdaptivePruningExperiment(
    nn_model=pntdnn_ideal_predistorted,
    retrain_epochs= 300,
    training_dataset = ideal_predistored_dataset.training_dataset,
    valid_dataset = ideal_predistored_dataset.validation_dataset,
    test_dataset = ideal_predistored_dataset.test_dataset,
    nmse_threshold = -38,
    initial_prune_fraction=0.5,
    min_prune_fraction=0.01,
    max_prune_fraction=0.5
)

adaptive_pruning_experiment_PNTDNN.run()

# Save the best model
adaptive_pruning_experiment_PNTDNN.best_model.write_nn_to_file(file_path="pntdnn_ideal_predistorted_forward_model_adaptive_pruned.pt")
# Out:
# Using cuda device
# Baseline NMSE          : -40.1854 dB
# Tolerance              : +2.19 dB
# NMSE must stay below   : -38.0000 dB
# Initial prune fraction : 50.0%
# Min prune fraction     : 1.0%
# Max prune fraction     : 50.0%
#
# ============================================================
# Step 1  |  fraction = 50.00%
# ============================================================
# Pruning 50.00% of remaining weights...
# Current sparsity: 50.00% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=1.4919e+00  Valid Loss=1.4495e-01  LR=1.00e-03  NMSE=-36.5266 dB
# Epoch  20/300  Loss=1.0620e+00  Valid Loss=1.0241e-01  LR=1.00e-03  NMSE=-38.0354 dB
# Epoch  30/300  Loss=9.2991e-01  Valid Loss=9.0833e-02  LR=1.00e-03  NMSE=-38.5562 dB
# Epoch  40/300  Loss=8.6206e-01  Valid Loss=8.5552e-02  LR=1.00e-03  NMSE=-38.8163 dB
# Epoch  50/300  Loss=8.0110e-01  Valid Loss=8.3527e-02  LR=1.00e-03  NMSE=-38.9204 dB
# Epoch  60/300  Loss=7.5387e-01  Valid Loss=7.9994e-02  LR=1.00e-03  NMSE=-39.1081 dB
# Epoch  70/300  Loss=7.2087e-01  Valid Loss=7.5748e-02  LR=1.00e-03  NMSE=-39.3449 dB
# Epoch  80/300  Loss=7.0010e-01  Valid Loss=7.2356e-02  LR=1.00e-03  NMSE=-39.5439 dB
# Epoch  90/300  Loss=6.8846e-01  Valid Loss=6.9756e-02  LR=1.00e-03  NMSE=-39.7028 dB
# Epoch 100/300  Loss=6.8210e-01  Valid Loss=6.7813e-02  LR=1.00e-03  NMSE=-39.8255 dB
# Epoch 110/300  Loss=6.7502e-01  Valid Loss=6.6352e-02  LR=1.00e-03  NMSE=-39.9201 dB
# Epoch 120/300  Loss=6.6676e-01  Valid Loss=6.5169e-02  LR=1.00e-03  NMSE=-39.9982 dB
# Epoch 130/300  Loss=6.5891e-01  Valid Loss=6.4151e-02  LR=1.00e-03  NMSE=-40.0667 dB
# Epoch 140/300  Loss=6.5216e-01  Valid Loss=6.3260e-02  LR=1.00e-03  NMSE=-40.1274 dB
# Epoch 150/300  Loss=6.4634e-01  Valid Loss=6.2464e-02  LR=1.00e-03  NMSE=-40.1824 dB
# Epoch 160/300  Loss=6.4131e-01  Valid Loss=6.1785e-02  LR=1.00e-03  NMSE=-40.2298 dB
# Epoch 170/300  Loss=6.3787e-01  Valid Loss=6.1152e-02  LR=1.00e-03  NMSE=-40.2746 dB
# Epoch 180/300  Loss=6.3328e-01  Valid Loss=6.0571e-02  LR=1.00e-03  NMSE=-40.3160 dB
# Epoch 190/300  Loss=6.2949e-01  Valid Loss=6.0060e-02  LR=1.00e-03  NMSE=-40.3528 dB
# Epoch 200/300  Loss=6.2648e-01  Valid Loss=5.9616e-02  LR=1.00e-03  NMSE=-40.3851 dB
# Epoch 210/300  Loss=6.2404e-01  Valid Loss=5.9217e-02  LR=1.00e-03  NMSE=-40.4142 dB
# Epoch 220/300  Loss=6.2188e-01  Valid Loss=5.8855e-02  LR=1.00e-03  NMSE=-40.4408 dB
# Epoch 230/300  Loss=6.1964e-01  Valid Loss=5.8542e-02  LR=1.00e-03  NMSE=-40.4640 dB
# Epoch 240/300  Loss=6.1760e-01  Valid Loss=5.8297e-02  LR=1.00e-03  NMSE=-40.4822 dB
# Epoch 250/300  Loss=6.1532e-01  Valid Loss=5.8080e-02  LR=1.00e-03  NMSE=-40.4984 dB
# Epoch 260/300  Loss=6.1087e-01  Valid Loss=5.7553e-02  LR=1.00e-03  NMSE=-40.5380 dB
# Epoch 270/300  Loss=6.0335e-01  Valid Loss=5.6879e-02  LR=1.00e-03  NMSE=-40.5891 dB
# Epoch 280/300  Loss=5.9859e-01  Valid Loss=5.6122e-02  LR=1.00e-03  NMSE=-40.6474 dB
# Epoch 290/300  Loss=5.9449e-01  Valid Loss=5.5637e-02  LR=1.00e-03  NMSE=-40.6850 dB
# Epoch 300/300  Loss=5.9050e-01  Valid Loss=5.5214e-02  LR=1.00e-03  NMSE=-40.7182 dB
#
# Best model from epoch 300 with validation loss: 5.5214e-02
# NMSE: -40.2525 dB  (threshold: -38.0000 dB)
#   ACCEPTED  (delta: -0.0672 dB)
#   Plenty of headroom -> increasing next fraction to 50.00%
#
# ============================================================
# Step 2  |  fraction = 50.00%
# ============================================================
# Pruning 50.00% of remaining weights...
# Current sparsity: 75.00% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=3.0313e+00  Valid Loss=2.7669e-01  LR=1.00e-03  NMSE=-33.7188 dB
# Epoch  20/300  Loss=1.4079e+00  Valid Loss=1.3591e-01  LR=1.00e-03  NMSE=-36.8063 dB
# Epoch  30/300  Loss=1.2314e+00  Valid Loss=1.2616e-01  LR=1.00e-03  NMSE=-37.1296 dB
# Epoch  40/300  Loss=1.1314e+00  Valid Loss=1.1854e-01  LR=1.00e-03  NMSE=-37.4000 dB
# Epoch  50/300  Loss=1.0670e+00  Valid Loss=1.1119e-01  LR=1.00e-03  NMSE=-37.6781 dB
# Epoch  60/300  Loss=1.0220e+00  Valid Loss=1.0545e-01  LR=1.00e-03  NMSE=-37.9083 dB
# Epoch  70/300  Loss=9.8605e-01  Valid Loss=1.0091e-01  LR=1.00e-03  NMSE=-38.0991 dB
# Epoch  80/300  Loss=9.5469e-01  Valid Loss=9.7222e-02  LR=1.00e-03  NMSE=-38.2610 dB
# Epoch  90/300  Loss=9.2688e-01  Valid Loss=9.4064e-02  LR=1.00e-03  NMSE=-38.4044 dB
# Epoch 100/300  Loss=9.0263e-01  Valid Loss=9.1313e-02  LR=1.00e-03  NMSE=-38.5333 dB
# Epoch 110/300  Loss=8.8138e-01  Valid Loss=8.8918e-02  LR=1.00e-03  NMSE=-38.6488 dB
# Epoch 120/300  Loss=8.6271e-01  Valid Loss=8.6776e-02  LR=1.00e-03  NMSE=-38.7547 dB
# Epoch 130/300  Loss=8.4654e-01  Valid Loss=8.4894e-02  LR=1.00e-03  NMSE=-38.8499 dB
# Epoch 140/300  Loss=8.3250e-01  Valid Loss=8.3305e-02  LR=1.00e-03  NMSE=-38.9320 dB
# Epoch 150/300  Loss=8.2036e-01  Valid Loss=8.1976e-02  LR=1.00e-03  NMSE=-39.0018 dB
# Epoch 160/300  Loss=8.1026e-01  Valid Loss=8.0932e-02  LR=1.00e-03  NMSE=-39.0574 dB
# Epoch 170/300  Loss=8.0157e-01  Valid Loss=8.0108e-02  LR=1.00e-03  NMSE=-39.1019 dB
# Epoch 180/300  Loss=7.9429e-01  Valid Loss=7.9387e-02  LR=1.00e-03  NMSE=-39.1412 dB
# Epoch 190/300  Loss=7.8821e-01  Valid Loss=7.8707e-02  LR=1.00e-03  NMSE=-39.1785 dB
# Epoch 200/300  Loss=7.8303e-01  Valid Loss=7.8069e-02  LR=1.00e-03  NMSE=-39.2139 dB
# Epoch 210/300  Loss=7.7860e-01  Valid Loss=7.7517e-02  LR=1.00e-03  NMSE=-39.2447 dB
# Epoch 220/300  Loss=7.7482e-01  Valid Loss=7.7044e-02  LR=1.00e-03  NMSE=-39.2713 dB
# Epoch 230/300  Loss=7.7158e-01  Valid Loss=7.6654e-02  LR=1.00e-03  NMSE=-39.2933 dB
# Epoch 240/300  Loss=7.6871e-01  Valid Loss=7.6316e-02  LR=1.00e-03  NMSE=-39.3125 dB
# Epoch 250/300  Loss=7.6624e-01  Valid Loss=7.6024e-02  LR=1.00e-03  NMSE=-39.3291 dB
# Epoch 260/300  Loss=7.6395e-01  Valid Loss=7.5767e-02  LR=1.00e-03  NMSE=-39.3439 dB
# Epoch 270/300  Loss=7.6189e-01  Valid Loss=7.5534e-02  LR=1.00e-03  NMSE=-39.3572 dB
# Epoch 280/300  Loss=7.6012e-01  Valid Loss=7.5324e-02  LR=1.00e-03  NMSE=-39.3694 dB
# Epoch 290/300  Loss=7.5854e-01  Valid Loss=7.5135e-02  LR=1.00e-03  NMSE=-39.3802 dB
# Epoch 300/300  Loss=7.5704e-01  Valid Loss=7.4964e-02  LR=1.00e-03  NMSE=-39.3901 dB
#
# Best model from epoch 300 with validation loss: 7.4964e-02
# NMSE: -39.1541 dB  (threshold: -38.0000 dB)
#   ACCEPTED  (delta: +1.0313 dB)
#   Moderate headroom -> keeping next fraction at 50.00%
#
# ============================================================
# Step 3  |  fraction = 50.00%
# ============================================================
# Pruning 50.00% of remaining weights...
# Current sparsity: 87.50% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=8.8505e+00  Valid Loss=8.2569e-01  LR=1.00e-03  NMSE=-28.9705 dB
# Epoch  20/300  Loss=3.4464e+00  Valid Loss=3.3651e-01  LR=1.00e-03  NMSE=-32.8687 dB
# Epoch  30/300  Loss=2.2911e+00  Valid Loss=2.2751e-01  LR=1.00e-03  NMSE=-34.5686 dB
# Epoch  40/300  Loss=1.8809e+00  Valid Loss=1.8828e-01  LR=1.00e-03  NMSE=-35.3906 dB
# Epoch  50/300  Loss=1.6974e+00  Valid Loss=1.7059e-01  LR=1.00e-03  NMSE=-35.8191 dB
# Epoch  60/300  Loss=1.6063e+00  Valid Loss=1.6152e-01  LR=1.00e-03  NMSE=-36.0565 dB
# Epoch  70/300  Loss=1.5570e+00  Valid Loss=1.5634e-01  LR=1.00e-03  NMSE=-36.1980 dB
# Epoch  80/300  Loss=1.5282e+00  Valid Loss=1.5305e-01  LR=1.00e-03  NMSE=-36.2904 dB
# Epoch  90/300  Loss=1.5102e+00  Valid Loss=1.5080e-01  LR=1.00e-03  NMSE=-36.3545 dB
# Epoch 100/300  Loss=1.4984e+00  Valid Loss=1.4925e-01  LR=1.00e-03  NMSE=-36.3995 dB
# Epoch 110/300  Loss=1.4904e+00  Valid Loss=1.4811e-01  LR=1.00e-03  NMSE=-36.4329 dB
# Epoch 120/300  Loss=1.4851e+00  Valid Loss=1.4723e-01  LR=1.00e-03  NMSE=-36.4586 dB
# Epoch 130/300  Loss=1.4816e+00  Valid Loss=1.4655e-01  LR=1.00e-03  NMSE=-36.4788 dB
# Epoch 140/300  Loss=1.4792e+00  Valid Loss=1.4601e-01  LR=1.00e-03  NMSE=-36.4949 dB
# Epoch 150/300  Loss=1.4777e+00  Valid Loss=1.4554e-01  LR=1.00e-03  NMSE=-36.5088 dB
# Epoch 160/300  Loss=1.4764e+00  Valid Loss=1.4512e-01  LR=1.00e-03  NMSE=-36.5213 dB
# Epoch 170/300  Loss=1.4753e+00  Valid Loss=1.4476e-01  LR=1.00e-03  NMSE=-36.5323 dB
# Epoch 180/300  Loss=1.4745e+00  Valid Loss=1.4443e-01  LR=1.00e-03  NMSE=-36.5422 dB
# Epoch 190/300  Loss=1.4735e+00  Valid Loss=1.4412e-01  LR=1.00e-03  NMSE=-36.5515 dB
# Epoch 200/300  Loss=1.4725e+00  Valid Loss=1.4383e-01  LR=1.00e-03  NMSE=-36.5601 dB
# Epoch 210/300  Loss=1.4713e+00  Valid Loss=1.4357e-01  LR=1.00e-03  NMSE=-36.5682 dB
# Epoch 220/300  Loss=1.4702e+00  Valid Loss=1.4332e-01  LR=1.00e-03  NMSE=-36.5757 dB
# Epoch 230/300  Loss=1.4689e+00  Valid Loss=1.4309e-01  LR=1.00e-03  NMSE=-36.5826 dB
# Epoch 240/300  Loss=1.4677e+00  Valid Loss=1.4287e-01  LR=1.00e-03  NMSE=-36.5891 dB
# Epoch 250/300  Loss=1.4665e+00  Valid Loss=1.4268e-01  LR=1.00e-03  NMSE=-36.5951 dB
# Epoch 260/300  Loss=1.4652e+00  Valid Loss=1.4249e-01  LR=1.00e-03  NMSE=-36.6008 dB
# Epoch 270/300  Loss=1.4639e+00  Valid Loss=1.4231e-01  LR=1.00e-03  NMSE=-36.6062 dB
# Epoch 280/300  Loss=1.4627e+00  Valid Loss=1.4215e-01  LR=1.00e-03  NMSE=-36.6111 dB
# Epoch 290/300  Loss=1.4615e+00  Valid Loss=1.4199e-01  LR=1.00e-03  NMSE=-36.6159 dB
# Epoch 300/300  Loss=1.4603e+00  Valid Loss=1.4184e-01  LR=1.00e-03  NMSE=-36.6206 dB
#
# Best model from epoch 300 with validation loss: 1.4184e-01
# NMSE: -36.3611 dB  (threshold: -38.0000 dB)
#   REJECTED  (delta: +3.8242 dB) — restoring model
#   Reduced fraction to 25.00%
#
# ============================================================
# Step 4  |  fraction = 25.00%
# ============================================================
# Pruning 25.00% of remaining weights...
# Current sparsity: 81.25% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=3.5939e+00  Valid Loss=3.5212e-01  LR=1.00e-03  NMSE=-32.6717 dB
# Epoch  20/300  Loss=2.3276e+00  Valid Loss=2.3941e-01  LR=1.00e-03  NMSE=-34.3473 dB
# Epoch  30/300  Loss=1.8479e+00  Valid Loss=1.9461e-01  LR=1.00e-03  NMSE=-35.2470 dB
# Epoch  40/300  Loss=1.5845e+00  Valid Loss=1.6870e-01  LR=1.00e-03  NMSE=-35.8674 dB
# Epoch  50/300  Loss=1.4113e+00  Valid Loss=1.5072e-01  LR=1.00e-03  NMSE=-36.3570 dB
# Epoch  60/300  Loss=1.2986e+00  Valid Loss=1.3848e-01  LR=1.00e-03  NMSE=-36.7247 dB
# Epoch  70/300  Loss=1.2312e+00  Valid Loss=1.3017e-01  LR=1.00e-03  NMSE=-36.9936 dB
# Epoch  80/300  Loss=1.1867e+00  Valid Loss=1.2468e-01  LR=1.00e-03  NMSE=-37.1808 dB
# Epoch  90/300  Loss=1.1502e+00  Valid Loss=1.2077e-01  LR=1.00e-03  NMSE=-37.3191 dB
# Epoch 100/300  Loss=1.1239e+00  Valid Loss=1.1770e-01  LR=1.00e-03  NMSE=-37.4308 dB
# Epoch 110/300  Loss=1.1039e+00  Valid Loss=1.1531e-01  LR=1.00e-03  NMSE=-37.5200 dB
# Epoch 120/300  Loss=1.0885e+00  Valid Loss=1.1338e-01  LR=1.00e-03  NMSE=-37.5932 dB
# Epoch 130/300  Loss=1.0763e+00  Valid Loss=1.1180e-01  LR=1.00e-03  NMSE=-37.6543 dB
# Epoch 140/300  Loss=1.0668e+00  Valid Loss=1.1048e-01  LR=1.00e-03  NMSE=-37.7060 dB
# Epoch 150/300  Loss=1.0594e+00  Valid Loss=1.0935e-01  LR=1.00e-03  NMSE=-37.7507 dB
# Epoch 160/300  Loss=1.0535e+00  Valid Loss=1.0837e-01  LR=1.00e-03  NMSE=-37.7896 dB
# Epoch 170/300  Loss=1.0485e+00  Valid Loss=1.0752e-01  LR=1.00e-03  NMSE=-37.8239 dB
# Epoch 180/300  Loss=1.0438e+00  Valid Loss=1.0678e-01  LR=1.00e-03  NMSE=-37.8539 dB
# Epoch 190/300  Loss=1.0393e+00  Valid Loss=1.0613e-01  LR=1.00e-03  NMSE=-37.8805 dB
# Epoch 200/300  Loss=1.0350e+00  Valid Loss=1.0555e-01  LR=1.00e-03  NMSE=-37.9040 dB
# Epoch 210/300  Loss=1.0310e+00  Valid Loss=1.0502e-01  LR=1.00e-03  NMSE=-37.9258 dB
# Epoch 220/300  Loss=1.0273e+00  Valid Loss=1.0458e-01  LR=1.00e-03  NMSE=-37.9443 dB
# Epoch 230/300  Loss=1.0238e+00  Valid Loss=1.0418e-01  LR=1.00e-03  NMSE=-37.9610 dB
# Epoch 240/300  Loss=1.0206e+00  Valid Loss=1.0383e-01  LR=1.00e-03  NMSE=-37.9754 dB
# Epoch 250/300  Loss=1.0176e+00  Valid Loss=1.0353e-01  LR=1.00e-03  NMSE=-37.9882 dB
# Epoch 260/300  Loss=1.0149e+00  Valid Loss=1.0325e-01  LR=1.00e-03  NMSE=-37.9999 dB
# Epoch 270/300  Loss=1.0121e+00  Valid Loss=1.0297e-01  LR=1.00e-03  NMSE=-38.0116 dB
# Epoch 280/300  Loss=1.0096e+00  Valid Loss=1.0273e-01  LR=1.00e-03  NMSE=-38.0217 dB
# Epoch 290/300  Loss=1.0074e+00  Valid Loss=1.0253e-01  LR=1.00e-03  NMSE=-38.0302 dB
# Epoch 300/300  Loss=1.0053e+00  Valid Loss=1.0234e-01  LR=1.00e-03  NMSE=-38.0384 dB
#
# Best model from epoch 300 with validation loss: 1.0234e-01
# NMSE: -37.9499 dB  (threshold: -38.0000 dB)
#   REJECTED  (delta: +2.2355 dB) — restoring model
#   Reduced fraction to 12.50%
#
# ============================================================
# Step 5  |  fraction = 12.50%
# ============================================================
# Pruning 12.50% of remaining weights...
# Current sparsity: 78.06% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=7.9080e-01  Valid Loss=8.0187e-02  LR=1.00e-03  NMSE=-39.0976 dB
# Epoch  20/300  Loss=7.7281e-01  Valid Loss=7.7790e-02  LR=1.00e-03  NMSE=-39.2294 dB
# Epoch  30/300  Loss=7.6820e-01  Valid Loss=7.7109e-02  LR=1.00e-03  NMSE=-39.2676 dB
# Epoch  40/300  Loss=7.7197e-01  Valid Loss=7.6711e-02  LR=1.00e-03  NMSE=-39.2901 dB
# Epoch  50/300  Loss=7.7267e-01  Valid Loss=7.6514e-02  LR=1.00e-03  NMSE=-39.3013 dB
# Epoch  60/300  Loss=7.7116e-01  Valid Loss=7.6368e-02  LR=1.00e-03  NMSE=-39.3095 dB
# Epoch  70/300  Loss=7.6980e-01  Valid Loss=7.6234e-02  LR=1.00e-03  NMSE=-39.3172 dB
# Epoch  80/300  Loss=7.6865e-01  Valid Loss=7.6121e-02  LR=1.00e-03  NMSE=-39.3236 dB
# Epoch  90/300  Loss=7.6762e-01  Valid Loss=7.6021e-02  LR=1.00e-03  NMSE=-39.3293 dB
# Epoch 100/300  Loss=7.6680e-01  Valid Loss=7.5934e-02  LR=1.00e-03  NMSE=-39.3343 dB
# Epoch 110/300  Loss=7.6599e-01  Valid Loss=7.5847e-02  LR=1.00e-03  NMSE=-39.3392 dB
# Epoch 120/300  Loss=7.6523e-01  Valid Loss=7.5771e-02  LR=1.00e-03  NMSE=-39.3436 dB
# Epoch 130/300  Loss=7.6454e-01  Valid Loss=7.5693e-02  LR=1.00e-03  NMSE=-39.3481 dB
# Epoch 140/300  Loss=7.6385e-01  Valid Loss=7.5622e-02  LR=1.00e-03  NMSE=-39.3522 dB
# Epoch 150/300  Loss=7.6323e-01  Valid Loss=7.5560e-02  LR=1.00e-03  NMSE=-39.3557 dB
# Epoch 160/300  Loss=7.6264e-01  Valid Loss=7.5500e-02  LR=1.00e-03  NMSE=-39.3592 dB
# Epoch 170/300  Loss=7.6207e-01  Valid Loss=7.5445e-02  LR=1.00e-03  NMSE=-39.3623 dB
# Epoch 180/300  Loss=7.6152e-01  Valid Loss=7.5390e-02  LR=1.00e-03  NMSE=-39.3655 dB
# Epoch 190/300  Loss=7.6100e-01  Valid Loss=7.5338e-02  LR=1.00e-03  NMSE=-39.3685 dB
# Epoch 200/300  Loss=7.6047e-01  Valid Loss=7.5286e-02  LR=1.00e-03  NMSE=-39.3715 dB
# Epoch 210/300  Loss=7.5997e-01  Valid Loss=7.5238e-02  LR=1.00e-03  NMSE=-39.3743 dB
# Epoch 220/300  Loss=7.5951e-01  Valid Loss=7.5191e-02  LR=1.00e-03  NMSE=-39.3770 dB
# Epoch 230/300  Loss=7.5904e-01  Valid Loss=7.5147e-02  LR=1.00e-03  NMSE=-39.3795 dB
# Epoch 240/300  Loss=7.5858e-01  Valid Loss=7.5100e-02  LR=1.00e-03  NMSE=-39.3823 dB
# Epoch 250/300  Loss=7.5817e-01  Valid Loss=7.5053e-02  LR=1.00e-03  NMSE=-39.3850 dB
# Epoch 260/300  Loss=7.5773e-01  Valid Loss=7.5012e-02  LR=1.00e-03  NMSE=-39.3874 dB
# Epoch 270/300  Loss=7.5731e-01  Valid Loss=7.4970e-02  LR=1.00e-03  NMSE=-39.3898 dB
# Epoch 280/300  Loss=7.5693e-01  Valid Loss=7.4927e-02  LR=1.00e-03  NMSE=-39.3923 dB
# Epoch 290/300  Loss=7.5653e-01  Valid Loss=7.4887e-02  LR=1.00e-03  NMSE=-39.3946 dB
# Epoch 300/300  Loss=7.5615e-01  Valid Loss=7.4847e-02  LR=1.00e-03  NMSE=-39.3969 dB
#
# Best model from epoch 300 with validation loss: 7.4847e-02
# NMSE: -39.1475 dB  (threshold: -38.0000 dB)
#   ACCEPTED  (delta: +1.0378 dB)
#   Moderate headroom -> keeping next fraction at 12.50%
#
# ============================================================
# Step 6  |  fraction = 12.50%
# ============================================================
# Pruning 12.50% of remaining weights...
# Current sparsity: 80.83% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=9.8271e-01  Valid Loss=1.0237e-01  LR=1.00e-03  NMSE=-38.0371 dB
# Epoch  20/300  Loss=9.0165e-01  Valid Loss=9.3313e-02  LR=1.00e-03  NMSE=-38.4393 dB
# Epoch  30/300  Loss=8.5081e-01  Valid Loss=8.6856e-02  LR=1.00e-03  NMSE=-38.7506 dB
# Epoch  40/300  Loss=8.2191e-01  Valid Loss=8.3522e-02  LR=1.00e-03  NMSE=-38.9206 dB
# Epoch  50/300  Loss=8.0567e-01  Valid Loss=8.1480e-02  LR=1.00e-03  NMSE=-39.0281 dB
# Epoch  60/300  Loss=7.9667e-01  Valid Loss=8.0129e-02  LR=1.00e-03  NMSE=-39.1008 dB
# Epoch  70/300  Loss=7.9158e-01  Valid Loss=7.9197e-02  LR=1.00e-03  NMSE=-39.1516 dB
# Epoch  80/300  Loss=7.8739e-01  Valid Loss=7.8535e-02  LR=1.00e-03  NMSE=-39.1880 dB
# Epoch  90/300  Loss=7.8333e-01  Valid Loss=7.8039e-02  LR=1.00e-03  NMSE=-39.2156 dB
# Epoch 100/300  Loss=7.7989e-01  Valid Loss=7.7658e-02  LR=1.00e-03  NMSE=-39.2368 dB
# Epoch 110/300  Loss=7.7709e-01  Valid Loss=7.7358e-02  LR=1.00e-03  NMSE=-39.2536 dB
# Epoch 120/300  Loss=7.7477e-01  Valid Loss=7.7115e-02  LR=1.00e-03  NMSE=-39.2673 dB
# Epoch 130/300  Loss=7.7285e-01  Valid Loss=7.6915e-02  LR=1.00e-03  NMSE=-39.2785 dB
# Epoch 140/300  Loss=7.7127e-01  Valid Loss=7.6753e-02  LR=1.00e-03  NMSE=-39.2877 dB
# Epoch 150/300  Loss=7.6995e-01  Valid Loss=7.6615e-02  LR=1.00e-03  NMSE=-39.2955 dB
# Epoch 160/300  Loss=7.6880e-01  Valid Loss=7.6485e-02  LR=1.00e-03  NMSE=-39.3029 dB
# Epoch 170/300  Loss=7.6786e-01  Valid Loss=7.6370e-02  LR=1.00e-03  NMSE=-39.3094 dB
# Epoch 180/300  Loss=7.6697e-01  Valid Loss=7.6273e-02  LR=1.00e-03  NMSE=-39.3149 dB
# Epoch 190/300  Loss=7.6617e-01  Valid Loss=7.6182e-02  LR=1.00e-03  NMSE=-39.3202 dB
# Epoch 200/300  Loss=7.6548e-01  Valid Loss=7.6098e-02  LR=1.00e-03  NMSE=-39.3249 dB
# Epoch 210/300  Loss=7.6479e-01  Valid Loss=7.6025e-02  LR=1.00e-03  NMSE=-39.3291 dB
# Epoch 220/300  Loss=7.6420e-01  Valid Loss=7.5952e-02  LR=1.00e-03  NMSE=-39.3333 dB
# Epoch 230/300  Loss=7.6365e-01  Valid Loss=7.5887e-02  LR=1.00e-03  NMSE=-39.3370 dB
# Epoch 240/300  Loss=7.6315e-01  Valid Loss=7.5826e-02  LR=1.00e-03  NMSE=-39.3405 dB
# Epoch 250/300  Loss=7.6265e-01  Valid Loss=7.5764e-02  LR=1.00e-03  NMSE=-39.3440 dB
# Epoch 260/300  Loss=7.6220e-01  Valid Loss=7.5704e-02  LR=1.00e-03  NMSE=-39.3475 dB
# Epoch 270/300  Loss=7.6171e-01  Valid Loss=7.5650e-02  LR=1.00e-03  NMSE=-39.3506 dB
# Epoch 280/300  Loss=7.6124e-01  Valid Loss=7.5600e-02  LR=1.00e-03  NMSE=-39.3534 dB
# Epoch 290/300  Loss=7.6080e-01  Valid Loss=7.5551e-02  LR=1.00e-03  NMSE=-39.3563 dB
# Epoch 300/300  Loss=7.6036e-01  Valid Loss=7.5506e-02  LR=1.00e-03  NMSE=-39.3588 dB
#
# Best model from epoch 300 with validation loss: 7.5506e-02
# NMSE: -39.1380 dB  (threshold: -38.0000 dB)
#   ACCEPTED  (delta: +1.0473 dB)
#   Moderate headroom -> keeping next fraction at 12.50%
#
# ============================================================
# Step 7  |  fraction = 12.50%
# ============================================================
# Pruning 12.50% of remaining weights...
# Current sparsity: 83.19% of weights are zero
# Retraining for 300 epochs...
# Epoch  10/300  Loss=5.2009e+00  Valid Loss=4.9320e-01  LR=1.00e-03  NMSE=-31.2084 dB
# Epoch  20/300  Loss=2.6835e+00  Valid Loss=2.6199e-01  LR=1.00e-03  NMSE=-33.9558 dB
# Epoch  30/300  Loss=1.9010e+00  Valid Loss=1.8809e-01  LR=1.00e-03  NMSE=-35.3950 dB
# Epoch  40/300  Loss=1.5513e+00  Valid Loss=1.5432e-01  LR=1.00e-03  NMSE=-36.2544 dB
# Epoch  50/300  Loss=1.3590e+00  Valid Loss=1.3525e-01  LR=1.00e-03  NMSE=-36.8273 dB
# Epoch  60/300  Loss=1.2425e+00  Valid Loss=1.2337e-01  LR=1.00e-03  NMSE=-37.2264 dB
# Epoch  70/300  Loss=1.1682e+00  Valid Loss=1.1552e-01  LR=1.00e-03  NMSE=-37.5119 dB

# %%
# make .mat files for the best models, so they can be used in the future for physical testing
import scipy.io

num_memory_levels = 15
# Load original, adaptive and fixed pruning models
adaptive_model = PNTDNN_NeuralNetwork(num_memory_levels=15, model_type="OneLayerNetwork", forward_model=True, nn_file_path="pntdnn_ideal_predistorted_forward_model_adaptive_pruned.pt")
fixed_percent_model = PNTDNN_NeuralNetwork(num_memory_levels=15, model_type="OneLayerNetwork", forward_model=True, nn_file_path="pntdnn_ideal_predistorted_forward_model_linear_pruned.pt")
original_model = PNTDNN_NeuralNetwork(num_memory_levels=15, model_type="OneLayerNetwork", forward_model=True, nn_file_path="pntdnn_ideal_predistorted_forward_model.pt")

# Get the full input signal
full_input = ideal_predistored_dataset.input_data

# Generate outputs for each model
print("Generating outputs for each model...")
adaptive_output = adaptive_model.generate_model_output(full_input)
fixed_output = fixed_percent_model.generate_model_output(full_input)
original_output = original_model.generate_model_output(full_input)

# Save to .mat files with 'x' (input) and 'u' (output) naming convention
print("Saving .mat files...")
scipy.io.savemat('adaptive_pruned_output.mat', {'x1': full_input[num_memory_levels:], 'u': adaptive_output})
scipy.io.savemat('fixed_pruned_output.mat', {'x1': full_input[num_memory_levels:], 'u': fixed_output})
scipy.io.savemat('original_model_output.mat', {'x1': full_input[num_memory_levels:], 'u': original_output})

print("✓ Saved adaptive_pruned_output.mat")
print("✓ Saved fixed_pruned_output.mat")
print("✓ Saved original_model_output.mat")
# Out:
# Using cuda device
# Using cuda device
# Using cuda device
# Generating outputs for each model...
# Saving .mat files...
# ✓ Saved adaptive_pruned_output.mat
# ✓ Saved fixed_pruned_output.mat
# ✓ Saved original_model_output.mat

# %%
# Optionally save Volterra model output as well
volterra_output = volterra_forward_model.generate_model_output(full_input)
scipy.io.savemat('volterra_output.mat', {'x1': full_input[num_memory_levels:], 'u': volterra_output})
print("✓ Saved volterra_output.mat")
# Out:
# ✓ Saved volterra_output.mat

# %%
test = DataManager(num_training_points=50000, num_test_points=5000, num_validaiton_points=5000, filepath='fixed_pruned_output.mat')

test.plot_pa_characteristics()
# Out:
# === PA Characteristic Summary ===
# Input amplitude range: 0.0000 to 0.9520
# Output amplitude range: 0.0024 to 1.1121
# Estimated small-signal gain: 1.0588
# Phase distortion range: -152.59° to 169.79°
